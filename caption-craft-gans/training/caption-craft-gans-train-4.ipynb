# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install ftfy
# !pip install huggingface-hub==0.16.4
# !pip install matplotlib 
# !pip install numpy==1.23.5
# !pip install Pillow
# !pip install pycocoevalcap==1.2
# !pip install pycocotools==2.0.6
# !pip install requests
# !pip install scikit-image==0.18.1
# !pip install scipy
# !pip install six
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 
# !pip install tqdm
# !pip install transformers==4.27.4
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-cmg99ujy
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-cmg99ujy
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
# done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (0.16.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (2024.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 718.1 kB/s eta 0:00:00
# Building wheels for collected packages: clip
# done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=31671655224d1fcc111cb4136e84217900da82bda25f4c73aa6453b2268db5bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bujbyzzu/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.2.0
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.10/site-packages (6.2.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy) (0.2.13)
# Collecting huggingface-hub==0.16.4
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (3.13.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub==0.16.4) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (2024.2.2)
# Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.22.2
#     Uninstalling huggingface-hub-0.22.2:
#       Successfully uninstalled huggingface-hub-0.22.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.18.0 requires huggingface-hub>=0.19.4, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.39.3 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# Successfully installed huggingface-hub-0.16.4
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 60.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-nlp 0.8.2 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# datasets 2.18.0 requires huggingface-hub>=0.19.4, but you have huggingface-hub 0.16.4 which is incompatible.
# featuretools 1.30.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.1.1 which is incompatible.
# tensorstore 0.1.56 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# transformers 4.39.3 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# woodwork 0.29.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.3.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# Successfully installed numpy-1.23.5
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Collecting pycocoevalcap==1.2
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pycocotools>=2.0.2 (from pycocoevalcap==1.2)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.16.0)
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 14.5 MB/s eta 0:00:00
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 20.7 MB/s eta 0:00:00
# Installing collected packages: pycocotools, pycocoevalcap
# Successfully installed pycocoevalcap-1.2 pycocotools-2.0.7
# Collecting pycocotools==2.0.6
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
# done
# done
# done
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools==2.0.6) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools==2.0.6) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0.6) (1.16.0)
# Building wheels for collected packages: pycocotools
# done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl size=109338 sha256=3ff19d0571b33a8600afdef8ebb4c2f1b5780b168a373d04e8c39daf5c184a90
#   Stored in directory: /root/.cache/pip/wheels/58/e6/f9/f87c8f8be098b51b616871315318329cae12cdb618f4caac93
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0.6
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
# Collecting scikit-image==0.18.1
#   Downloading scikit-image-0.18.1.tar.gz (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 45.1 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.23.5)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.11.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (3.7.5)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (9.5.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (2.33.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.16.0)
# Building wheels for collected packages: scikit-image
# done
#   Created wheel for scikit-image: filename=scikit_image-0.18.1-cp310-cp310-linux_x86_64.whl size=13943038 sha256=7cc78eb032be4186fd76d72635d5b1680225cb885dcda222d8cc60cb3ceeeee1
#   Stored in directory: /root/.cache/pip/wheels/f7/a4/9c/45bb6974dbba881f9fe338541ad8349705deeb5942928ff243
# Successfully built scikit-image
# Installing collected packages: scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.22.0
#     Uninstalling scikit-image-0.22.0:
#       Successfully uninstalled scikit-image-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.18.1 which is incompatible.
# Successfully installed scikit-image-0.18.1
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.23.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (1.16.0)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Collecting transformers==4.27.4
#   Downloading transformers-4.27.4-py3-none-any.whl.metadata (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.4)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.4) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.4) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.27.4) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (2024.2.2)
# Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 4.7 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.27.4 which is incompatible.
# Successfully installed tokenizers-0.13.3 transformers-4.27.4

# %%
# !mkdir data
# !mkdir data/coco

# %%
import requests
from tqdm import tqdm
import zipfile
import os

url = "https://drive.google.com/uc?export=download&id=1Noa8Bcw6it_ui2rFUhmtxugC2pQ648dH"
file_name = "./data/coco/annotations.zip"
extracted_folder = "./data/coco/"

response = requests.get(url, stream=True)

if response.status_code == 200:
    total_size = int(response.headers.get('content-length', 0))
    with open(file_name, 'wb') as f, tqdm(
        total=total_size, unit='B', unit_scale=True, desc=file_name, ncols=100) as pbar:
        for data in response.iter_content(chunk_size=1024):
            f.write(data)
            pbar.update(len(data))
    print("File downloaded successfully.")

    # Unzip the downloaded file
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder)
    print("File extracted successfully.")
    
    # Delete the downloaded zip file
    os.remove(file_name)
    print("Temporary zip file removed.")
    
else:
    print("Failed to download the file. Status code:", response.status_code)
# Out:
# ./data/coco/annotations.zip: 100%|█████████████████████████████| 16.5M/16.5M [00:00<00:00, 51.2MB/s]
# File downloaded successfully.
# File extracted successfully.
# Temporary zip file removed.

# %%
import requests
from tqdm import tqdm
import zipfile
import os

url = "https://drive.google.com/uc?export=download&id=1vhPZSyHyUPL3gSFdNAXXzfya_MfWn6xT"
file_name = "./CgtGAN-main.zip"
extracted_folder = "./CgtGAN-main"

response = requests.get(url, stream=True)

if response.status_code == 200:
    total_size = int(response.headers.get('content-length', 0))
    with open(file_name, 'wb') as f, tqdm(
        total=total_size, unit='B', unit_scale=True, desc=file_name, ncols=100) as pbar:
        for data in response.iter_content(chunk_size=1024):
            f.write(data)
            pbar.update(len(data))
    print("File downloaded successfully.")

    # Unzip the downloaded file
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder)
    print("File extracted successfully.")
    
    # Delete the downloaded zip file
    os.remove(file_name)
    print("Temporary zip file removed.")
    
else:
    print("Failed to download the file. Status code:", response.status_code)
# Out:
# ./CgtGAN-main.zip: 100%|███████████████████████████████████████| 16.6M/16.6M [00:00<00:00, 51.9MB/s]
# File downloaded successfully.
# File extracted successfully.
# Temporary zip file removed.

# %%
# !cp -r /kaggle/input/clip-embedding-cgt-gans /kaggle/working/data

# %%
# !python /kaggle/working/CgtGAN-main/CgtGAN-main/preprocess/coco/coco_train_captions.py

# %%
# !python /kaggle/working/CgtGAN-main/CgtGAN-main/preprocess/generate_embeddings.py --image_pkl /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_train_images.pkl --caption_pkl /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_train_captions.pkl --image_dataset coco --caption_corpus coco --t 100

# %%
# python initialization.py --output_dir path/to/save/folder --data ./data/external/gcc_ViT-L_14_external_captions.pkl

# %%
# !mkdir output

# %%
# !ls /kaggle/working/data/clip-embedding-cgt-gans
# Out:
# coco_ViT-L_14_test.pkl		  coco_images_coco_captions_ViT-L_14_100.pkl
# coco_ViT-L_14_train_captions.pkl  coco_train_sentences.pkl
# coco_ViT-L_14_train_images.pkl	  model.pt
# coco_ViT-L_14_val.pkl

# %%
# %%writefile /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py

import argparse
from cProfile import label
from tkinter import image_names
from typing import OrderedDict, Tuple, Optional, Union, overload
import torch
from torch.nn import functional as nnf
import os
import os.path as op
from utils.logger import setup_logger
from utils.misc import mkdir, set_seed
from models import ClipCaptionModel, MLP, Mapping_Network
from models import ClipCocoDatasetImageWise, ClipCocoDatasetCaptionWise, TextFeatures, PairsFeatures
from models import ScstRewardCLIPCriterion
from models import RobertaDiscriminator
from transformers import AdamW, get_linear_schedule_with_warmup, get_constant_schedule_with_warmup
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import sys
import json
from tqdm import tqdm
from utils.distributional_utils import json_writer, concat_json_files, delete_json_files
import time
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap
from utils.distributional_utils import get_rank, is_main_process, synchronize, ensure_init_process_group, get_world_size
from enum import Enum
from run_inference import evalation
import gc
import random
import numpy as np



# make dataloader
def make_data_sampler(dataset, shuffle, distributed):
    if distributed:
        return torch.utils.data.distributed.DistributedSampler(dataset, shuffle=shuffle)
    if shuffle:
        sampler = torch.utils.data.sampler.RandomSampler(dataset)
    else:
        sampler = torch.utils.data.sampler.SequentialSampler(dataset)
    return sampler

def make_data_loader(args, mode, is_distributed=True, is_train=True):
    if mode == "train":
        shuffle = True
        # Main Generator dataloader
        image_dataset = PairsFeatures(args.data_train)

        images_per_gpu = args.batch_size
        images_per_batch = images_per_gpu * get_world_size()
        iters_per_batch = len(image_dataset) // images_per_batch
        num_iters = iters_per_batch * args.epochs

        image_sampler = make_data_sampler(image_dataset, shuffle, is_distributed)

        image_dataloader = torch.utils.data.DataLoader(
            image_dataset, num_workers=args.num_workers, sampler=image_sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )

        # Main Discriminator dataloader
        text_dataset = TextFeatures(args.train_sample_n, args.text_corpus,
                                      args.max_gen_length, args.discriminator_type)

        text_sampler = make_data_sampler(text_dataset, shuffle, is_distributed)

        text_dataloader = torch.utils.data.DataLoader(
            text_dataset, num_workers=args.num_workers, sampler=text_sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )

        # log info
        logger.info("Train with {} images per GPU.".format(images_per_gpu))
        logger.info("Total batch size {}".format(images_per_batch))
        logger.info("Total training steps {}".format(num_iters))
        logger.info("load without concate")
        return image_dataloader, text_dataloader

    else:
        # TODO: tensorize and tokenize caption
        if mode == "val":
            dataset = ClipCocoDatasetImageWise(args.gt_val, args.data_val, args.prefix_length,
                                               normalize_prefix=args.normalize_prefix, mode="val")
        elif mode == "test":
            dataset = ClipCocoDatasetImageWise(args.gt_test, args.data_test, args.prefix_length,
                                               normalize_prefix=args.normalize_prefix, mode="test")
        else:
            raise ValueError

        shuffle = False
        images_per_gpu = args.batch_size

        sampler = make_data_sampler(dataset, shuffle, is_distributed)
        data_loader = torch.utils.data.DataLoader(
            dataset, num_workers=args.num_workers, sampler=sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )
        return data_loader

# do train

def generate_with_baseline(args, img_feats, model, tokenizer):
    inputs = {
        'img_feats': img_feats,
        'do_sample': False,
        # hyperparameters of beam search
        'max_length': args.max_gen_length,
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "repetition_penalty": args.repetition_penalty,
        "length_penalty": args.length_penalty,
        "num_return_sequences": 1,
        "num_keep_best": 1,
        "eos_token": args.eos_token,
        "is_decode": True
    }

    def _ids_to_captions(all_ids):
        captions = []
        for ids in all_ids:
            c = tokenizer.decode(ids.tolist(), skip_special_tokens=True)
            captions.append(c)
        return captions

    if args.sc_baseline_type == 'greedy':
        model.eval()
        with torch.no_grad():
            greedy_res_raw, _ = model(**inputs)
            greedy_res_raw.squeeze_(1)  # batch_size * max_len
        greedy_res = _ids_to_captions(greedy_res_raw)
    else:
        greedy_res = None

    model.train()
    inputs['do_sample'] = True
    inputs['num_return_sequences'] = args.train_sample_n
    sample_res_raw, sample_logprobs = model(**inputs)
    sample_res_raw.squeeze_(1)
    sample_logprobs.squeeze_(1)
    assert sample_logprobs.requires_grad == True
    assert sample_res_raw.requires_grad == False
    sample_res = _ids_to_captions(sample_res_raw)

    # gt_res = [train_dataloader.dataset.get_captions_by_key(k) for k in img_keys]
    return greedy_res, sample_res, sample_logprobs

def save_checkpoint(model, args, save_type, epoch=0, step=0, num_trial=10):
    if save_type == 'checkpoint':
        checkpoint_dir = op.join(args.output_dir, 'checkpoint')
    elif save_type == 'best_model':
        checkpoint_dir = op.join(args.output_dir, 'best')

    if not is_main_process():
        return checkpoint_dir
    mkdir(checkpoint_dir)
    # model.module is the model self of DDP distributional setting
    model_to_save = model.module if hasattr(model, 'module') else model
    for i in range(num_trial):
        try:
            torch.save(
                model_to_save.state_dict(),
                op.join(checkpoint_dir, "model.pt"),
            )
            logger.info("Save checkpoint to {}".format(checkpoint_dir))
            break
        except:
            pass
    else:
        logger.info("Failed to save checkpoint after {} trails.".format(num_trial))
    return checkpoint_dir

def train(image_dataloader, text_dataloader, val_dataloader, generator, discriminator, args ,local_rank):
    if args.distributed:
        generator = torch.nn.parallel.DistributedDataParallel(
            generator, device_ids=[local_rank],
            output_device=local_rank,
            find_unused_parameters=True,
        )
        discriminator = torch.nn.parallel.DistributedDataParallel(
            discriminator, device_ids=[local_rank],
            output_device=local_rank,
            find_unused_parameters=True,
        )

    t_total = len(image_dataloader) // args.gradient_accumulation_steps \
                  * args.epochs

    no_decay = ['bias', 'LayerNorm.weight']

    gp_G = [
        {'params': [p for n, p in generator.named_parameters() if not \
            any(nd in n for nd in no_decay)], 'weight_decay': args.weight_decay},
        {'params': [p for n, p in generator.named_parameters() if \
                    any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
    gp_D = [
        {'params': [p for n, p in discriminator.named_parameters() if not \
            any(nd in n for nd in no_decay)], 'weight_decay': args.weight_decay},
        {'params': [p for n, p in discriminator.named_parameters() if \
                    any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]

    optimizer_G = AdamW(gp_G, lr=args.learning_rate, eps=args.adam_epsilon)
    optimizer_D = AdamW(gp_D, lr=args.learning_rate, eps=args.adam_epsilon)

    if args.scheduler == "constant":
        scheduler_G = get_constant_schedule_with_warmup(
            optimizer_G, num_warmup_steps=args.warmup_steps)
        scheduler_D = get_constant_schedule_with_warmup(
            optimizer_D, num_warmup_steps=0)

    elif args.scheduler == "linear":
        scheduler_G = get_linear_schedule_with_warmup(
            optimizer_G, num_warmup_steps=args.warmup_steps, num_training_steps=t_total)
        scheduler_D = get_linear_schedule_with_warmup(
            optimizer_D, num_warmup_steps=0, num_training_steps=t_total)

    else:
        raise ValueError("Unknown scheduler type: {}".format(args.scheduler))

    optimizer_G.zero_grad()
    optimizer_D.zero_grad()

    logger.info("***** Running training *****")
    logger.info("  Epoch number = %d", args.epochs)
    logger.info("  Batch size per GPU = %d", args.batch_size)
    logger.info("  Total train batch size (w. parallel, & accumulation) = %d",
                args.batch_size * get_world_size() * args.gradient_accumulation_steps)
    logger.info("  Gradient Accumulation steps = %d", args.gradient_accumulation_steps)
    logger.info("  Total optimization steps = %d", t_total)

    scst_criterion_CLIP = ScstRewardCLIPCriterion(
        args=args,
        baseline_type=args.sc_baseline_type,
    )

    logger.info("SCST training... ")

    global_step = 0
    best_score = 0.0

    cos_list = []
    l1_list = []
    clip_list = []

    epoch_steps = len(image_dataloader) // args.gradient_accumulation_steps

    if args.distributed:
        tokenizer = generator.module.tokenizer
        pad_and_token = discriminator.module.pad_and_token
        PG_loss = discriminator.module.PG_loss
        get_critic_score = discriminator.module.get_score
    else:
        tokenizer = generator.tokenizer
        pad_and_token = discriminator.pad_and_token
        PG_loss = discriminator.PG_loss
        get_critic_score = discriminator.get_score

    for epoch in range(int(args.epochs)):
        if args.distributed:
            image_dataloader.sampler.set_epoch(epoch)
            text_dataloader.sampler.set_epoch(epoch)

        it_text = iter(text_dataloader)

        cos_total = 0.
        l1_total = 0.
        clip_total = 0.

        for step, (image_feats, text_feats) in enumerate(image_dataloader):
            # Training Main Network
            ## process data
            real_tokens, real_masks = next(it_text)
            real_tokens = real_tokens.to(args.device)
            real_masks = real_masks.to(args.device)
            bsz, sample_times, seq_len = real_tokens.shape
            real_tokens = real_tokens.view((bsz * sample_times, seq_len))
            real_masks = real_masks.view((bsz * sample_times, seq_len))
            image_feats, text_feats = image_feats.to(args.device), text_feats.to(args.device)
            if args.normalize_prefix:
                image_feats = image_feats / image_feats.norm(dim=1, keepdim=True)
                text_feats = text_feats / text_feats.norm(dim=1, keepdim=True)

            ## training Discriminator
            greedy_res, sample_res, sample_logprobs = generate_with_baseline(args, image_feats, generator, tokenizer)

            sample_res_token, sample_res_mask = pad_and_token(sample_res)
            text_real_labels = torch.ones((bsz * sample_times))
            text_fake_labels = torch.zeros((sample_res_token.shape[0]))
            D_loss = discriminator(torch.cat((real_tokens, sample_res_token.detach())),
                             torch.cat((real_masks, sample_res_mask.detach())), training=True,
                             labels=torch.cat((text_real_labels, text_fake_labels)))

            ## training Generator
            reward_loss = scst_criterion_CLIP(image_feats, text_feats, greedy_res, sample_res, sample_logprobs)
            fd_loss = PG_loss(greedy_res, sample_res, sample_logprobs)
            ## compute scores for main network
            l1_score, cos_score, clip_score = scst_criterion_CLIP.get_score()
            cos_total += cos_score
            l1_total += l1_score
            clip_total += clip_score
            critic_score = get_critic_score()

            # loss backward and logging
            if args.gradient_accumulation_steps > 1:
                D_loss = D_loss / args.gradient_accumulation_steps
            D_loss.backward()
            torch.nn.utils.clip_grad_norm_(discriminator.parameters(), args.max_grad_norm)
            if (step + 1) % args.gradient_accumulation_steps == 0:
                global_step += 1
                optimizer_D.step()
                scheduler_D.step()
                discriminator.zero_grad()

            if global_step > args.gan_training_steps:
                reward_weight = min((global_step - args.gan_training_steps) / args.gan_warm_steps, 1.0) * args.reward_weight
            else:
                reward_weight = 0.0
            G_loss = reward_weight * reward_loss + (1.0 - reward_weight) * fd_loss

            if args.gradient_accumulation_steps > 1:
                G_loss = G_loss / args.gradient_accumulation_steps
            G_loss.backward()
            torch.nn.utils.clip_grad_norm_(generator.parameters(), args.max_grad_norm)
            if (step + 1) % args.gradient_accumulation_steps == 0:
                optimizer_G.step()
                scheduler_G.step()
                generator.zero_grad()

            if (step + 1) % args.gradient_accumulation_steps == 0:
                if global_step % args.logging_steps == 0:
                    logger.info("Epoch: {}, global_step: {}\n" \
                                "G loss: {:.4f}, D loss: {:.4f}".format(epoch + 1, global_step,
                                                                           G_loss, D_loss))
                    logger.info("Main Network Training: \n" \
                                "cosine score: {:.4f}, l1 score: {:.4f}, clip score: {:.4f}, critic score: {:.4f}\n" \
                                "reward loss: {:.4f}, fD loss: {:.4f}\n".format(cos_score, l1_score, clip_score, critic_score,
                                                                                 reward_loss, fd_loss))

        checkpoint_dir = save_checkpoint(generator, args, save_type='checkpoint')
        synchronize()
        # evaluation
        if args.evaluate_during_training:
            logger.info("Epoch %d training finish. Performing evaluation" % (epoch + 1))
            res = evaluate(args, global_step, val_dataloader, generator, tokenizer,
                    checkpoint_dir)
            if is_main_process():
                logger.info('evaluation result: {}\n'.format(str(res)))
                cider_score = res['CIDEr']
                if cider_score > best_score:
                    best_score = cider_score
                    logger.info("epoch: {}, best cider: {}".format(epoch + 1, best_score))
                    best_dir = save_checkpoint(generator, args, save_type='best_model', epoch=epoch + 1, step=global_step)
            synchronize()

        cos_total /= epoch_steps
        l1_total /= epoch_steps
        clip_total /= epoch_steps
        cos_list.append(cos_total)
        l1_list.append(l1_total)
        clip_list.append(clip_total)

        logger.info("average cos score: {} \n " \
                    "average l1 score: {} \n " \
                    "average clip score: {}".format(str(cos_list), str(l1_list), str(clip_list)))
    return 0

# do test/val

def test(args, test_dataloader, model, tokenizer, predict_file):
    world_size = get_world_size()
    if world_size == 1:
        cache_file = predict_file
    else:
        cache_file = op.splitext(predict_file)[0] + '_{}_{}'.format(get_rank(),
                world_size) + op.splitext(predict_file)[1]
    model.eval()
    inputs_param = {'is_decode': True,
        'do_sample': False,
        # hyperparameters of beam search
        'eos_token' : args.eos_token,
        'max_length': args.max_gen_length,
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "repetition_penalty": args.repetition_penalty,
        "length_penalty": args.length_penalty,
        "num_return_sequences": args.num_return_sequences,
        "num_keep_best": args.num_keep_best,
    }
    def _generate():
        time_meter = 0
        with torch.no_grad():
            for step, (img_id, batch) in enumerate(test_dataloader):
                batch = tuple(t.to(args.device) for t in batch)
                inputs = {"img_feats":batch[2]}
                inputs.update(inputs_param)
                tic = time.time()
                # captions, logprobs
                outputs = model(**inputs)
                time_meter += time.time() - tic
                all_caps = outputs[0]  # batch_size * num_keep_best * max_len
                all_confs = torch.exp(outputs[1])

                for img_key, caps, confs in zip(img_id, all_caps, all_confs):
                    res = []
                    for cap, conf in zip(caps, confs):
                        cap = tokenizer.decode(cap.tolist(), skip_special_tokens=True)
                        res.append({'caption': cap, 'conf': conf.item()})
                    if isinstance(img_key, torch.Tensor):
                        img_key = img_key.item()
                    yield img_key, res[0]['caption']
        logger.info("Inference model computing time: {} seconds per batch".format(time_meter / (step+1)))
    cache_file = open(cache_file, 'w')
    json_writer(_generate(), cache_file)
    if world_size > 1:
        torch.distributed.barrier()
    if world_size > 1 and is_main_process():
        cache_files = [op.splitext(predict_file)[0] + '_{}_{}'.format(i, world_size) + \
            op.splitext(predict_file)[1] for i in range(world_size)]
        concat_json_files(cache_files, predict_file)
        delete_json_files(cache_files)
    if world_size > 1:
        torch.distributed.barrier()

def get_predict_file(output_dir, mode, iteration, args):
    cc = ['pred']
    # make sure it works with/without / in end of the path.
    # data = op.basename(op.join(args.data_dir, '')[:-1])
    # cc.append(data)
    cc.append('max{}'.format(args.max_gen_length))
    if args.num_keep_best != 1:
        cc.append('best{}'.format(args.num_keep_best))
    return op.join(output_dir, '{}_{}_{}.json'.format('.'.join(cc), iteration, mode))

def evaluate_on_coco_caption(predict_file, caption_file):
    coco = COCO(caption_file)
    cocoRes = coco.loadRes(predict_file)
    cocoEval = COCOEvalCap(coco, cocoRes)

    # evaluate on a subset of images by setting
    # cocoEval.params['image_id'] = cocoRes.getImgIds()
    # please remove this line when evaluating the full validation set
    cocoEval.params['image_id'] = cocoRes.getImgIds()

    # evaluate results
    # SPICE will take a few minutes the first time, but speeds up due to caching
    cocoEval.evaluate()
    result = cocoEval.eval
    return result

def evaluate(args, iteration, val_dataloader, model, tokenizer, output_dir):
    result = None
    mode = val_dataloader.dataset.mode
    predict_file = get_predict_file(output_dir, mode, iteration, args)
    test(args, val_dataloader, model, tokenizer, predict_file)

    if get_world_size() > 1:
        torch.distributed.barrier()
    if is_main_process():
        caption_file = val_dataloader.dataset.gt_file
        result = evaluate_on_coco_caption(predict_file, caption_file)
    if get_world_size() > 1:
        torch.distributed.barrier()
    return result

def main():
    parser = argparse.ArgumentParser()

    # directory settings
    parser.add_argument('--data_train', type=str, default="", help="path to pair embedding file")
    parser.add_argument('--text_corpus', type=str, default="", help="path to text corpus file")
    parser.add_argument('--data_val', type=str, default="", help="path to val embedding file")
    parser.add_argument('--data_test', type=str, default="", help="path to test embedding file")
    parser.add_argument('--gt_val', type=str, default="", help="path to val json file")
    parser.add_argument('--gt_test', type=str, default="", help="path to test json file")
    parser.add_argument('--output_dir', type=str, default="", help="path to output")
    # operation settings
    parser.add_argument("--do_train", action='store_true', help="Whether to run training.")
    parser.add_argument("--do_infer", action='store_true', help="Whether to run inference.")
    parser.add_argument("--do_eval", action='store_true', help="Whether to run evaluation.")
    parser.add_argument("--batch_size", default=16, type=int,
                        help="Batch size per GPU/CPU for training and evaluation.")
    parser.add_argument("--num_workers", default=4, type=int, help="Workers in dataloader.")
    # global setting
    parser.add_argument("--generator_init", type=str, default='', help="Generator checkpoint.")
#     parser.add_argument("--local_rank", type=int, default=0, help="For distributed training.")
    parser.add_argument('--seed', type=int, default=0, help="random seed")
    # model setting
    parser.add_argument('--clip_model_type', default="ViT-L/14", help="ViT-L/14 or RN50x4 or ViT-B/32")
    parser.add_argument('--mapping_type', type=str, default="mlp", help="mapper type: mlp or transformer")
    parser.add_argument('--prefix_length', type=int, default=10, help="The prefix seq length")
    parser.add_argument('--prefix_length_clip', type=int, default=10,
                        help="When using transformer, project to this length by linear")
    parser.add_argument('--num_layers', type=int, default=4, help="transformer layer number")
    parser.add_argument('--normalize_prefix', dest='normalize_prefix', action='store_true')
    parser.add_argument('--discriminator_type', default='roberta-base')
    # training settings
    parser.add_argument('--gradient_accumulation_steps', type=int, default=1,
                        help="Number of updates steps to accumulate before backward.")
    parser.add_argument("--learning_rate", default=1e-5, type=float, help="The initial lr for G and D")
    parser.add_argument("--weight_decay", default=0.05, type=float, help="Weight deay.")
    parser.add_argument("--adam_epsilon", default=1e-8, type=float, help="Epsilon for Adam.")
    parser.add_argument("--max_grad_norm", default=1.0, type=float, help="Max gradient norm.")
    parser.add_argument("--warmup_steps", default=150, type=int, help="lr linear warmup.")
    parser.add_argument("--scheduler", default='constant', type=str, help="constant or linear")
    parser.add_argument("--epochs", default=50, type=int,
                        help="Total number of training epochs to perform.")
    parser.add_argument('--logging_steps', type=int, default=25, help="Log every X steps.")
    parser.add_argument("--evaluate_during_training", type=bool, default=True,
                        help="Run evaluation during training at each save_steps.")
    parser.add_argument("--test_after_training", type=bool, default=True,
                        help="Test best model after trainig.")
    parser.add_argument('--sc_baseline_type', type=str, default='greedy',
                        help="baseline tyep of REINFORCE algorithm")
    parser.add_argument('--train_sample_n', type=int, default=5,
                        help="number of sampled captions for sc training")
    # param settings
    parser.add_argument("--clip_weight", default=0., type=float, help="weight balancing clip reward and agg reward")
    parser.add_argument("--cos_weight", default=0.5, type=float, help="weight balancing cos and l1 in agg reward")
    parser.add_argument("--reward_weight", default=0.5, type=float, help="weight balancing reward and fD")
    parser.add_argument("--gan_training_steps", type=int, default=150, help="GAN training steps")
    parser.add_argument("--gan_warm_steps", type=int, default=2350, help="GAN warmup steps")
    # generation settings
    parser.add_argument("--eval_model_dir", type=str, default='',
                        help="Model directory for evaluation.")
    parser.add_argument('--max_gen_length', type=int, default=20,
                        help="max length of generated sentences")
    parser.add_argument('--num_return_sequences', type=int, default=1,
                        help="repeating times per image")
    parser.add_argument('--num_keep_best', type=int, default=1,
                        help="number of hypotheses to keep in beam search")
    parser.add_argument('--temperature', type=float, default=1,
                        help="temperature in softmax for sampling")
    parser.add_argument('--top_k', type=int, default=0,
                        help="filter distribution for sampling")
    parser.add_argument('--top_p', type=float, default=1,
                        help="filter distribution for sampling")
    parser.add_argument('--repetition_penalty', type=int, default=1,
                        help="repetition penalty from CTRL paper (https://arxiv.org/abs/1909.05858)")
    parser.add_argument('--length_penalty', type=int, default=1,
                        help="beam search length penalty")
    parser.add_argument('--eos_token', default='.')
    # eval settings
    parser.add_argument('--eval_mode', default="test", help="test dataset: test or val")
    args = parser.parse_args()
    global logger

    local_rank = int(os.environ["LOCAL_RANK"])
    local_rank = ensure_init_process_group(local_rank=local_rank)


    args.num_gpus = get_world_size()
    args.distributed = args.num_gpus > 1
    args.device = torch.device('cuda')
    synchronize()

    output_dir = args.output_dir

    logger = setup_logger("Trainer", output_dir, local_rank)
    logger.warning("Device: %s, n_gpu: %s", args.device, args.num_gpus)
    set_seed(args.seed, args.num_gpus)

    prefix_length = args.prefix_length

    if args.clip_model_type == "ViT-B/32":
        prefix_dim = 512
    elif args.clip_model_type == "ViT-L/14":
        prefix_dim = 768
    elif args.clip_model_type == "RN50x4":
        prefix_dim = 640
    else:
        raise RuntimeError('CLIP model type error')

    # create model
    if args.do_train:
        # create main generator
        generator_checkpoint = args.generator_init
        generator = ClipCaptionModel(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                 num_layers=args.num_layers, mapping_type=args.mapping_type)

        if generator_checkpoint != "":
            logger.info(f"loading generator from {generator_checkpoint}")
            state_dict = torch.load(generator_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)

        # create main discriminator
        discriminator = RobertaDiscriminator(args, args.sc_baseline_type, args.discriminator_type)
        discriminator.to(args.device)

    else:
        generator_checkpoint = args.generator_init
        generator = ClipCaptionModel(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                 num_layers=args.num_layers, mapping_type=args.mapping_type)

        if generator_checkpoint != "":
            logger.info(f"loading generator from {generator_checkpoint}")
            state_dict = torch.load(generator_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)

    generator.to(args.device)
    logger.info("Training/evaluation parameters %s", args)

    # create dataloader and train
    if args.do_train:
        # dataloader for text_generatior, text_discriminatior, image_generatior, image_discriminatior
        image_dataloader, text_dataloader = \
        make_data_loader(args, "train", is_distributed=args.distributed, is_train=True)
        val_dataloader = None
        if args.evaluate_during_training:
            val_dataloader = make_data_loader(args, "val", is_distributed=args.distributed, is_train=False)

        train(image_dataloader, text_dataloader, val_dataloader, generator, discriminator, args ,local_rank )

        # test best model after training
        if args.test_after_training:
            del val_dataloader, image_dataloader, text_dataloader, discriminator
            gc.collect()
            torch.cuda.empty_cache()
            test_dataloader = make_data_loader(args, "test", is_distributed=args.distributed, is_train=False)
            logger.info("Testing best checkpoint")
            best_checkpoint = op.join(args.output_dir, 'best/model.pt')
            logger.info(f"loading generator from {best_checkpoint}")
            state_dict = torch.load(best_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)
            generator.to(args.device)
            result = evaluate(args, "testtime", test_dataloader, generator, generator.tokenizer,
                                    args.output_dir)
            logger.info("Evaluation results : {}".format(str(result)))

    # inference and evaluation
    elif args.do_infer or args.do_eval:
        logger.info("Evaluate on dataset: " + args.eval_mode)
        test_dataloader = make_data_loader(args, args.eval_mode, is_distributed=args.distributed, is_train=False)

        if not args.do_eval:
            predict_file = get_predict_file(args.output_dir, args.eval_mode, "testtime", args)
            test(args, test_dataloader, generator, generator.tokenizer, predict_file)
            logger.info("Prediction results saved to: {}".format(predict_file))
        else:
            result = evaluate(args, "testtime", test_dataloader, generator, generator.tokenizer,
                              args.output_dir)
            logger.info("Evaluation results : {}".format(str(result)))

if __name__ == "__main__":
    main()
# Out:
# Overwriting /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py

# %%
import os

gpus = "0,1"
os.environ["CUDA_VISIBLE_DEVICES"] = gpus
# !export CUDA_VISIBLE_DEVICES=0,1
# !export WORLD_SIZE=2

# %%
import torch
torch.cuda.device_count()
# Out:
# 2

# %%
# !python -m torch.distributed.launch \
# --master_port 17527 \
# --nproc_per_node 2 /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py \
# --output_dir /kaggle/working/output \
# --generator_init /kaggle/working/data/clip-embedding-cgt-gans/model.pt \
# --data_train /kaggle/working/data/clip-embedding-cgt-gans\coco_images_coco_captions_ViT-L_14_100.pkl \
# --data_val /kaggle/working/data/clip-embedding-cgt-gans\coco_ViT-L_14_val.pkl \
# --data_test /kaggle/working/data/clip-embedding-cgt-gans\coco_ViT-L_14_test.pkl \
# --text_corpus /kaggle/working/data/clip-embedding-cgt-gans\coco_train_sentences.pkl \
# --gt_val /kaggle/working/data/coco/annotations/val_caption_coco_format.json \
# --gt_test /kaggle/working/data/coco/annotations/test_caption_coco_format.json \
# --do_train \
# --epochs 1

# %%
# !export TORCH_ELASTIC_MP_TRACEBACK=1

# %%
# !torchrun --nproc_per_node=2 --master_port 17527 \
/kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py \
--output_dir /kaggle/working/output \
--generator_init /kaggle/working/data/clip-embedding-cgt-gans/model.pt \
--data_train /kaggle/working/data/clip-embedding-cgt-gans/coco_images_coco_captions_ViT-L_14_100.pkl \
--data_val /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_val.pkl \
--data_test /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_test.pkl \
--text_corpus /kaggle/working/data/clip-embedding-cgt-gans/coco_train_sentences.pkl \
--gt_val /kaggle/working/data/coco/annotations/val_caption_coco_format.json \
--gt_test /kaggle/working/data/coco/annotations/test_caption_coco_format.json \
--do_train \
--batch_size 16 \
--epochs 4
# Out:
# [2024-04-12 20:06:32,271] torch.distributed.run: [WARNING]
# [2024-04-12 20:06:32,271] torch.distributed.run: [WARNING] *****************************************
# [2024-04-12 20:06:32,271] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# [2024-04-12 20:06:32,271] torch.distributed.run: [WARNING] *****************************************
# 2024-04-12 20:06:40.695224: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-12 20:06:40.695224: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-12 20:06:40.695295: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-12 20:06:40.695364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-12 20:06:40.867429: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-12 20:06:40.867450: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Init distributed training on local rank 1
# Init distributed training on local rank 0
# 2024-04-12 20:06:54,371 Trainer WARNING: Device: cuda, n_gpu: 2
# Downloading config.json: 100%|█████████████████| 665/665 [00:00<00:00, 3.81MB/s]
# Downloading model.safetensors: 100%|██████████| 548M/548M [00:02<00:00, 203MB/s]
# Downloading generation_config.json: 100%|███████| 124/124 [00:00<00:00, 670kB/s]
# Downloading vocab.json: 100%|██████████████| 1.04M/1.04M [00:00<00:00, 14.6MB/s]
# Downloading merges.txt: 100%|████████████████| 456k/456k [00:00<00:00, 21.8MB/s]
# Downloading tokenizer_config.json: 100%|██████| 26.0/26.0 [00:00<00:00, 156kB/s]
# Using MLP as Mapper
# 2024-04-12 20:07:00,740 Trainer INFO: loading generator from /kaggle/working/data/clip-embedding-cgt-gans/model.pt
# Using MLP as Mapper
# Downloading config.json: 100%|█████████████████| 481/481 [00:00<00:00, 2.63MB/s]
# Downloading model.safetensors: 100%|██████████| 499M/499M [00:02<00:00, 205MB/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading vocab.json: 100%|████████████████| 899k/899k [00:00<00:00, 22.5MB/s]
# Downloading merges.txt: 100%|████████████████| 456k/456k [00:00<00:00, 42.6MB/s]
# Downloading tokenizer_config.json: 100%|██████| 25.0/25.0 [00:00<00:00, 181kB/s]
# 2024-04-12 20:07:06,364 Trainer INFO: Training/evaluation parameters Namespace(data_train='/kaggle/working/data/clip-embedding-cgt-gans/coco_images_coco_captions_ViT-L_14_100.pkl', text_corpus='/kaggle/working/data/clip-embedding-cgt-gans/coco_train_sentences.pkl', data_val='/kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_val.pkl', data_test='/kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_test.pkl', gt_val='/kaggle/working/data/coco/annotations/val_caption_coco_format.json', gt_test='/kaggle/working/data/coco/annotations/test_caption_coco_format.json', output_dir='/kaggle/working/output', do_train=True, do_infer=False, do_eval=False, batch_size=16, num_workers=4, generator_init='/kaggle/working/data/clip-embedding-cgt-gans/model.pt', seed=0, clip_model_type='ViT-L/14', mapping_type='mlp', prefix_length=10, prefix_length_clip=10, num_layers=4, normalize_prefix=False, discriminator_type='roberta-base', gradient_accumulation_steps=1, learning_rate=1e-05, weight_decay=0.05, adam_epsilon=1e-08, max_grad_norm=1.0, warmup_steps=150, scheduler='constant', epochs=4, logging_steps=25, evaluate_during_training=True, test_after_training=True, sc_baseline_type='greedy', train_sample_n=5, clip_weight=0.0, cos_weight=0.5, reward_weight=0.5, gan_training_steps=150, gan_warm_steps=2350, eval_model_dir='', max_gen_length=20, num_return_sequences=1, num_keep_best=1, temperature=1, top_k=0, top_p=1, repetition_penalty=1, length_penalty=1, eos_token='.', eval_mode='test', num_gpus=2, distributed=True, device=device(type='cuda'))
# Pair data size is 113287
# Image embedding dim is 768
# Caption embedding dim is 768
# Pair data size is 113287
# Image embedding dim is 768
# Caption embedding dim is 768
# Text Corpus size for Discrimination is 566747
# Text Corpus size for Discrimination is 566747
# 2024-04-12 20:10:21,080 Trainer INFO: Train with 16 images per GPU.
# 2024-04-12 20:10:21,080 Trainer INFO: Total batch size 32
# 2024-04-12 20:10:21,080 Trainer INFO: Total training steps 14160
# 2024-04-12 20:10:21,081 Trainer INFO: load without concate
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# 2024-04-12 20:10:28,551 Trainer INFO: ***** Running training *****
# 2024-04-12 20:10:28,552 Trainer INFO:   Epoch number = 4
# 2024-04-12 20:10:28,552 Trainer INFO:   Batch size per GPU = 16
# 2024-04-12 20:10:28,552 Trainer INFO:   Total train batch size (w. parallel, & accumulation) = 32
# 2024-04-12 20:10:28,552 Trainer INFO:   Gradient Accumulation steps = 1
# 2024-04-12 20:10:28,552 Trainer INFO:   Total optimization steps = 14160
# 100%|████████████████████████████████████████| 890M/890M [00:05<00:00, 167MiB/s]
# 100%|████████████████████████████████████████| 890M/890M [00:07<00:00, 122MiB/s]
# 2024-04-12 20:10:48,747 Trainer INFO: SCST training...
# [W reducer.cpp:1346] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [W reducer.cpp:1346] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# 2024-04-12 20:11:52,027 Trainer INFO: Epoch: 1, global_step: 25
# G loss: -3.8656, D loss: 0.4253
# 2024-04-12 20:11:52,028 Trainer INFO: Main Network Training:
# cosine score: 51.0312, l1 score: 66.1661, clip score: 19.7817, critic score: -0.7828
# reward loss: -38.3431, fD loss: -3.8656
#
# 2024-04-12 20:12:52,893 Trainer INFO: Epoch: 1, global_step: 50
# G loss: -9.9028, D loss: 0.1598
# 2024-04-12 20:12:52,893 Trainer INFO: Main Network Training:
# cosine score: 49.5847, l1 score: 65.9734, clip score: 19.3539, critic score: -2.2153
# reward loss: -32.5308, fD loss: -9.9028
#
# 2024-04-12 20:13:54,394 Trainer INFO: Epoch: 1, global_step: 75
# G loss: -9.0398, D loss: 0.2437
# 2024-04-12 20:13:54,395 Trainer INFO: Main Network Training:
# cosine score: 53.9486, l1 score: 66.6822, clip score: 19.0947, critic score: -1.4160
# reward loss: -26.6071, fD loss: -9.0398
#
# 2024-04-12 20:14:55,763 Trainer INFO: Epoch: 1, global_step: 100
# G loss: -1.2569, D loss: 0.3798
# 2024-04-12 20:14:55,764 Trainer INFO: Main Network Training:
# cosine score: 59.1443, l1 score: 69.7269, clip score: 20.1735, critic score: -1.5829
# reward loss: -10.9315, fD loss: -1.2569
#
# 2024-04-12 20:15:56,308 Trainer INFO: Epoch: 1, global_step: 125
# G loss: -0.2432, D loss: 0.4424
# 2024-04-12 20:15:56,309 Trainer INFO: Main Network Training:
# cosine score: 65.1398, l1 score: 71.6717, clip score: 20.6773, critic score: -0.9477
# reward loss: -12.4799, fD loss: -0.2432
#
# 2024-04-12 20:16:57,174 Trainer INFO: Epoch: 1, global_step: 150
# G loss: -0.9618, D loss: 0.4553
# 2024-04-12 20:16:57,175 Trainer INFO: Main Network Training:
# cosine score: 63.6170, l1 score: 71.4426, clip score: 21.7538, critic score: -1.1726
# reward loss: -5.0105, fD loss: -0.9618
#
# 2024-04-12 20:17:58,013 Trainer INFO: Epoch: 1, global_step: 175
# G loss: -0.5559, D loss: 0.5247
# 2024-04-12 20:17:58,013 Trainer INFO: Main Network Training:
# cosine score: 64.3137, l1 score: 70.5158, clip score: 19.9446, critic score: -0.3684
# reward loss: -11.6541, fD loss: -0.4965
#
# 2024-04-12 20:19:01,766 Trainer INFO: Epoch: 1, global_step: 200
# G loss: 0.0939, D loss: 0.5858
# 2024-04-12 20:19:01,767 Trainer INFO: Main Network Training:
# cosine score: 62.1371, l1 score: 71.4074, clip score: 20.5927, critic score: -1.1175
# reward loss: -7.4562, fD loss: 0.1751
#
# 2024-04-12 20:20:04,755 Trainer INFO: Epoch: 1, global_step: 225
# G loss: -0.6636, D loss: 0.5836
# 2024-04-12 20:20:04,755 Trainer INFO: Main Network Training:
# cosine score: 63.1179, l1 score: 70.7791, clip score: 21.1317, critic score: -0.4858
# reward loss: -7.0026, fD loss: -0.5608
#
# 2024-04-12 20:21:04,572 Trainer INFO: Epoch: 1, global_step: 250
# G loss: -0.0026, D loss: 0.4556
# 2024-04-12 20:21:04,573 Trainer INFO: Main Network Training:
# cosine score: 64.8194, l1 score: 70.3347, clip score: 19.5607, critic score: -1.0074
# reward loss: -3.0277, fD loss: 0.0631
#
# 2024-04-12 20:22:05,377 Trainer INFO: Epoch: 1, global_step: 275
# G loss: -0.2992, D loss: 0.5902
# 2024-04-12 20:22:05,377 Trainer INFO: Main Network Training:
# cosine score: 73.4075, l1 score: 75.5262, clip score: 22.9868, critic score: -0.3363
# reward loss: -3.5471, fD loss: -0.2104
#
# 2024-04-12 20:23:07,776 Trainer INFO: Epoch: 1, global_step: 300
# G loss: -0.5041, D loss: 0.5758
# 2024-04-12 20:23:07,776 Trainer INFO: Main Network Training:
# cosine score: 67.0991, l1 score: 72.6674, clip score: 22.0012, critic score: -0.3810
# reward loss: -6.8160, fD loss: -0.2960
#
# 2024-04-12 20:24:08,827 Trainer INFO: Epoch: 1, global_step: 325
# G loss: -0.1291, D loss: 0.5512
# 2024-04-12 20:24:08,828 Trainer INFO: Main Network Training:
# cosine score: 62.4539, l1 score: 69.4770, clip score: 20.0826, critic score: -0.5793
# reward loss: -3.9166, fD loss: 0.0174
#
# 2024-04-12 20:25:11,033 Trainer INFO: Epoch: 1, global_step: 350
# G loss: -0.1234, D loss: 0.6444
# 2024-04-12 20:25:11,033 Trainer INFO: Main Network Training:
# cosine score: 71.9535, l1 score: 74.9304, clip score: 22.0385, critic score: -0.5837
# reward loss: -2.8079, fD loss: -0.0041
#
# 2024-04-12 20:26:11,408 Trainer INFO: Epoch: 1, global_step: 375
# G loss: -0.1179, D loss: 0.5668
# 2024-04-12 20:26:11,408 Trainer INFO: Main Network Training:
# cosine score: 72.1936, l1 score: 74.9343, clip score: 23.4982, critic score: -0.7722
# reward loss: -6.4008, fD loss: 0.1980
#
# 2024-04-12 20:27:12,526 Trainer INFO: Epoch: 1, global_step: 400
# G loss: -0.2040, D loss: 0.4957
# 2024-04-12 20:27:12,526 Trainer INFO: Main Network Training:
# cosine score: 71.4145, l1 score: 74.6679, clip score: 21.8000, critic score: -0.9590
# reward loss: -7.2904, fD loss: 0.1941
#
# 2024-04-12 20:28:12,763 Trainer INFO: Epoch: 1, global_step: 425
# G loss: -0.0017, D loss: 0.5456
# 2024-04-12 20:28:12,764 Trainer INFO: Main Network Training:
# cosine score: 71.1308, l1 score: 73.6651, clip score: 22.4173, critic score: -0.5556
# reward loss: -3.5139, fD loss: 0.2166
#
# 2024-04-12 20:29:14,827 Trainer INFO: Epoch: 1, global_step: 450
# G loss: -0.4414, D loss: 0.5439
# 2024-04-12 20:29:14,827 Trainer INFO: Main Network Training:
# cosine score: 72.5667, l1 score: 73.6981, clip score: 21.7666, critic score: -0.8637
# reward loss: -5.3452, fD loss: -0.1071
#
# 2024-04-12 20:30:17,881 Trainer INFO: Epoch: 1, global_step: 475
# G loss: -0.3432, D loss: 0.5857
# 2024-04-12 20:30:17,882 Trainer INFO: Main Network Training:
# cosine score: 71.2140, l1 score: 73.8971, clip score: 22.3798, critic score: -0.3286
# reward loss: -5.4449, fD loss: 0.0358
#
# 2024-04-12 20:31:17,998 Trainer INFO: Epoch: 1, global_step: 500
# G loss: -0.4289, D loss: 0.5414
# 2024-04-12 20:31:17,998 Trainer INFO: Main Network Training:
# cosine score: 68.4043, l1 score: 72.0191, clip score: 20.9041, critic score: -0.9689
# reward loss: -5.8773, fD loss: 0.0095
#
# 2024-04-12 20:32:18,865 Trainer INFO: Epoch: 1, global_step: 525
# G loss: -0.4590, D loss: 0.5507
# 2024-04-12 20:32:18,865 Trainer INFO: Main Network Training:
# cosine score: 69.1744, l1 score: 73.4626, clip score: 23.1441, critic score: -0.6779
# reward loss: -5.1244, fD loss: -0.0544
#
# 2024-04-12 20:33:20,803 Trainer INFO: Epoch: 1, global_step: 550
# G loss: -0.2832, D loss: 0.5667
# 2024-04-12 20:33:20,803 Trainer INFO: Main Network Training:
# cosine score: 74.4013, l1 score: 75.8736, clip score: 24.1268, critic score: -1.2165
# reward loss: -3.5903, fD loss: 0.0244
#
# 2024-04-12 20:34:21,346 Trainer INFO: Epoch: 1, global_step: 575
# G loss: -0.3142, D loss: 0.5884
# 2024-04-12 20:34:21,347 Trainer INFO: Main Network Training:
# cosine score: 73.0585, l1 score: 74.4476, clip score: 23.1780, critic score: -1.0426
# reward loss: -4.4048, fD loss: 0.0925
#
# 2024-04-12 20:35:21,978 Trainer INFO: Epoch: 1, global_step: 600
# G loss: -0.2306, D loss: 0.5610
# 2024-04-12 20:35:21,978 Trainer INFO: Main Network Training:
# cosine score: 74.7784, l1 score: 75.6043, clip score: 23.3276, critic score: -1.0011
# reward loss: -3.5867, fD loss: 0.1247
#
# 2024-04-12 20:36:22,556 Trainer INFO: Epoch: 1, global_step: 625
# G loss: 0.2009, D loss: 0.4971
# 2024-04-12 20:36:22,557 Trainer INFO: Main Network Training:
# cosine score: 79.2937, l1 score: 77.7012, clip score: 23.3582, critic score: -1.2089
# reward loss: -2.0611, fD loss: 0.4552
#
# 2024-04-12 20:37:22,086 Trainer INFO: Epoch: 1, global_step: 650
# G loss: -0.4227, D loss: 0.4710
# 2024-04-12 20:37:22,087 Trainer INFO: Main Network Training:
# cosine score: 73.2515, l1 score: 75.4847, clip score: 22.8112, critic score: -1.0979
# reward loss: -1.5732, fD loss: -0.2857
#
# 2024-04-12 20:38:21,984 Trainer INFO: Epoch: 1, global_step: 675
# G loss: -0.0016, D loss: 0.5647
# 2024-04-12 20:38:21,984 Trainer INFO: Main Network Training:
# cosine score: 77.5166, l1 score: 76.3363, clip score: 24.0234, critic score: -0.9061
# reward loss: -1.2189, fD loss: 0.1515
#
# 2024-04-12 20:39:23,432 Trainer INFO: Epoch: 1, global_step: 700
# G loss: -0.9938, D loss: 0.5219
# 2024-04-12 20:39:23,433 Trainer INFO: Main Network Training:
# cosine score: 72.1419, l1 score: 74.7481, clip score: 22.8600, critic score: -0.2029
# reward loss: -6.1049, fD loss: -0.3164
#
# 2024-04-12 20:40:25,346 Trainer INFO: Epoch: 1, global_step: 725
# G loss: -0.7622, D loss: 0.5450
# 2024-04-12 20:40:25,347 Trainer INFO: Main Network Training:
# cosine score: 74.5052, l1 score: 75.2841, clip score: 23.2681, critic score: -0.8591
# reward loss: -5.1917, fD loss: -0.1447
#
# 2024-04-12 20:41:24,733 Trainer INFO: Epoch: 1, global_step: 750
# G loss: -0.2090, D loss: 0.4978
# 2024-04-12 20:41:24,734 Trainer INFO: Main Network Training:
# cosine score: 77.6504, l1 score: 77.2432, clip score: 24.0537, critic score: -1.2081
# reward loss: -2.2181, fD loss: 0.0850
#
# 2024-04-12 20:42:23,703 Trainer INFO: Epoch: 1, global_step: 775
# G loss: -0.3268, D loss: 0.5703
# 2024-04-12 20:42:23,704 Trainer INFO: Main Network Training:
# cosine score: 73.6961, l1 score: 74.6752, clip score: 23.5174, critic score: -0.6627
# reward loss: -2.9917, fD loss: 0.0820
#
# 2024-04-12 20:43:23,789 Trainer INFO: Epoch: 1, global_step: 800
# G loss: -0.4135, D loss: 0.5428
# 2024-04-12 20:43:23,790 Trainer INFO: Main Network Training:
# cosine score: 76.8794, l1 score: 76.6371, clip score: 24.5217, critic score: -1.0758
# reward loss: -2.2854, fD loss: -0.1131
#
# 2024-04-12 20:44:24,447 Trainer INFO: Epoch: 1, global_step: 825
# G loss: 0.0447, D loss: 0.5495
# 2024-04-12 20:44:24,448 Trainer INFO: Main Network Training:
# cosine score: 75.1675, l1 score: 76.0281, clip score: 23.3150, critic score: -0.6849
# reward loss: -1.7340, fD loss: 0.3429
#
# 2024-04-12 20:45:23,614 Trainer INFO: Epoch: 1, global_step: 850
# G loss: -0.3421, D loss: 0.4167
# 2024-04-12 20:45:23,614 Trainer INFO: Main Network Training:
# cosine score: 79.2892, l1 score: 77.2020, clip score: 23.2251, critic score: -1.7254
# reward loss: -2.2246, fD loss: -0.0127
#
# 2024-04-12 20:46:20,953 Trainer INFO: Epoch: 1, global_step: 875
# G loss: -0.3986, D loss: 0.4788
# 2024-04-12 20:46:20,953 Trainer INFO: Main Network Training:
# cosine score: 76.7246, l1 score: 76.3269, clip score: 24.0813, critic score: -1.0880
# reward loss: -4.0077, fD loss: 0.2597
#
# 2024-04-12 20:47:21,648 Trainer INFO: Epoch: 1, global_step: 900
# G loss: -0.4676, D loss: 0.5268
# 2024-04-12 20:47:21,648 Trainer INFO: Main Network Training:
# cosine score: 75.5580, l1 score: 76.3765, clip score: 24.9245, critic score: -0.7568
# reward loss: -2.9949, fD loss: 0.0123
#
# 2024-04-12 20:48:22,862 Trainer INFO: Epoch: 1, global_step: 925
# G loss: -0.0327, D loss: 0.5419
# 2024-04-12 20:48:22,863 Trainer INFO: Main Network Training:
# cosine score: 75.9896, l1 score: 75.8936, clip score: 23.5943, critic score: -0.9295
# reward loss: -0.1070, fD loss: -0.0180
#
# 2024-04-12 20:49:21,308 Trainer INFO: Epoch: 1, global_step: 950
# G loss: -0.5538, D loss: 0.5918
# 2024-04-12 20:49:21,308 Trainer INFO: Main Network Training:
# cosine score: 77.7013, l1 score: 76.6588, clip score: 24.6525, critic score: -0.8904
# reward loss: -1.2631, fD loss: -0.4083
#
# 2024-04-12 20:50:21,956 Trainer INFO: Epoch: 1, global_step: 975
# G loss: -0.0695, D loss: 0.4954
# 2024-04-12 20:50:21,957 Trainer INFO: Main Network Training:
# cosine score: 82.8511, l1 score: 79.4518, clip score: 26.5370, critic score: -0.9031
# reward loss: -0.1168, fD loss: -0.0594
#
# 2024-04-12 20:51:22,567 Trainer INFO: Epoch: 1, global_step: 1000
# G loss: -0.4451, D loss: 0.5565
# 2024-04-12 20:51:22,568 Trainer INFO: Main Network Training:
# cosine score: 77.0427, l1 score: 76.8196, clip score: 25.4735, critic score: -0.7571
# reward loss: -2.3898, fD loss: -0.0158
#
# 2024-04-12 20:52:20,591 Trainer INFO: Epoch: 1, global_step: 1025
# G loss: -0.2692, D loss: 0.4729
# 2024-04-12 20:52:20,592 Trainer INFO: Main Network Training:
# cosine score: 79.2686, l1 score: 77.4342, clip score: 24.0039, critic score: -0.9986
# reward loss: -3.3781, fD loss: 0.4420
#
# 2024-04-12 20:53:19,957 Trainer INFO: Epoch: 1, global_step: 1050
# G loss: -0.2996, D loss: 0.4576
# 2024-04-12 20:53:19,958 Trainer INFO: Main Network Training:
# cosine score: 76.7849, l1 score: 77.1069, clip score: 24.4368, critic score: -1.1425
# reward loss: -2.1644, fD loss: 0.1420
#
# 2024-04-12 20:54:21,387 Trainer INFO: Epoch: 1, global_step: 1075
# G loss: -0.2268, D loss: 0.4387
# 2024-04-12 20:54:21,388 Trainer INFO: Main Network Training:
# cosine score: 77.9685, l1 score: 76.5306, clip score: 24.6702, critic score: -1.0739
# reward loss: -3.0657, fD loss: 0.4688
#
# 2024-04-12 20:55:20,069 Trainer INFO: Epoch: 1, global_step: 1100
# G loss: -0.1904, D loss: 0.5238
# 2024-04-12 20:55:20,070 Trainer INFO: Main Network Training:
# cosine score: 79.9611, l1 score: 77.8484, clip score: 24.5349, critic score: -1.0689
# reward loss: -1.3463, fD loss: 0.1025
#
# 2024-04-12 20:56:17,991 Trainer INFO: Epoch: 1, global_step: 1125
# G loss: -0.7043, D loss: 0.4702
# 2024-04-12 20:56:17,991 Trainer INFO: Main Network Training:
# cosine score: 80.8365, l1 score: 78.3438, clip score: 23.3299, critic score: -1.6080
# reward loss: -2.2659, fD loss: -0.2956
#
# 2024-04-12 20:57:16,827 Trainer INFO: Epoch: 1, global_step: 1150
# G loss: -0.3831, D loss: 0.5402
# 2024-04-12 20:57:16,827 Trainer INFO: Main Network Training:
# cosine score: 75.7446, l1 score: 75.3409, clip score: 22.7683, critic score: -0.7519
# reward loss: -3.2592, fD loss: 0.3942
#
# 2024-04-12 20:58:16,902 Trainer INFO: Epoch: 1, global_step: 1175
# G loss: -0.5436, D loss: 0.4496
# 2024-04-12 20:58:16,902 Trainer INFO: Main Network Training:
# cosine score: 78.7070, l1 score: 76.8151, clip score: 24.2897, critic score: -1.1575
# reward loss: -2.2300, fD loss: -0.0732
#
# 2024-04-12 20:59:15,669 Trainer INFO: Epoch: 1, global_step: 1200
# G loss: -0.9000, D loss: 0.5066
# 2024-04-12 20:59:15,669 Trainer INFO: Main Network Training:
# cosine score: 76.4364, l1 score: 76.2617, clip score: 24.3287, critic score: -0.9434
# reward loss: -3.4391, fD loss: -0.1696
#
# 2024-04-12 21:00:13,185 Trainer INFO: Epoch: 1, global_step: 1225
# G loss: -0.2275, D loss: 0.4549
# 2024-04-12 21:00:13,185 Trainer INFO: Main Network Training:
# cosine score: 77.5334, l1 score: 76.7112, clip score: 23.2302, critic score: -1.2901
# reward loss: -1.4029, fD loss: 0.1211
#
# 2024-04-12 21:01:12,566 Trainer INFO: Epoch: 1, global_step: 1250
# G loss: -0.3449, D loss: 0.5087
# 2024-04-12 21:01:12,567 Trainer INFO: Main Network Training:
# cosine score: 77.7789, l1 score: 77.6507, clip score: 25.8141, critic score: -0.9384
# reward loss: -1.2656, fD loss: -0.0636
#
# 2024-04-12 21:02:11,311 Trainer INFO: Epoch: 1, global_step: 1275
# G loss: -0.1781, D loss: 0.3782
# 2024-04-12 21:02:11,312 Trainer INFO: Main Network Training:
# cosine score: 80.1692, l1 score: 78.8853, clip score: 25.2032, critic score: -1.6586
# reward loss: -1.6986, fD loss: 0.3004
#
# 2024-04-12 21:03:10,068 Trainer INFO: Epoch: 1, global_step: 1300
# G loss: -0.4361, D loss: 0.4120
# 2024-04-12 21:03:10,069 Trainer INFO: Main Network Training:
# cosine score: 72.9134, l1 score: 74.1613, clip score: 23.2247, critic score: -1.4691
# reward loss: -1.2768, fD loss: -0.1638
#
# 2024-04-12 21:04:07,250 Trainer INFO: Epoch: 1, global_step: 1325
# G loss: -0.7617, D loss: 0.4154
# 2024-04-12 21:04:07,250 Trainer INFO: Main Network Training:
# cosine score: 77.8234, l1 score: 76.7615, clip score: 24.5775, critic score: -1.4591
# reward loss: -1.7311, fD loss: -0.4385
#
# 2024-04-12 21:05:06,178 Trainer INFO: Epoch: 1, global_step: 1350
# G loss: -0.9862, D loss: 0.4792
# 2024-04-12 21:05:06,178 Trainer INFO: Main Network Training:
# cosine score: 76.5162, l1 score: 76.4033, clip score: 23.9897, critic score: -0.7671
# reward loss: -3.0036, fD loss: -0.2946
#
# 2024-04-12 21:06:06,309 Trainer INFO: Epoch: 1, global_step: 1375
# G loss: -0.2033, D loss: 0.4805
# 2024-04-12 21:06:06,310 Trainer INFO: Main Network Training:
# cosine score: 80.2528, l1 score: 78.5505, clip score: 25.7130, critic score: -1.2168
# reward loss: -0.1848, fD loss: -0.2097
#
# 2024-04-12 21:07:06,574 Trainer INFO: Epoch: 1, global_step: 1400
# G loss: -0.2359, D loss: 0.4805
# 2024-04-12 21:07:06,575 Trainer INFO: Main Network Training:
# cosine score: 81.0885, l1 score: 78.9782, clip score: 24.6758, critic score: -1.0611
# reward loss: -0.8859, fD loss: -0.0004
#
# 2024-04-12 21:08:03,834 Trainer INFO: Epoch: 1, global_step: 1425
# G loss: 0.7698, D loss: 0.4286
# 2024-04-12 21:08:03,835 Trainer INFO: Main Network Training:
# cosine score: 77.8332, l1 score: 76.9936, clip score: 24.2051, critic score: -1.4308
# reward loss: 1.2478, fD loss: 0.5919
#
# 2024-04-12 21:09:01,770 Trainer INFO: Epoch: 1, global_step: 1450
# G loss: -0.7501, D loss: 0.4554
# 2024-04-12 21:09:01,770 Trainer INFO: Main Network Training:
# cosine score: 76.9142, l1 score: 76.4442, clip score: 24.4965, critic score: -0.9258
# reward loss: -2.6697, fD loss: -0.0162
#
# 2024-04-12 21:10:01,012 Trainer INFO: Epoch: 1, global_step: 1475
# G loss: -0.5480, D loss: 0.4538
# 2024-04-12 21:10:01,013 Trainer INFO: Main Network Training:
# cosine score: 80.1075, l1 score: 77.8933, clip score: 25.3887, critic score: -1.3790
# reward loss: -1.7447, fD loss: -0.0781
#
# 2024-04-12 21:11:01,305 Trainer INFO: Epoch: 1, global_step: 1500
# G loss: -0.0164, D loss: 0.5140
# 2024-04-12 21:11:01,306 Trainer INFO: Main Network Training:
# cosine score: 72.8986, l1 score: 75.0213, clip score: 23.8422, critic score: -1.1005
# reward loss: -1.0867, fD loss: 0.4148
#
# 2024-04-12 21:12:01,225 Trainer INFO: Epoch: 1, global_step: 1525
# G loss: -0.1325, D loss: 0.4644
# 2024-04-12 21:12:01,226 Trainer INFO: Main Network Training:
# cosine score: 82.3565, l1 score: 79.0748, clip score: 24.2150, critic score: -1.2612
# reward loss: -0.6822, fD loss: 0.0949
#
# 2024-04-12 21:12:59,952 Trainer INFO: Epoch: 1, global_step: 1550
# G loss: -0.3276, D loss: 0.4394
# 2024-04-12 21:12:59,952 Trainer INFO: Main Network Training:
# cosine score: 77.2207, l1 score: 76.8886, clip score: 24.9464, critic score: -1.3984
# reward loss: -1.2247, fD loss: 0.0530
#
# 2024-04-12 21:13:58,669 Trainer INFO: Epoch: 1, global_step: 1575
# G loss: -0.7219, D loss: 0.4850
# 2024-04-12 21:13:58,669 Trainer INFO: Main Network Training:
# cosine score: 79.3816, l1 score: 77.6771, clip score: 23.6997, critic score: -1.1504
# reward loss: -2.4696, fD loss: 0.0385
#
# 2024-04-12 21:14:58,146 Trainer INFO: Epoch: 1, global_step: 1600
# G loss: -0.2064, D loss: 0.3929
# 2024-04-12 21:14:58,146 Trainer INFO: Main Network Training:
# cosine score: 83.9038, l1 score: 79.5139, clip score: 25.7360, critic score: -1.3749
# reward loss: -1.0582, fD loss: 0.1736
#
# 2024-04-12 21:15:58,520 Trainer INFO: Epoch: 1, global_step: 1625
# G loss: 0.0266, D loss: 0.4935
# 2024-04-12 21:15:58,521 Trainer INFO: Main Network Training:
# cosine score: 81.6596, l1 score: 79.3182, clip score: 25.2136, critic score: -1.5377
# reward loss: -1.0172, fD loss: 0.5040
#
# 2024-04-12 21:16:57,787 Trainer INFO: Epoch: 1, global_step: 1650
# G loss: -0.6358, D loss: 0.4017
# 2024-04-12 21:16:57,788 Trainer INFO: Main Network Training:
# cosine score: 81.1240, l1 score: 78.0666, clip score: 23.7766, critic score: -1.6592
# reward loss: -2.4678, fD loss: 0.2230
#
# 2024-04-12 21:17:56,194 Trainer INFO: Epoch: 1, global_step: 1675
# G loss: -0.4859, D loss: 0.5067
# 2024-04-12 21:17:56,194 Trainer INFO: Main Network Training:
# cosine score: 84.5265, l1 score: 80.5581, clip score: 25.8989, critic score: -0.9902
# reward loss: -1.2060, fD loss: -0.1401
#
# 2024-04-12 21:18:53,228 Trainer INFO: Epoch: 1, global_step: 1700
# G loss: -0.1545, D loss: 0.3838
# 2024-04-12 21:18:53,229 Trainer INFO: Main Network Training:
# cosine score: 82.5356, l1 score: 79.2255, clip score: 24.9586, critic score: -2.3167
# reward loss: -0.6252, fD loss: 0.0771
#
# 2024-04-12 21:19:49,928 Trainer INFO: Epoch: 1, global_step: 1725
# G loss: -0.8220, D loss: 0.3820
# 2024-04-12 21:19:49,928 Trainer INFO: Main Network Training:
# cosine score: 83.0663, l1 score: 79.4817, clip score: 24.4369, critic score: -1.9432
# reward loss: -2.1774, fD loss: -0.1388
#
# 2024-04-12 21:20:47,231 Trainer INFO: Epoch: 1, global_step: 1750
# G loss: -0.1112, D loss: 0.3581
# 2024-04-12 21:20:47,232 Trainer INFO: Main Network Training:
# cosine score: 82.0331, l1 score: 78.6603, clip score: 24.3038, critic score: -1.6506
# reward loss: -0.9620, fD loss: 0.3279
#
# 2024-04-12 21:21:45,374 Trainer INFO: Epoch: 1, global_step: 1775
# G loss: -0.4378, D loss: 0.3632
# 2024-04-12 21:21:45,374 Trainer INFO: Main Network Training:
# cosine score: 81.7197, l1 score: 79.0881, clip score: 24.4581, critic score: -1.8420
# reward loss: -1.3148, fD loss: 0.0256
#
# 2024-04-12 21:22:43,261 Trainer INFO: Epoch: 1, global_step: 1800
# G loss: -0.2903, D loss: 0.4602
# 2024-04-12 21:22:43,261 Trainer INFO: Main Network Training:
# cosine score: 81.3926, l1 score: 78.1275, clip score: 24.3054, critic score: -1.9416
# reward loss: -1.2337, fD loss: 0.2201
#
# 2024-04-12 21:23:40,898 Trainer INFO: Epoch: 1, global_step: 1825
# G loss: -0.9122, D loss: 0.4220
# 2024-04-12 21:23:40,898 Trainer INFO: Main Network Training:
# cosine score: 79.4137, l1 score: 77.6347, clip score: 23.4465, critic score: -1.6092
# reward loss: -2.3960, fD loss: -0.0906
#
# 2024-04-12 21:24:39,748 Trainer INFO: Epoch: 1, global_step: 1850
# G loss: -0.4982, D loss: 0.4323
# 2024-04-12 21:24:39,749 Trainer INFO: Main Network Training:
# cosine score: 79.4843, l1 score: 77.8159, clip score: 24.6024, critic score: -1.6477
# reward loss: -0.7017, fD loss: -0.3828
#
# 2024-04-12 21:25:40,046 Trainer INFO: Epoch: 1, global_step: 1875
# G loss: -0.8891, D loss: 0.3075
# 2024-04-12 21:25:40,047 Trainer INFO: Main Network Training:
# cosine score: 82.7472, l1 score: 79.3734, clip score: 25.9157, critic score: -2.3026
# reward loss: -2.5102, fD loss: 0.0509
#
# 2024-04-12 21:26:39,303 Trainer INFO: Epoch: 1, global_step: 1900
# G loss: -0.4648, D loss: 0.3912
# 2024-04-12 21:26:39,303 Trainer INFO: Main Network Training:
# cosine score: 85.5693, l1 score: 80.3608, clip score: 24.9262, critic score: -1.6770
# reward loss: -1.5349, fD loss: 0.1700
#
# 2024-04-12 21:27:37,012 Trainer INFO: Epoch: 1, global_step: 1925
# G loss: 0.0301, D loss: 0.4467
# 2024-04-12 21:27:37,012 Trainer INFO: Main Network Training:
# cosine score: 83.6549, l1 score: 79.7885, clip score: 25.6930, critic score: -1.2475
# reward loss: -0.1687, fD loss: 0.1507
#
# 2024-04-12 21:28:35,525 Trainer INFO: Epoch: 1, global_step: 1950
# G loss: 0.1198, D loss: 0.4732
# 2024-04-12 21:28:35,526 Trainer INFO: Main Network Training:
# cosine score: 78.2052, l1 score: 76.6249, clip score: 23.8111, critic score: -1.2176
# reward loss: -0.5023, fD loss: 0.5059
#
# 2024-04-12 21:29:35,262 Trainer INFO: Epoch: 1, global_step: 1975
# G loss: -0.4389, D loss: 0.4336
# 2024-04-12 21:29:35,262 Trainer INFO: Main Network Training:
# cosine score: 84.1094, l1 score: 80.2222, clip score: 23.8952, critic score: -1.6719
# reward loss: -1.1795, fD loss: 0.0311
#
# 2024-04-12 21:30:34,497 Trainer INFO: Epoch: 1, global_step: 2000
# G loss: -1.0345, D loss: 0.3915
# 2024-04-12 21:30:34,498 Trainer INFO: Main Network Training:
# cosine score: 76.9600, l1 score: 76.8206, clip score: 23.9833, critic score: -1.5461
# reward loss: -2.3939, fD loss: -0.1521
#
# 2024-04-12 21:31:31,056 Trainer INFO: Epoch: 1, global_step: 2025
# G loss: -0.3879, D loss: 0.3656
# 2024-04-12 21:31:31,057 Trainer INFO: Main Network Training:
# cosine score: 80.8761, l1 score: 78.7592, clip score: 25.2567, critic score: -1.7224
# reward loss: -1.1709, fD loss: 0.1318
#
# 2024-04-12 21:32:27,848 Trainer INFO: Epoch: 1, global_step: 2050
# G loss: -0.6222, D loss: 0.3303
# 2024-04-12 21:32:27,849 Trainer INFO: Main Network Training:
# cosine score: 79.8631, l1 score: 77.9547, clip score: 25.3054, critic score: -2.1145
# reward loss: -1.4935, fD loss: -0.0309
#
# 2024-04-12 21:33:26,263 Trainer INFO: Epoch: 1, global_step: 2075
# G loss: -0.5523, D loss: 0.4455
# 2024-04-12 21:33:26,263 Trainer INFO: Main Network Training:
# cosine score: 80.0363, l1 score: 77.7187, clip score: 24.4766, critic score: -1.6904
# reward loss: -1.5070, fD loss: 0.1099
#
# 2024-04-12 21:34:25,047 Trainer INFO: Epoch: 1, global_step: 2100
# G loss: -0.5893, D loss: 0.4668
# 2024-04-12 21:34:25,048 Trainer INFO: Main Network Training:
# cosine score: 83.3276, l1 score: 79.2382, clip score: 25.1943, critic score: -1.9768
# reward loss: -1.6158, fD loss: 0.1386
#
# 2024-04-12 21:35:22,566 Trainer INFO: Epoch: 1, global_step: 2125
# G loss: -0.6781, D loss: 0.3777
# 2024-04-12 21:35:22,567 Trainer INFO: Main Network Training:
# cosine score: 82.6485, l1 score: 78.8670, clip score: 24.5241, critic score: -2.3045
# reward loss: -1.2232, fD loss: -0.2830
#
# 2024-04-12 21:36:20,145 Trainer INFO: Epoch: 1, global_step: 2150
# G loss: -0.0528, D loss: 0.3305
# 2024-04-12 21:36:20,146 Trainer INFO: Main Network Training:
# cosine score: 83.5249, l1 score: 79.2346, clip score: 24.4509, critic score: -2.6211
# reward loss: -0.8283, fD loss: 0.5217
#
# 2024-04-12 21:37:17,276 Trainer INFO: Epoch: 1, global_step: 2175
# G loss: -0.5892, D loss: 0.3161
# 2024-04-12 21:37:17,276 Trainer INFO: Main Network Training:
# cosine score: 86.4555, l1 score: 82.2241, clip score: 27.1075, critic score: -1.8574
# reward loss: -1.5467, fD loss: 0.1356
#
# 2024-04-12 21:38:15,267 Trainer INFO: Epoch: 1, global_step: 2200
# G loss: -0.8075, D loss: 0.4122
# 2024-04-12 21:38:15,267 Trainer INFO: Main Network Training:
# cosine score: 82.3504, l1 score: 79.8142, clip score: 26.9363, critic score: -1.3245
# reward loss: -1.6959, fD loss: -0.1202
#
# 2024-04-12 21:39:11,570 Trainer INFO: Epoch: 1, global_step: 2225
# G loss: -0.2727, D loss: 0.3576
# 2024-04-12 21:39:11,571 Trainer INFO: Main Network Training:
# cosine score: 82.3278, l1 score: 78.5171, clip score: 24.1322, critic score: -1.9105
# reward loss: -1.1182, fD loss: 0.3956
#
# 2024-04-12 21:40:09,659 Trainer INFO: Epoch: 1, global_step: 2250
# G loss: -0.7932, D loss: 0.3126
# 2024-04-12 21:40:09,659 Trainer INFO: Main Network Training:
# cosine score: 83.4268, l1 score: 80.1767, clip score: 26.3583, critic score: -1.9456
# reward loss: -2.1956, fD loss: 0.3395
#
# 2024-04-12 21:41:08,897 Trainer INFO: Epoch: 1, global_step: 2275
# G loss: -0.6459, D loss: 0.3960
# 2024-04-12 21:41:08,897 Trainer INFO: Main Network Training:
# cosine score: 78.7383, l1 score: 77.6892, clip score: 24.2661, critic score: -2.1696
# reward loss: -1.9901, fD loss: 0.4633
#
# 2024-04-12 21:42:09,421 Trainer INFO: Epoch: 1, global_step: 2300
# G loss: -0.3774, D loss: 0.3685
# 2024-04-12 21:42:09,422 Trainer INFO: Main Network Training:
# cosine score: 82.2469, l1 score: 79.6264, clip score: 25.5274, critic score: -2.7640
# reward loss: -0.9900, fD loss: 0.1390
#
# 2024-04-12 21:43:08,164 Trainer INFO: Epoch: 1, global_step: 2325
# G loss: -0.9211, D loss: 0.3487
# 2024-04-12 21:43:08,164 Trainer INFO: Main Network Training:
# cosine score: 82.6401, l1 score: 79.2076, clip score: 25.3148, critic score: -2.6161
# reward loss: -1.8906, fD loss: -0.0860
#
# 2024-04-12 21:44:06,378 Trainer INFO: Epoch: 1, global_step: 2350
# G loss: -0.3316, D loss: 0.3664
# 2024-04-12 21:44:06,378 Trainer INFO: Main Network Training:
# cosine score: 79.3442, l1 score: 77.8366, clip score: 24.7979, critic score: -1.4425
# reward loss: -0.7649, fD loss: 0.0497
#
# 2024-04-12 21:45:04,660 Trainer INFO: Epoch: 1, global_step: 2375
# G loss: -0.4064, D loss: 0.3144
# 2024-04-12 21:45:04,661 Trainer INFO: Main Network Training:
# cosine score: 83.2012, l1 score: 79.3174, clip score: 25.7199, critic score: -2.3311
# reward loss: -0.9960, fD loss: 0.1236
#
# 2024-04-12 21:46:02,567 Trainer INFO: Epoch: 1, global_step: 2400
# G loss: -0.6303, D loss: 0.3039
# 2024-04-12 21:46:02,568 Trainer INFO: Main Network Training:
# cosine score: 82.0597, l1 score: 78.7342, clip score: 24.9910, critic score: -2.8441
# reward loss: -1.5057, fD loss: 0.1737
#
# 2024-04-12 21:47:01,193 Trainer INFO: Epoch: 1, global_step: 2425
# G loss: -0.4528, D loss: 0.3333
# 2024-04-12 21:47:01,194 Trainer INFO: Main Network Training:
# cosine score: 82.8796, l1 score: 79.7958, clip score: 24.5879, critic score: -2.7397
# reward loss: -0.7060, fD loss: -0.2152
#
# 2024-04-12 21:47:58,961 Trainer INFO: Epoch: 1, global_step: 2450
# G loss: -0.6834, D loss: 0.3101
# 2024-04-12 21:47:58,961 Trainer INFO: Main Network Training:
# cosine score: 83.9723, l1 score: 79.9488, clip score: 25.7363, critic score: -2.8612
# reward loss: -1.3394, fD loss: -0.0547
#
# 2024-04-12 21:48:57,739 Trainer INFO: Epoch: 1, global_step: 2475
# G loss: -0.5700, D loss: 0.2689
# 2024-04-12 21:48:57,739 Trainer INFO: Main Network Training:
# cosine score: 81.6674, l1 score: 78.9266, clip score: 25.6248, critic score: -2.9048
# reward loss: -1.0090, fD loss: -0.1401
#
# 2024-04-12 21:49:55,792 Trainer INFO: Epoch: 1, global_step: 2500
# G loss: -0.2992, D loss: 0.3605
# 2024-04-12 21:49:55,792 Trainer INFO: Main Network Training:
# cosine score: 84.0801, l1 score: 80.1595, clip score: 25.5262, critic score: -2.4635
# reward loss: -0.3136, fD loss: -0.2848
#
# 2024-04-12 21:50:54,194 Trainer INFO: Epoch: 1, global_step: 2525
# G loss: -0.6852, D loss: 0.2982
# 2024-04-12 21:50:54,195 Trainer INFO: Main Network Training:
# cosine score: 82.5658, l1 score: 79.5338, clip score: 25.7665, critic score: -2.0473
# reward loss: -1.5063, fD loss: 0.1359
#
# 2024-04-12 21:51:53,531 Trainer INFO: Epoch: 1, global_step: 2550
# G loss: -0.3397, D loss: 0.4355
# 2024-04-12 21:51:53,532 Trainer INFO: Main Network Training:
# cosine score: 83.8919, l1 score: 80.4473, clip score: 26.8013, critic score: -1.6772
# reward loss: -0.6146, fD loss: -0.0649
#
# 2024-04-12 21:52:52,730 Trainer INFO: Epoch: 1, global_step: 2575
# G loss: -1.1004, D loss: 0.3446
# 2024-04-12 21:52:52,731 Trainer INFO: Main Network Training:
# cosine score: 82.0607, l1 score: 79.1006, clip score: 26.0104, critic score: -2.0876
# reward loss: -2.0458, fD loss: -0.1549
#
# 2024-04-12 21:53:50,181 Trainer INFO: Epoch: 1, global_step: 2600
# G loss: -0.3036, D loss: 0.4383
# 2024-04-12 21:53:50,181 Trainer INFO: Main Network Training:
# cosine score: 82.1116, l1 score: 79.1827, clip score: 23.9674, critic score: -1.9439
# reward loss: -0.4655, fD loss: -0.1418
#
# 2024-04-12 21:54:47,906 Trainer INFO: Epoch: 1, global_step: 2625
# G loss: -0.2493, D loss: 0.2746
# 2024-04-12 21:54:47,907 Trainer INFO: Main Network Training:
# cosine score: 85.8938, l1 score: 81.1831, clip score: 25.4599, critic score: -2.5324
# reward loss: -0.8225, fD loss: 0.3238
#
# 2024-04-12 21:55:44,987 Trainer INFO: Epoch: 1, global_step: 2650
# G loss: 0.2541, D loss: 0.3101
# 2024-04-12 21:55:44,987 Trainer INFO: Main Network Training:
# cosine score: 83.8478, l1 score: 80.0847, clip score: 26.2407, critic score: -2.4332
# reward loss: 0.1897, fD loss: 0.3186
#
# 2024-04-12 21:56:42,230 Trainer INFO: Epoch: 1, global_step: 2675
# G loss: -0.6809, D loss: 0.3193
# 2024-04-12 21:56:42,231 Trainer INFO: Main Network Training:
# cosine score: 85.0299, l1 score: 80.5608, clip score: 25.8501, critic score: -2.5779
# reward loss: -1.1341, fD loss: -0.2277
#
# 2024-04-12 21:57:40,780 Trainer INFO: Epoch: 1, global_step: 2700
# G loss: -1.0772, D loss: 0.3195
# 2024-04-12 21:57:40,781 Trainer INFO: Main Network Training:
# cosine score: 80.2727, l1 score: 78.0424, clip score: 24.8376, critic score: -2.5505
# reward loss: -1.9206, fD loss: -0.2339
#
# 2024-04-12 21:58:40,029 Trainer INFO: Epoch: 1, global_step: 2725
# G loss: -0.4588, D loss: 0.3394
# 2024-04-12 21:58:40,030 Trainer INFO: Main Network Training:
# cosine score: 84.6716, l1 score: 80.0673, clip score: 25.2338, critic score: -2.6832
# reward loss: -0.6689, fD loss: -0.2487
#
# 2024-04-12 21:59:38,655 Trainer INFO: Epoch: 1, global_step: 2750
# G loss: -1.2808, D loss: 0.3664
# 2024-04-12 21:59:38,655 Trainer INFO: Main Network Training:
# cosine score: 81.1817, l1 score: 78.8696, clip score: 25.7665, critic score: -2.1940
# reward loss: -2.1531, fD loss: -0.4084
#
# 2024-04-12 22:00:37,746 Trainer INFO: Epoch: 1, global_step: 2775
# G loss: -0.5178, D loss: 0.3399
# 2024-04-12 22:00:37,747 Trainer INFO: Main Network Training:
# cosine score: 86.1953, l1 score: 81.6082, clip score: 26.2273, critic score: -3.0203
# reward loss: -1.0739, fD loss: 0.0383
#
# 2024-04-12 22:01:36,636 Trainer INFO: Epoch: 1, global_step: 2800
# G loss: -0.2344, D loss: 0.2031
# 2024-04-12 22:01:36,636 Trainer INFO: Main Network Training:
# cosine score: 86.8562, l1 score: 81.4329, clip score: 25.3719, critic score: -2.8198
# reward loss: -0.8191, fD loss: 0.3503
#
# 2024-04-12 22:02:35,217 Trainer INFO: Epoch: 1, global_step: 2825
# G loss: -0.3167, D loss: 0.3002
# 2024-04-12 22:02:35,218 Trainer INFO: Main Network Training:
# cosine score: 85.8322, l1 score: 81.5423, clip score: 26.8231, critic score: -3.3913
# reward loss: -0.5813, fD loss: -0.0520
#
# 2024-04-12 22:03:33,453 Trainer INFO: Epoch: 1, global_step: 2850
# G loss: -0.4153, D loss: 0.3240
# 2024-04-12 22:03:33,453 Trainer INFO: Main Network Training:
# cosine score: 86.1790, l1 score: 81.3537, clip score: 24.4846, critic score: -2.6131
# reward loss: -1.0652, fD loss: 0.2346
#
# 2024-04-12 22:04:34,421 Trainer INFO: Epoch: 1, global_step: 2875
# G loss: -1.1802, D loss: 0.3810
# 2024-04-12 22:04:34,422 Trainer INFO: Main Network Training:
# cosine score: 77.3438, l1 score: 76.5678, clip score: 23.1229, critic score: -2.3283
# reward loss: -2.3802, fD loss: 0.0198
#
# 2024-04-12 22:05:32,887 Trainer INFO: Epoch: 1, global_step: 2900
# G loss: -0.3515, D loss: 0.2998
# 2024-04-12 22:05:32,887 Trainer INFO: Main Network Training:
# cosine score: 81.9346, l1 score: 78.8292, clip score: 24.7421, critic score: -2.1557
# reward loss: -0.4087, fD loss: -0.2942
#
# 2024-04-12 22:06:30,610 Trainer INFO: Epoch: 1, global_step: 2925
# G loss: -1.0554, D loss: 0.2429
# 2024-04-12 22:06:30,611 Trainer INFO: Main Network Training:
# cosine score: 84.7571, l1 score: 80.9818, clip score: 25.7783, critic score: -3.0008
# reward loss: -2.3158, fD loss: 0.2050
#
# 2024-04-12 22:07:28,269 Trainer INFO: Epoch: 1, global_step: 2950
# G loss: -1.1417, D loss: 0.4077
# 2024-04-12 22:07:28,269 Trainer INFO: Main Network Training:
# cosine score: 82.5854, l1 score: 79.4408, clip score: 25.2832, critic score: -2.9829
# reward loss: -2.2026, fD loss: -0.0807
#
# 2024-04-12 22:08:26,392 Trainer INFO: Epoch: 1, global_step: 2975
# G loss: -0.6093, D loss: 0.3354
# 2024-04-12 22:08:26,392 Trainer INFO: Main Network Training:
# cosine score: 81.6058, l1 score: 78.4427, clip score: 24.9000, critic score: -2.1916
# reward loss: -1.3973, fD loss: 0.1787
#
# 2024-04-12 22:09:24,343 Trainer INFO: Epoch: 1, global_step: 3000
# G loss: -0.1723, D loss: 0.3053
# 2024-04-12 22:09:24,344 Trainer INFO: Main Network Training:
# cosine score: 80.2944, l1 score: 78.0419, clip score: 23.8842, critic score: -2.4442
# reward loss: -0.4084, fD loss: 0.0637
#
# 2024-04-12 22:10:22,586 Trainer INFO: Epoch: 1, global_step: 3025
# G loss: -0.9525, D loss: 0.3172
# 2024-04-12 22:10:22,586 Trainer INFO: Main Network Training:
# cosine score: 83.0925, l1 score: 79.7748, clip score: 25.4697, critic score: -2.7421
# reward loss: -1.5238, fD loss: -0.3812
#
# 2024-04-12 22:11:21,242 Trainer INFO: Epoch: 1, global_step: 3050
# G loss: -0.6854, D loss: 0.2627
# 2024-04-12 22:11:21,243 Trainer INFO: Main Network Training:
# cosine score: 81.8177, l1 score: 79.0912, clip score: 25.0443, critic score: -2.4265
# reward loss: -1.3752, fD loss: 0.0044
#
# 2024-04-12 22:12:18,651 Trainer INFO: Epoch: 1, global_step: 3075
# G loss: -0.3053, D loss: 0.3370
# 2024-04-12 22:12:18,652 Trainer INFO: Main Network Training:
# cosine score: 82.2480, l1 score: 79.5605, clip score: 24.2794, critic score: -3.2299
# reward loss: -0.2335, fD loss: -0.3771
#
# 2024-04-12 22:13:15,763 Trainer INFO: Epoch: 1, global_step: 3100
# G loss: -0.3919, D loss: 0.2970
# 2024-04-12 22:13:15,763 Trainer INFO: Main Network Training:
# cosine score: 83.6862, l1 score: 79.2271, clip score: 24.9295, critic score: -3.2232
# reward loss: -0.7396, fD loss: -0.0443
#
# 2024-04-12 22:14:14,662 Trainer INFO: Epoch: 1, global_step: 3125
# G loss: -0.1222, D loss: 0.3768
# 2024-04-12 22:14:14,663 Trainer INFO: Main Network Training:
# cosine score: 81.8419, l1 score: 78.9095, clip score: 25.2889, critic score: -2.7032
# reward loss: 0.0863, fD loss: -0.3307
#
# 2024-04-12 22:15:14,088 Trainer INFO: Epoch: 1, global_step: 3150
# G loss: -0.3354, D loss: 0.2528
# 2024-04-12 22:15:14,089 Trainer INFO: Main Network Training:
# cosine score: 84.5854, l1 score: 80.7718, clip score: 25.1582, critic score: -2.6673
# reward loss: -0.7695, fD loss: 0.0988
#
# 2024-04-12 22:16:13,427 Trainer INFO: Epoch: 1, global_step: 3175
# G loss: -0.5118, D loss: 0.3258
# 2024-04-12 22:16:13,428 Trainer INFO: Main Network Training:
# cosine score: 83.8023, l1 score: 80.0991, clip score: 25.2028, critic score: -2.7081
# reward loss: -1.3268, fD loss: 0.3033
#
# 2024-04-12 22:17:12,701 Trainer INFO: Epoch: 1, global_step: 3200
# G loss: 0.2575, D loss: 0.2208
# 2024-04-12 22:17:12,702 Trainer INFO: Main Network Training:
# cosine score: 83.4485, l1 score: 79.7911, clip score: 25.2137, critic score: -3.0299
# reward loss: 0.1122, fD loss: 0.4027
#
# 2024-04-12 22:18:10,833 Trainer INFO: Epoch: 1, global_step: 3225
# G loss: -0.7975, D loss: 0.2866
# 2024-04-12 22:18:10,833 Trainer INFO: Main Network Training:
# cosine score: 83.4453, l1 score: 79.1475, clip score: 24.2413, critic score: -2.6061
# reward loss: -1.5458, fD loss: -0.0492
#
# 2024-04-12 22:19:07,002 Trainer INFO: Epoch: 1, global_step: 3250
# G loss: -0.9540, D loss: 0.2335
# 2024-04-12 22:19:07,003 Trainer INFO: Main Network Training:
# cosine score: 84.6088, l1 score: 80.4030, clip score: 26.2750, critic score: -3.8771
# reward loss: -1.8698, fD loss: -0.0383
#
# 2024-04-12 22:20:05,329 Trainer INFO: Epoch: 1, global_step: 3275
# G loss: -0.6741, D loss: 0.2811
# 2024-04-12 22:20:05,330 Trainer INFO: Main Network Training:
# cosine score: 82.4697, l1 score: 79.2398, clip score: 25.1963, critic score: -2.6942
# reward loss: -1.4093, fD loss: 0.0611
#
# 2024-04-12 22:21:05,096 Trainer INFO: Epoch: 1, global_step: 3300
# G loss: -0.2148, D loss: 0.3526
# 2024-04-12 22:21:05,097 Trainer INFO: Main Network Training:
# cosine score: 85.8504, l1 score: 81.5087, clip score: 26.0738, critic score: -2.2335
# reward loss: -0.4620, fD loss: 0.0323
#
# 2024-04-12 22:22:03,372 Trainer INFO: Epoch: 1, global_step: 3325
# G loss: -0.2998, D loss: 0.2761
# 2024-04-12 22:22:03,372 Trainer INFO: Main Network Training:
# cosine score: 82.3239, l1 score: 79.1960, clip score: 24.3234, critic score: -2.8753
# reward loss: -0.5008, fD loss: -0.0988
#
# 2024-04-12 22:23:00,769 Trainer INFO: Epoch: 1, global_step: 3350
# G loss: -0.2410, D loss: 0.3784
# 2024-04-12 22:23:00,770 Trainer INFO: Main Network Training:
# cosine score: 83.8797, l1 score: 80.1151, clip score: 25.9558, critic score: -2.1343
# reward loss: -0.8435, fD loss: 0.3615
#
# 2024-04-12 22:23:58,811 Trainer INFO: Epoch: 1, global_step: 3375
# G loss: -0.2768, D loss: 0.2250
# 2024-04-12 22:23:58,812 Trainer INFO: Main Network Training:
# cosine score: 84.8286, l1 score: 80.6280, clip score: 25.3423, critic score: -2.9286
# reward loss: -0.6103, fD loss: 0.0567
#
# 2024-04-12 22:24:57,526 Trainer INFO: Epoch: 1, global_step: 3400
# G loss: -0.0546, D loss: 0.2473
# 2024-04-12 22:24:57,526 Trainer INFO: Main Network Training:
# ...
# 2024-04-13 05:09:14,044 Trainer INFO: Main Network Training:
# cosine score: 84.9656, l1 score: 80.3978, clip score: 25.6178, critic score: -2.6360
# reward loss: -1.2130, fD loss: -0.4779
#
# 2024-04-13 05:10:12,293 Trainer INFO: Epoch: 4, global_step: 13400
# G loss: -0.4109, D loss: 0.2450
# 2024-04-13 05:10:12,293 Trainer INFO: Main Network Training:
# cosine score: 84.8101, l1 score: 80.3484, clip score: 24.9492, critic score: -2.5381
# reward loss: -0.4564, fD loss: -0.3654
#
# 2024-04-13 05:11:09,778 Trainer INFO: Epoch: 4, global_step: 13425
# G loss: -0.1584, D loss: 0.2206
# 2024-04-13 05:11:09,779 Trainer INFO: Main Network Training:
# cosine score: 86.6139, l1 score: 81.4923, clip score: 26.1433, critic score: -2.8715
# reward loss: -0.3689, fD loss: 0.0520
#
# 2024-04-13 05:12:07,847 Trainer INFO: Epoch: 4, global_step: 13450
# G loss: -0.1203, D loss: 0.3852
# 2024-04-13 05:12:07,848 Trainer INFO: Main Network Training:
# cosine score: 82.8598, l1 score: 78.9860, clip score: 24.9539, critic score: -1.6495
# reward loss: -0.3772, fD loss: 0.1366
#
# 2024-04-13 05:13:04,950 Trainer INFO: Epoch: 4, global_step: 13475
# G loss: -0.2951, D loss: 0.2385
# 2024-04-13 05:13:04,951 Trainer INFO: Main Network Training:
# cosine score: 87.1533, l1 score: 82.0523, clip score: 26.5278, critic score: -2.8620
# reward loss: -0.6723, fD loss: 0.0821
#
# 2024-04-13 05:14:02,416 Trainer INFO: Epoch: 4, global_step: 13500
# G loss: 0.1058, D loss: 0.3492
# 2024-04-13 05:14:02,417 Trainer INFO: Main Network Training:
# cosine score: 85.2680, l1 score: 80.2271, clip score: 26.0266, critic score: -2.4972
# reward loss: -0.1672, fD loss: 0.3787
#
# 2024-04-13 05:15:00,768 Trainer INFO: Epoch: 4, global_step: 13525
# G loss: -0.0471, D loss: 0.2371
# 2024-04-13 05:15:00,768 Trainer INFO: Main Network Training:
# cosine score: 87.5405, l1 score: 82.1550, clip score: 26.5256, critic score: -2.4399
# reward loss: -0.1901, fD loss: 0.0960
#
# 2024-04-13 05:15:58,665 Trainer INFO: Epoch: 4, global_step: 13550
# G loss: -0.3365, D loss: 0.2877
# 2024-04-13 05:15:58,665 Trainer INFO: Main Network Training:
# cosine score: 86.3185, l1 score: 81.9691, clip score: 26.2429, critic score: -3.1928
# reward loss: -1.0429, fD loss: 0.3700
#
# 2024-04-13 05:16:55,203 Trainer INFO: Epoch: 4, global_step: 13575
# G loss: 0.0929, D loss: 0.3190
# 2024-04-13 05:16:55,204 Trainer INFO: Main Network Training:
# cosine score: 84.3106, l1 score: 80.2395, clip score: 26.6855, critic score: -2.4319
# reward loss: -0.2983, fD loss: 0.4841
#
# 2024-04-13 05:17:52,533 Trainer INFO: Epoch: 4, global_step: 13600
# G loss: 0.0689, D loss: 0.2437
# 2024-04-13 05:17:52,534 Trainer INFO: Main Network Training:
# cosine score: 89.3589, l1 score: 83.1268, clip score: 27.1712, critic score: -2.5524
# reward loss: 0.0309, fD loss: 0.1069
#
# 2024-04-13 05:18:48,953 Trainer INFO: Epoch: 4, global_step: 13625
# G loss: 0.0971, D loss: 0.3259
# 2024-04-13 05:18:48,954 Trainer INFO: Main Network Training:
# cosine score: 82.1643, l1 score: 79.0173, clip score: 26.4135, critic score: -2.5023
# reward loss: 0.0368, fD loss: 0.1573
#
# 2024-04-13 05:19:47,227 Trainer INFO: Epoch: 4, global_step: 13650
# G loss: -0.2517, D loss: 0.2031
# 2024-04-13 05:19:47,227 Trainer INFO: Main Network Training:
# cosine score: 88.4336, l1 score: 82.7599, clip score: 25.8000, critic score: -2.6276
# reward loss: -0.4689, fD loss: -0.0344
#
# 2024-04-13 05:20:45,446 Trainer INFO: Epoch: 4, global_step: 13675
# G loss: -0.2732, D loss: 0.2097
# 2024-04-13 05:20:45,447 Trainer INFO: Main Network Training:
# cosine score: 80.7268, l1 score: 78.6970, clip score: 25.2136, critic score: -2.7225
# reward loss: -0.5265, fD loss: -0.0199
#
# 2024-04-13 05:21:43,217 Trainer INFO: Epoch: 4, global_step: 13700
# G loss: 0.0002, D loss: 0.3200
# 2024-04-13 05:21:43,218 Trainer INFO: Main Network Training:
# cosine score: 84.0747, l1 score: 79.8776, clip score: 25.4459, critic score: -2.2856
# reward loss: -0.1932, fD loss: 0.1935
#
# 2024-04-13 05:22:42,533 Trainer INFO: Epoch: 4, global_step: 13725
# G loss: -0.3109, D loss: 0.2262
# 2024-04-13 05:22:42,534 Trainer INFO: Main Network Training:
# cosine score: 90.1795, l1 score: 84.0482, clip score: 26.1233, critic score: -2.6685
# reward loss: -0.6130, fD loss: -0.0088
#
# 2024-04-13 05:23:40,331 Trainer INFO: Epoch: 4, global_step: 13750
# G loss: -0.4355, D loss: 0.3639
# 2024-04-13 05:23:40,332 Trainer INFO: Main Network Training:
# cosine score: 84.7932, l1 score: 80.0758, clip score: 24.5861, critic score: -2.3557
# reward loss: -0.8985, fD loss: 0.0276
#
# 2024-04-13 05:24:37,711 Trainer INFO: Epoch: 4, global_step: 13775
# G loss: -0.3030, D loss: 0.2055
# 2024-04-13 05:24:37,712 Trainer INFO: Main Network Training:
# cosine score: 87.3844, l1 score: 82.5184, clip score: 26.7816, critic score: -3.2209
# reward loss: -0.8467, fD loss: 0.2408
#
# 2024-04-13 05:25:34,748 Trainer INFO: Epoch: 4, global_step: 13800
# G loss: -0.1932, D loss: 0.2500
# 2024-04-13 05:25:34,749 Trainer INFO: Main Network Training:
# cosine score: 90.7833, l1 score: 84.1637, clip score: 26.7086, critic score: -3.1772
# reward loss: -0.5223, fD loss: 0.1358
#
# 2024-04-13 05:26:33,887 Trainer INFO: Epoch: 4, global_step: 13825
# G loss: -0.3442, D loss: 0.3044
# 2024-04-13 05:26:33,888 Trainer INFO: Main Network Training:
# cosine score: 83.1822, l1 score: 79.6669, clip score: 25.9575, critic score: -2.5964
# reward loss: -0.7388, fD loss: 0.0504
#
# 2024-04-13 05:27:31,997 Trainer INFO: Epoch: 4, global_step: 13850
# G loss: 0.0867, D loss: 0.2637
# 2024-04-13 05:27:31,997 Trainer INFO: Main Network Training:
# cosine score: 86.9075, l1 score: 81.4007, clip score: 25.8852, critic score: -2.9805
# reward loss: 0.4877, fD loss: -0.3142
#
# 2024-04-13 05:28:29,051 Trainer INFO: Epoch: 4, global_step: 13875
# G loss: -0.3478, D loss: 0.2462
# 2024-04-13 05:28:29,052 Trainer INFO: Main Network Training:
# cosine score: 85.5575, l1 score: 80.9748, clip score: 25.5320, critic score: -3.2183
# reward loss: -0.5749, fD loss: -0.1208
#
# 2024-04-13 05:29:27,463 Trainer INFO: Epoch: 4, global_step: 13900
# G loss: -0.4922, D loss: 0.2919
# 2024-04-13 05:29:27,464 Trainer INFO: Main Network Training:
# cosine score: 81.2495, l1 score: 78.8263, clip score: 24.9557, critic score: -2.5638
# reward loss: -0.7411, fD loss: -0.2433
#
# 2024-04-13 05:30:26,820 Trainer INFO: Epoch: 4, global_step: 13925
# G loss: -0.3459, D loss: 0.2953
# 2024-04-13 05:30:26,821 Trainer INFO: Main Network Training:
# cosine score: 86.7964, l1 score: 81.6036, clip score: 27.0530, critic score: -2.8761
# reward loss: -0.6961, fD loss: 0.0044
#
# 2024-04-13 05:31:24,886 Trainer INFO: Epoch: 4, global_step: 13950
# G loss: -0.4450, D loss: 0.2730
# 2024-04-13 05:31:24,887 Trainer INFO: Main Network Training:
# cosine score: 87.5008, l1 score: 81.8235, clip score: 25.7292, critic score: -2.5997
# reward loss: -1.1985, fD loss: 0.3084
#
# 2024-04-13 05:32:21,647 Trainer INFO: Epoch: 4, global_step: 13975
# G loss: -0.2355, D loss: 0.2659
# 2024-04-13 05:32:21,648 Trainer INFO: Main Network Training:
# cosine score: 83.0558, l1 score: 79.9995, clip score: 24.9814, critic score: -2.8075
# reward loss: -0.4894, fD loss: 0.0184
#
# 2024-04-13 05:33:19,202 Trainer INFO: Epoch: 4, global_step: 14000
# G loss: -0.4173, D loss: 0.2551
# 2024-04-13 05:33:19,202 Trainer INFO: Main Network Training:
# cosine score: 86.5594, l1 score: 81.9491, clip score: 25.2680, critic score: -3.3901
# reward loss: -0.5657, fD loss: -0.2690
#
# 2024-04-13 05:34:15,910 Trainer INFO: Epoch: 4, global_step: 14025
# G loss: -0.5214, D loss: 0.3210
# 2024-04-13 05:34:15,911 Trainer INFO: Main Network Training:
# cosine score: 88.0703, l1 score: 81.9255, clip score: 25.2457, critic score: -2.7171
# reward loss: -0.9660, fD loss: -0.0768
#
# 2024-04-13 05:35:13,804 Trainer INFO: Epoch: 4, global_step: 14050
# G loss: -0.2548, D loss: 0.2159
# 2024-04-13 05:35:13,804 Trainer INFO: Main Network Training:
# cosine score: 90.0453, l1 score: 83.1836, clip score: 26.2367, critic score: -2.7110
# reward loss: -0.7193, fD loss: 0.2097
#
# 2024-04-13 05:36:12,535 Trainer INFO: Epoch: 4, global_step: 14075
# G loss: 0.1162, D loss: 0.2214
# 2024-04-13 05:36:12,537 Trainer INFO: Main Network Training:
# cosine score: 83.5193, l1 score: 80.1016, clip score: 26.8459, critic score: -2.9369
# reward loss: 0.1576, fD loss: 0.0748
#
# 2024-04-13 05:37:10,064 Trainer INFO: Epoch: 4, global_step: 14100
# G loss: 0.1327, D loss: 0.2402
# 2024-04-13 05:37:10,065 Trainer INFO: Main Network Training:
# cosine score: 87.2503, l1 score: 81.0741, clip score: 25.4756, critic score: -2.7969
# reward loss: 0.0512, fD loss: 0.2142
#
# 2024-04-13 05:38:07,166 Trainer INFO: Epoch: 4, global_step: 14125
# G loss: -0.4226, D loss: 0.2952
# 2024-04-13 05:38:07,167 Trainer INFO: Main Network Training:
# cosine score: 86.7958, l1 score: 81.3842, clip score: 25.3113, critic score: -2.4983
# reward loss: -0.3969, fD loss: -0.4483
#
# 2024-04-13 05:39:03,534 Trainer INFO: Epoch: 4, global_step: 14150
# G loss: -0.1830, D loss: 0.2857
# 2024-04-13 05:39:03,535 Trainer INFO: Main Network Training:
# cosine score: 85.6114, l1 score: 81.0652, clip score: 26.3548, critic score: -2.6176
# reward loss: -0.2662, fD loss: -0.0998
#
# 2024-04-13 05:39:28,724 Trainer INFO: Save checkpoint to /kaggle/working/output/checkpoint
# 2024-04-13 05:39:28,725 Trainer INFO: Epoch 4 training finish. Performing evaluation
# 2024-04-13 05:40:03,000 Trainer INFO: Inference model computing time: 0.20268664238559211 seconds per batch
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 307821 tokens at 509918.19 tokens per second.
# PTBTokenizer tokenized 58424 tokens at 188284.89 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 48180, 'reflen': 47799, 'guess': [48180, 43180, 38180, 33180], 'correct': [34708, 16951, 7053, 2825]}
# ratio: 1.007970878051821
# Bleu_1: 0.720
# Bleu_2: 0.532
# Bleu_3: 0.374
# Bleu_4: 0.258
# computing METEOR score...
# METEOR: 0.254
# computing Rouge score...
# ROUGE_L: 0.516
# computing CIDEr score...
# CIDEr: 0.965
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/opt/conda/lib/python3.10/site-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.9 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.9 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# Threads( StanfordCoreNLP ) [01:22.459 minutes]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 1.692 min
# SPICE: 0.186
# 2024-04-13 05:42:18,482 Trainer INFO: evaluation result: {'Bleu_1': 0.7203819012038041, 'Bleu_2': 0.5317870282640915, 'Bleu_3': 0.37382741382812484, 'Bleu_4': 0.2582491360575901, 'METEOR': 0.2538641267299962, 'ROUGE_L': 0.51602397857316, 'CIDEr': 0.9647718280806088, 'SPICE': 0.18641624287104616}
#
# 2024-04-13 05:42:18,483 Trainer INFO: epoch: 4, best cider: 0.9647718280806088
# 2024-04-13 05:42:19,950 Trainer INFO: Save checkpoint to /kaggle/working/output/best
# 2024-04-13 05:42:19,951 Trainer INFO: average cos score: [78.45201876257772, 84.74623252523821, 85.61458424067094, 86.0906861795544]
#  average l1 score: [77.48601283596061, 80.54135290242859, 81.01062339093052, 81.27088533175194]
#  average clip score: [24.235511587433894, 25.62399567156862, 25.840088086209054, 25.96583988329785]
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# 2024-04-13 05:42:31,530 Trainer INFO: Testing best checkpoint
# 2024-04-13 05:42:31,531 Trainer INFO: loading generator from /kaggle/working/output/best/model.pt
# 2024-04-13 05:43:05,127 Trainer INFO: Inference model computing time: 0.19605312985219772 seconds per batch
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 307086 tokens at 501933.33 tokens per second.
# PTBTokenizer tokenized 58413 tokens at 185131.01 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 48198, 'reflen': 47891, 'guess': [48198, 43198, 38198, 33198], 'correct': [34551, 16800, 7109, 2988]}
# ratio: 1.0064103902611972
# Bleu_1: 0.717
# Bleu_2: 0.528
# Bleu_3: 0.373
# Bleu_4: 0.261
# computing METEOR score...
# METEOR: 0.252
# computing Rouge score...
# ROUGE_L: 0.512
# computing CIDEr score...
# CIDEr: 0.969
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/opt/conda/lib/python3.10/site-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.9 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.0 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# Threads( StanfordCoreNLP ) [03:53.112 minutes]
# Threads( StanfordCoreNLP ) [03:32.337 minutes]
# Threads( StanfordCoreNLP ) [01:35.411 minutes]
# Parsing test captions
# Threads( StanfordCoreNLP ) [01:08.831 minutes]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 10.59 min
# SPICE: 0.189
# 2024-04-13 05:54:14,787 Trainer INFO: Evaluation results : {'Bleu_1': 0.716855471181362, 'Bleu_2': 0.5280057145786226, 'Bleu_3': 0.3729767083945522, 'Bleu_4': 0.2614137649991376, 'METEOR': 0.25208445612190367, 'ROUGE_L': 0.5115443461034846, 'CIDEr': 0.9687550605892964, 'SPICE': 0.18869971309636843}

# %%
# !nvidia-smi
# Out:
# Sat Apr 13 05:54:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  Tesla T4                       Off | 00000000:00:05.0 Off |                    0 |
# | N/A   59C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
import zipfile
from IPython.display import FileLink
from tqdm import tqdm

def zip_and_display(folder_path, zip_file_name):
    """
    Zip a folder and display the link to the zipped file.

    Parameters:
    - folder_path (str): Path to the folder to be zipped.
    - zip_file_name (str): Name of the zip file to be created.

    Returns:
    - None
    """
    zip_file_path = os.path.join(os.path.dirname(folder_path), zip_file_name)
    
    # Get total number of files for tqdm
    total_files = sum(len(files) for _, _, files in os.walk(folder_path))
    
    # Create a ZipFile object
    with zipfile.ZipFile(zip_file_path, 'w') as zipf:
        # Walk through all files and folders in the given directory
        for root, _, files in tqdm(os.walk(folder_path), total=total_files, desc='Zipping files'):
            for file in files:
                file_path = os.path.join(root, file)
                # Add the file to the zip archive
                zipf.write(file_path, os.path.relpath(file_path, folder_path))
    
    # Display the link to the zipped file
    display(FileLink(zip_file_name))

# %%
zip_and_display('/kaggle/working/output', 'cgt-gan-epoch-1.zip')
# Out:
# Zipping files:  38%|███▊      | 3/8 [00:03<00:05,  1.11s/it]
# /kaggle/working/cgt-gan-epoch-1.zip
