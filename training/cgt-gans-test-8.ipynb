# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install ftfy
# !pip install huggingface-hub==0.16.4
# !pip install matplotlib 
# !pip install numpy==1.23.5
# !pip install Pillow
# !pip install pycocoevalcap==1.2
# !pip install pycocotools==2.0.6
# !pip install requests
# !pip install scikit-image==0.18.1
# !pip install scipy
# !pip install six
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 
# !pip install tqdm
# !pip install transformers==4.27.4
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-xni6em6b
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-xni6em6b
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
# done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from clip==1.0) (0.16.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->clip==1.0) (2024.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->clip==1.0) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->clip==1.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.3 MB/s eta 0:00:00
# Building wheels for collected packages: clip
# done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=ae7cca5203989207170534f0d1ca1b6431b6a1ee347429b6a58783e6f5ae1361
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wt4pp7o_/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.2.0
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.10/site-packages (6.2.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy) (0.2.13)
# Collecting huggingface-hub==0.16.4
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (3.13.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub==0.16.4) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub==0.16.4) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub==0.16.4) (2024.2.2)
# Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.22.2
#     Uninstalling huggingface-hub-0.22.2:
#       Successfully uninstalled huggingface-hub-0.22.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.18.0 requires huggingface-hub>=0.19.4, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.39.3 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# Successfully installed huggingface-hub-0.16.4
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 77.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-nlp 0.8.2 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# datasets 2.18.0 requires huggingface-hub>=0.19.4, but you have huggingface-hub 0.16.4 which is incompatible.
# featuretools 1.30.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.0 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.1.1 which is incompatible.
# tensorstore 0.1.56 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# transformers 4.39.3 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# woodwork 0.29.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.3.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# Successfully installed numpy-1.23.5
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Collecting pycocoevalcap==1.2
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pycocotools>=2.0.2 (from pycocoevalcap==1.2)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.16.0)
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 16.2 MB/s eta 0:00:00
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 20.6 MB/s eta 0:00:00
# Installing collected packages: pycocotools, pycocoevalcap
# Successfully installed pycocoevalcap-1.2 pycocotools-2.0.7
# Collecting pycocotools==2.0.6
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
# done
# done
# done
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools==2.0.6) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools==2.0.6) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0.6) (1.16.0)
# Building wheels for collected packages: pycocotools
# done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl size=109338 sha256=2ddf13af7ae7c39940754f7891017fe534a531becb5b39bbf3017603606f4748
#   Stored in directory: /root/.cache/pip/wheels/58/e6/f9/f87c8f8be098b51b616871315318329cae12cdb618f4caac93
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0.6
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
# Collecting scikit-image==0.18.1
#   Downloading scikit-image-0.18.1.tar.gz (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 55.6 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.23.5)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.11.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (3.7.5)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (9.5.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (2.33.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image==0.18.1) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1) (1.16.0)
# Building wheels for collected packages: scikit-image
# done
#   Created wheel for scikit-image: filename=scikit_image-0.18.1-cp310-cp310-linux_x86_64.whl size=13943038 sha256=3c957857ba99de41ee7b565f7f8e4725da519c58f87772fdca80d60b204d1c19
#   Stored in directory: /root/.cache/pip/wheels/f7/a4/9c/45bb6974dbba881f9fe338541ad8349705deeb5942928ff243
# Successfully built scikit-image
# Installing collected packages: scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.22.0
#     Uninstalling scikit-image-0.22.0:
#       Successfully uninstalled scikit-image-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.18.1 which is incompatible.
# Successfully installed scikit-image-0.18.1
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.23.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (1.16.0)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Collecting transformers==4.27.4
#   Downloading transformers-4.27.4-py3-none-any.whl.metadata (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.4)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.27.4) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.4) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.4) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.27.4) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.27.4) (2024.2.2)
# Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 72.4 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.4 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.27.4 which is incompatible.
# Successfully installed tokenizers-0.13.3 transformers-4.27.4

# %%
# !mkdir data
# !mkdir data/coco

# %%
import requests
from tqdm import tqdm
import zipfile
import os

url = "https://drive.google.com/uc?export=download&id=1Noa8Bcw6it_ui2rFUhmtxugC2pQ648dH"
file_name = "./data/coco/annotations.zip"
extracted_folder = "./data/coco/"

response = requests.get(url, stream=True)

if response.status_code == 200:
    total_size = int(response.headers.get('content-length', 0))
    with open(file_name, 'wb') as f, tqdm(
        total=total_size, unit='B', unit_scale=True, desc=file_name, ncols=100) as pbar:
        for data in response.iter_content(chunk_size=1024):
            f.write(data)
            pbar.update(len(data))
    print("File downloaded successfully.")

    # Unzip the downloaded file
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder)
    print("File extracted successfully.")
    
    # Delete the downloaded zip file
    os.remove(file_name)
    print("Temporary zip file removed.")
    
else:
    print("Failed to download the file. Status code:", response.status_code)
# Out:
# ./data/coco/annotations.zip: 100%|█████████████████████████████| 16.5M/16.5M [00:00<00:00, 46.9MB/s]
# File downloaded successfully.
# File extracted successfully.
# Temporary zip file removed.

# %%
import requests
from tqdm import tqdm
import zipfile
import os

url = "https://drive.google.com/uc?export=download&id=1vhPZSyHyUPL3gSFdNAXXzfya_MfWn6xT"
file_name = "./CgtGAN-main.zip"
extracted_folder = "./CgtGAN-main"

response = requests.get(url, stream=True)

if response.status_code == 200:
    total_size = int(response.headers.get('content-length', 0))
    with open(file_name, 'wb') as f, tqdm(
        total=total_size, unit='B', unit_scale=True, desc=file_name, ncols=100) as pbar:
        for data in response.iter_content(chunk_size=1024):
            f.write(data)
            pbar.update(len(data))
    print("File downloaded successfully.")

    # Unzip the downloaded file
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder)
    print("File extracted successfully.")
    
    # Delete the downloaded zip file
    os.remove(file_name)
    print("Temporary zip file removed.")
    
else:
    print("Failed to download the file. Status code:", response.status_code)
# Out:
# ./CgtGAN-main.zip: 100%|███████████████████████████████████████| 16.6M/16.6M [00:00<00:00, 37.1MB/s]
# File downloaded successfully.
# File extracted successfully.
# Temporary zip file removed.

# %%
# !cp -r /kaggle/input/clip-embedding-cgt-gans /kaggle/working/data

# %%
# !python /kaggle/working/CgtGAN-main/CgtGAN-main/preprocess/coco/coco_train_captions.py

# %%
# !python /kaggle/working/CgtGAN-main/CgtGAN-main/preprocess/generate_embeddings.py --image_pkl /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_train_images.pkl --caption_pkl /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_train_captions.pkl --image_dataset coco --caption_corpus coco --t 100

# %%
# python initialization.py --output_dir path/to/save/folder --data ./data/external/gcc_ViT-L_14_external_captions.pkl

# %%
# !mkdir output

# %%
# !ls /kaggle/working/data/clip-embedding-cgt-gans
# Out:
# coco_ViT-L_14_test.pkl		  coco_images_coco_captions_ViT-L_14_100.pkl
# coco_ViT-L_14_train_captions.pkl  coco_train_sentences.pkl
# coco_ViT-L_14_train_images.pkl	  model.pt
# coco_ViT-L_14_val.pkl		  model_epoch4.pt

# %%
# %%writefile /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py

import argparse
from cProfile import label
from tkinter import image_names
from typing import OrderedDict, Tuple, Optional, Union, overload
import torch
from torch.nn import functional as nnf
import os
import os.path as op
from utils.logger import setup_logger
from utils.misc import mkdir, set_seed
from models import ClipCaptionModel, MLP, Mapping_Network
from models import ClipCocoDatasetImageWise, ClipCocoDatasetCaptionWise, TextFeatures, PairsFeatures
from models import ScstRewardCLIPCriterion
from models import RobertaDiscriminator
from transformers import AdamW, get_linear_schedule_with_warmup, get_constant_schedule_with_warmup
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import sys
import json
from tqdm import tqdm
from utils.distributional_utils import json_writer, concat_json_files, delete_json_files
import time
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap
from utils.distributional_utils import get_rank, is_main_process, synchronize, ensure_init_process_group, get_world_size
from enum import Enum
from run_inference import evalation
import gc
import random
import numpy as np



# make dataloader
def make_data_sampler(dataset, shuffle, distributed):
    if distributed:
        return torch.utils.data.distributed.DistributedSampler(dataset, shuffle=shuffle)
    if shuffle:
        sampler = torch.utils.data.sampler.RandomSampler(dataset)
    else:
        sampler = torch.utils.data.sampler.SequentialSampler(dataset)
    return sampler

def make_data_loader(args, mode, is_distributed=True, is_train=True):
    if mode == "train":
        shuffle = True
        # Main Generator dataloader
        image_dataset = PairsFeatures(args.data_train)

        images_per_gpu = args.batch_size
        images_per_batch = images_per_gpu * get_world_size()
        iters_per_batch = len(image_dataset) // images_per_batch
        num_iters = iters_per_batch * args.epochs

        image_sampler = make_data_sampler(image_dataset, shuffle, is_distributed)

        image_dataloader = torch.utils.data.DataLoader(
            image_dataset, num_workers=args.num_workers, sampler=image_sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )

        # Main Discriminator dataloader
        text_dataset = TextFeatures(args.train_sample_n, args.text_corpus,
                                      args.max_gen_length, args.discriminator_type)

        text_sampler = make_data_sampler(text_dataset, shuffle, is_distributed)

        text_dataloader = torch.utils.data.DataLoader(
            text_dataset, num_workers=args.num_workers, sampler=text_sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )

        # log info
        logger.info("Train with {} images per GPU.".format(images_per_gpu))
        logger.info("Total batch size {}".format(images_per_batch))
        logger.info("Total training steps {}".format(num_iters))
        logger.info("load without concate")
        return image_dataloader, text_dataloader

    else:
        # TODO: tensorize and tokenize caption
        if mode == "val":
            dataset = ClipCocoDatasetImageWise(args.gt_val, args.data_val, args.prefix_length,
                                               normalize_prefix=args.normalize_prefix, mode="val")
        elif mode == "test":
            dataset = ClipCocoDatasetImageWise(args.gt_test, args.data_test, args.prefix_length,
                                               normalize_prefix=args.normalize_prefix, mode="test")
        else:
            raise ValueError

        shuffle = False
        images_per_gpu = args.batch_size

        sampler = make_data_sampler(dataset, shuffle, is_distributed)
        data_loader = torch.utils.data.DataLoader(
            dataset, num_workers=args.num_workers, sampler=sampler,
            batch_size=images_per_gpu,
            pin_memory=True, drop_last=True if mode == 'train' else False,
        )
        return data_loader

# do train

def generate_with_baseline(args, img_feats, model, tokenizer):
    inputs = {
        'img_feats': img_feats,
        'do_sample': False,
        # hyperparameters of beam search
        'max_length': args.max_gen_length,
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "repetition_penalty": args.repetition_penalty,
        "length_penalty": args.length_penalty,
        "num_return_sequences": 1,
        "num_keep_best": 1,
        "eos_token": args.eos_token,
        "is_decode": True
    }

    def _ids_to_captions(all_ids):
        captions = []
        for ids in all_ids:
            c = tokenizer.decode(ids.tolist(), skip_special_tokens=True)
            captions.append(c)
        return captions

    if args.sc_baseline_type == 'greedy':
        model.eval()
        with torch.no_grad():
            greedy_res_raw, _ = model(**inputs)
            greedy_res_raw.squeeze_(1)  # batch_size * max_len
        greedy_res = _ids_to_captions(greedy_res_raw)
    else:
        greedy_res = None

    model.train()
    inputs['do_sample'] = True
    inputs['num_return_sequences'] = args.train_sample_n
    sample_res_raw, sample_logprobs = model(**inputs)
    sample_res_raw.squeeze_(1)
    sample_logprobs.squeeze_(1)
    assert sample_logprobs.requires_grad == True
    assert sample_res_raw.requires_grad == False
    sample_res = _ids_to_captions(sample_res_raw)

    # gt_res = [train_dataloader.dataset.get_captions_by_key(k) for k in img_keys]
    return greedy_res, sample_res, sample_logprobs

def save_checkpoint(model, args, save_type, epoch=0, step=0, num_trial=10):
    if save_type == 'checkpoint':
        checkpoint_dir = op.join(args.output_dir, 'checkpoint')
    elif save_type == 'best_model':
        checkpoint_dir = op.join(args.output_dir, 'best')

    if not is_main_process():
        return checkpoint_dir
    mkdir(checkpoint_dir)
    # model.module is the model self of DDP distributional setting
    model_to_save = model.module if hasattr(model, 'module') else model
    for i in range(num_trial):
        try:
            torch.save(
                model_to_save.state_dict(),
                op.join(checkpoint_dir, "model.pt"),
            )
            logger.info("Save checkpoint to {}".format(checkpoint_dir))
            break
        except:
            pass
    else:
        logger.info("Failed to save checkpoint after {} trails.".format(num_trial))
    return checkpoint_dir

def train(image_dataloader, text_dataloader, val_dataloader, generator, discriminator, args ,local_rank):
    if args.distributed:
        generator = torch.nn.parallel.DistributedDataParallel(
            generator, device_ids=[local_rank],
            output_device=local_rank,
            find_unused_parameters=True,
        )
        discriminator = torch.nn.parallel.DistributedDataParallel(
            discriminator, device_ids=[local_rank],
            output_device=local_rank,
            find_unused_parameters=True,
        )

    t_total = len(image_dataloader) // args.gradient_accumulation_steps \
                  * args.epochs

    no_decay = ['bias', 'LayerNorm.weight']

    gp_G = [
        {'params': [p for n, p in generator.named_parameters() if not \
            any(nd in n for nd in no_decay)], 'weight_decay': args.weight_decay},
        {'params': [p for n, p in generator.named_parameters() if \
                    any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
    gp_D = [
        {'params': [p for n, p in discriminator.named_parameters() if not \
            any(nd in n for nd in no_decay)], 'weight_decay': args.weight_decay},
        {'params': [p for n, p in discriminator.named_parameters() if \
                    any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]

    optimizer_G = AdamW(gp_G, lr=args.learning_rate, eps=args.adam_epsilon)
    optimizer_D = AdamW(gp_D, lr=args.learning_rate, eps=args.adam_epsilon)

    if args.scheduler == "constant":
        scheduler_G = get_constant_schedule_with_warmup(
            optimizer_G, num_warmup_steps=args.warmup_steps)
        scheduler_D = get_constant_schedule_with_warmup(
            optimizer_D, num_warmup_steps=0)

    elif args.scheduler == "linear":
        scheduler_G = get_linear_schedule_with_warmup(
            optimizer_G, num_warmup_steps=args.warmup_steps, num_training_steps=t_total)
        scheduler_D = get_linear_schedule_with_warmup(
            optimizer_D, num_warmup_steps=0, num_training_steps=t_total)

    else:
        raise ValueError("Unknown scheduler type: {}".format(args.scheduler))

    optimizer_G.zero_grad()
    optimizer_D.zero_grad()

    logger.info("***** Running training *****")
    logger.info("  Epoch number = %d", args.epochs)
    logger.info("  Batch size per GPU = %d", args.batch_size)
    logger.info("  Total train batch size (w. parallel, & accumulation) = %d",
                args.batch_size * get_world_size() * args.gradient_accumulation_steps)
    logger.info("  Gradient Accumulation steps = %d", args.gradient_accumulation_steps)
    logger.info("  Total optimization steps = %d", t_total)

    scst_criterion_CLIP = ScstRewardCLIPCriterion(
        args=args,
        baseline_type=args.sc_baseline_type,
    )

    logger.info("SCST training... ")

    global_step = 0
    best_score = 0.0

    cos_list = []
    l1_list = []
    clip_list = []

    epoch_steps = len(image_dataloader) // args.gradient_accumulation_steps

    if args.distributed:
        tokenizer = generator.module.tokenizer
        pad_and_token = discriminator.module.pad_and_token
        PG_loss = discriminator.module.PG_loss
        get_critic_score = discriminator.module.get_score
    else:
        tokenizer = generator.tokenizer
        pad_and_token = discriminator.pad_and_token
        PG_loss = discriminator.PG_loss
        get_critic_score = discriminator.get_score

    for epoch in range(int(args.epochs)):
        if args.distributed:
            image_dataloader.sampler.set_epoch(epoch)
            text_dataloader.sampler.set_epoch(epoch)

        it_text = iter(text_dataloader)

        cos_total = 0.
        l1_total = 0.
        clip_total = 0.

        for step, (image_feats, text_feats) in enumerate(image_dataloader):
            # Training Main Network
            ## process data
            real_tokens, real_masks = next(it_text)
            real_tokens = real_tokens.to(args.device)
            real_masks = real_masks.to(args.device)
            bsz, sample_times, seq_len = real_tokens.shape
            real_tokens = real_tokens.view((bsz * sample_times, seq_len))
            real_masks = real_masks.view((bsz * sample_times, seq_len))
            image_feats, text_feats = image_feats.to(args.device), text_feats.to(args.device)
            if args.normalize_prefix:
                image_feats = image_feats / image_feats.norm(dim=1, keepdim=True)
                text_feats = text_feats / text_feats.norm(dim=1, keepdim=True)

            ## training Discriminator
            greedy_res, sample_res, sample_logprobs = generate_with_baseline(args, image_feats, generator, tokenizer)

            sample_res_token, sample_res_mask = pad_and_token(sample_res)
            text_real_labels = torch.ones((bsz * sample_times))
            text_fake_labels = torch.zeros((sample_res_token.shape[0]))
            D_loss = discriminator(torch.cat((real_tokens, sample_res_token.detach())),
                             torch.cat((real_masks, sample_res_mask.detach())), training=True,
                             labels=torch.cat((text_real_labels, text_fake_labels)))

            ## training Generator
            reward_loss = scst_criterion_CLIP(image_feats, text_feats, greedy_res, sample_res, sample_logprobs)
            fd_loss = PG_loss(greedy_res, sample_res, sample_logprobs)
            ## compute scores for main network
            l1_score, cos_score, clip_score = scst_criterion_CLIP.get_score()
            cos_total += cos_score
            l1_total += l1_score
            clip_total += clip_score
            critic_score = get_critic_score()

            # loss backward and logging
            if args.gradient_accumulation_steps > 1:
                D_loss = D_loss / args.gradient_accumulation_steps
            D_loss.backward()
            torch.nn.utils.clip_grad_norm_(discriminator.parameters(), args.max_grad_norm)
            if (step + 1) % args.gradient_accumulation_steps == 0:
                global_step += 1
                optimizer_D.step()
                scheduler_D.step()
                discriminator.zero_grad()

            if global_step > args.gan_training_steps:
                reward_weight = min((global_step - args.gan_training_steps) / args.gan_warm_steps, 1.0) * args.reward_weight
            else:
                reward_weight = 0.0
            G_loss = reward_weight * reward_loss + (1.0 - reward_weight) * fd_loss

            if args.gradient_accumulation_steps > 1:
                G_loss = G_loss / args.gradient_accumulation_steps
            G_loss.backward()
            torch.nn.utils.clip_grad_norm_(generator.parameters(), args.max_grad_norm)
            if (step + 1) % args.gradient_accumulation_steps == 0:
                optimizer_G.step()
                scheduler_G.step()
                generator.zero_grad()

            if (step + 1) % args.gradient_accumulation_steps == 0:
                if global_step % args.logging_steps == 0:
                    logger.info("Epoch: {}, global_step: {}\n" \
                                "G loss: {:.4f}, D loss: {:.4f}".format(epoch + 1, global_step,
                                                                           G_loss, D_loss))
                    logger.info("Main Network Training: \n" \
                                "cosine score: {:.4f}, l1 score: {:.4f}, clip score: {:.4f}, critic score: {:.4f}\n" \
                                "reward loss: {:.4f}, fD loss: {:.4f}\n".format(cos_score, l1_score, clip_score, critic_score,
                                                                                 reward_loss, fd_loss))

        checkpoint_dir = save_checkpoint(generator, args, save_type='checkpoint')
        synchronize()
        # evaluation
        if args.evaluate_during_training:
            logger.info("Epoch %d training finish. Performing evaluation" % (epoch + 1))
            res = evaluate(args, global_step, val_dataloader, generator, tokenizer,
                    checkpoint_dir)
            if is_main_process():
                logger.info('evaluation result: {}\n'.format(str(res)))
                cider_score = res['CIDEr']
                if cider_score > best_score:
                    best_score = cider_score
                    logger.info("epoch: {}, best cider: {}".format(epoch + 1, best_score))
                    best_dir = save_checkpoint(generator, args, save_type='best_model', epoch=epoch + 1, step=global_step)
            synchronize()

        cos_total /= epoch_steps
        l1_total /= epoch_steps
        clip_total /= epoch_steps
        cos_list.append(cos_total)
        l1_list.append(l1_total)
        clip_list.append(clip_total)

        logger.info("average cos score: {} \n " \
                    "average l1 score: {} \n " \
                    "average clip score: {}".format(str(cos_list), str(l1_list), str(clip_list)))
    return 0

# do test/val

def test(args, test_dataloader, model, tokenizer, predict_file):
    world_size = get_world_size()
    if world_size == 1:
        cache_file = predict_file
    else:
        cache_file = op.splitext(predict_file)[0] + '_{}_{}'.format(get_rank(),
                world_size) + op.splitext(predict_file)[1]
    model.eval()
    inputs_param = {'is_decode': True,
        'do_sample': False,
        # hyperparameters of beam search
        'eos_token' : args.eos_token,
        'max_length': args.max_gen_length,
        "temperature": args.temperature,
        "top_k": args.top_k,
        "top_p": args.top_p,
        "repetition_penalty": args.repetition_penalty,
        "length_penalty": args.length_penalty,
        "num_return_sequences": args.num_return_sequences,
        "num_keep_best": args.num_keep_best,
    }
    def _generate():
        time_meter = 0
        with torch.no_grad():
            for step, (img_id, batch) in enumerate(test_dataloader):
                batch = tuple(t.to(args.device) for t in batch)
                inputs = {"img_feats":batch[2]}
                inputs.update(inputs_param)
                tic = time.time()
                # captions, logprobs
                outputs = model(**inputs)
                time_meter += time.time() - tic
                all_caps = outputs[0]  # batch_size * num_keep_best * max_len
                all_confs = torch.exp(outputs[1])

                for img_key, caps, confs in zip(img_id, all_caps, all_confs):
                    res = []
                    for cap, conf in zip(caps, confs):
                        cap = tokenizer.decode(cap.tolist(), skip_special_tokens=True)
                        res.append({'caption': cap, 'conf': conf.item()})
                    if isinstance(img_key, torch.Tensor):
                        img_key = img_key.item()
                    yield img_key, res[0]['caption']
        logger.info("Inference model computing time: {} seconds per batch".format(time_meter / (step+1)))
    cache_file = open(cache_file, 'w')
    json_writer(_generate(), cache_file)
    if world_size > 1:
        torch.distributed.barrier()
    if world_size > 1 and is_main_process():
        cache_files = [op.splitext(predict_file)[0] + '_{}_{}'.format(i, world_size) + \
            op.splitext(predict_file)[1] for i in range(world_size)]
        concat_json_files(cache_files, predict_file)
        delete_json_files(cache_files)
    if world_size > 1:
        torch.distributed.barrier()

def get_predict_file(output_dir, mode, iteration, args):
    cc = ['pred']
    # make sure it works with/without / in end of the path.
    # data = op.basename(op.join(args.data_dir, '')[:-1])
    # cc.append(data)
    cc.append('max{}'.format(args.max_gen_length))
    if args.num_keep_best != 1:
        cc.append('best{}'.format(args.num_keep_best))
    return op.join(output_dir, '{}_{}_{}.json'.format('.'.join(cc), iteration, mode))

def evaluate_on_coco_caption(predict_file, caption_file):
    coco = COCO(caption_file)
    cocoRes = coco.loadRes(predict_file)
    cocoEval = COCOEvalCap(coco, cocoRes)

    # evaluate on a subset of images by setting
    # cocoEval.params['image_id'] = cocoRes.getImgIds()
    # please remove this line when evaluating the full validation set
    cocoEval.params['image_id'] = cocoRes.getImgIds()

    # evaluate results
    # SPICE will take a few minutes the first time, but speeds up due to caching
    cocoEval.evaluate()
    result = cocoEval.eval
    return result

def evaluate(args, iteration, val_dataloader, model, tokenizer, output_dir):
    result = None
    mode = val_dataloader.dataset.mode
    predict_file = get_predict_file(output_dir, mode, iteration, args)
    test(args, val_dataloader, model, tokenizer, predict_file)

    if get_world_size() > 1:
        torch.distributed.barrier()
    if is_main_process():
        caption_file = val_dataloader.dataset.gt_file
        result = evaluate_on_coco_caption(predict_file, caption_file)
    if get_world_size() > 1:
        torch.distributed.barrier()
    return result

def main():
    parser = argparse.ArgumentParser()

    # directory settings
    parser.add_argument('--data_train', type=str, default="", help="path to pair embedding file")
    parser.add_argument('--text_corpus', type=str, default="", help="path to text corpus file")
    parser.add_argument('--data_val', type=str, default="", help="path to val embedding file")
    parser.add_argument('--data_test', type=str, default="", help="path to test embedding file")
    parser.add_argument('--gt_val', type=str, default="", help="path to val json file")
    parser.add_argument('--gt_test', type=str, default="", help="path to test json file")
    parser.add_argument('--output_dir', type=str, default="", help="path to output")
    # operation settings
    parser.add_argument("--do_train", action='store_true', help="Whether to run training.")
    parser.add_argument("--do_infer", action='store_true', help="Whether to run inference.")
    parser.add_argument("--do_eval", action='store_true', help="Whether to run evaluation.")
    parser.add_argument("--batch_size", default=16, type=int,
                        help="Batch size per GPU/CPU for training and evaluation.")
    parser.add_argument("--num_workers", default=4, type=int, help="Workers in dataloader.")
    # global setting
    parser.add_argument("--generator_init", type=str, default='', help="Generator checkpoint.")
#     parser.add_argument("--local_rank", type=int, default=0, help="For distributed training.")
    parser.add_argument('--seed', type=int, default=0, help="random seed")
    # model setting
    parser.add_argument('--clip_model_type', default="ViT-L/14", help="ViT-L/14 or RN50x4 or ViT-B/32")
    parser.add_argument('--mapping_type', type=str, default="mlp", help="mapper type: mlp or transformer")
    parser.add_argument('--prefix_length', type=int, default=10, help="The prefix seq length")
    parser.add_argument('--prefix_length_clip', type=int, default=10,
                        help="When using transformer, project to this length by linear")
    parser.add_argument('--num_layers', type=int, default=4, help="transformer layer number")
    parser.add_argument('--normalize_prefix', dest='normalize_prefix', action='store_true')
    parser.add_argument('--discriminator_type', default='roberta-base')
    # training settings
    parser.add_argument('--gradient_accumulation_steps', type=int, default=1,
                        help="Number of updates steps to accumulate before backward.")
    parser.add_argument("--learning_rate", default=1e-5, type=float, help="The initial lr for G and D")
    parser.add_argument("--weight_decay", default=0.05, type=float, help="Weight deay.")
    parser.add_argument("--adam_epsilon", default=1e-8, type=float, help="Epsilon for Adam.")
    parser.add_argument("--max_grad_norm", default=1.0, type=float, help="Max gradient norm.")
    parser.add_argument("--warmup_steps", default=150, type=int, help="lr linear warmup.")
    parser.add_argument("--scheduler", default='constant', type=str, help="constant or linear")
    parser.add_argument("--epochs", default=50, type=int,
                        help="Total number of training epochs to perform.")
    parser.add_argument('--logging_steps', type=int, default=25, help="Log every X steps.")
    parser.add_argument("--evaluate_during_training", type=bool, default=True,
                        help="Run evaluation during training at each save_steps.")
    parser.add_argument("--test_after_training", type=bool, default=True,
                        help="Test best model after trainig.")
    parser.add_argument('--sc_baseline_type', type=str, default='greedy',
                        help="baseline tyep of REINFORCE algorithm")
    parser.add_argument('--train_sample_n', type=int, default=5,
                        help="number of sampled captions for sc training")
    # param settings
    parser.add_argument("--clip_weight", default=0., type=float, help="weight balancing clip reward and agg reward")
    parser.add_argument("--cos_weight", default=0.5, type=float, help="weight balancing cos and l1 in agg reward")
    parser.add_argument("--reward_weight", default=0.5, type=float, help="weight balancing reward and fD")
    parser.add_argument("--gan_training_steps", type=int, default=150, help="GAN training steps")
    parser.add_argument("--gan_warm_steps", type=int, default=2350, help="GAN warmup steps")
    # generation settings
    parser.add_argument("--eval_model_dir", type=str, default='',
                        help="Model directory for evaluation.")
    parser.add_argument('--max_gen_length', type=int, default=20,
                        help="max length of generated sentences")
    parser.add_argument('--num_return_sequences', type=int, default=1,
                        help="repeating times per image")
    parser.add_argument('--num_keep_best', type=int, default=1,
                        help="number of hypotheses to keep in beam search")
    parser.add_argument('--temperature', type=float, default=1,
                        help="temperature in softmax for sampling")
    parser.add_argument('--top_k', type=int, default=0,
                        help="filter distribution for sampling")
    parser.add_argument('--top_p', type=float, default=1,
                        help="filter distribution for sampling")
    parser.add_argument('--repetition_penalty', type=int, default=1,
                        help="repetition penalty from CTRL paper (https://arxiv.org/abs/1909.05858)")
    parser.add_argument('--length_penalty', type=int, default=1,
                        help="beam search length penalty")
    parser.add_argument('--eos_token', default='.')
    # eval settings
    parser.add_argument('--eval_mode', default="test", help="test dataset: test or val")
    args = parser.parse_args()
    global logger

    local_rank = int(os.environ["LOCAL_RANK"])
    local_rank = ensure_init_process_group(local_rank=local_rank)


    args.num_gpus = get_world_size()
    args.distributed = args.num_gpus > 1
    args.device = torch.device('cuda')
    synchronize()

    output_dir = args.output_dir

    logger = setup_logger("Trainer", output_dir, local_rank)
    logger.warning("Device: %s, n_gpu: %s", args.device, args.num_gpus)
    set_seed(args.seed, args.num_gpus)

    prefix_length = args.prefix_length

    if args.clip_model_type == "ViT-B/32":
        prefix_dim = 512
    elif args.clip_model_type == "ViT-L/14":
        prefix_dim = 768
    elif args.clip_model_type == "RN50x4":
        prefix_dim = 640
    else:
        raise RuntimeError('CLIP model type error')

    # create model
    if args.do_train:
        # create main generator
        generator_checkpoint = args.generator_init
        generator = ClipCaptionModel(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                 num_layers=args.num_layers, mapping_type=args.mapping_type)

        if generator_checkpoint != "":
            logger.info(f"loading generator from {generator_checkpoint}")
            state_dict = torch.load(generator_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)

        # create main discriminator
        discriminator = RobertaDiscriminator(args, args.sc_baseline_type, args.discriminator_type)
        discriminator.to(args.device)

    else:
        generator_checkpoint = args.generator_init
        generator = ClipCaptionModel(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                 num_layers=args.num_layers, mapping_type=args.mapping_type)

        if generator_checkpoint != "":
            logger.info(f"loading generator from {generator_checkpoint}")
            state_dict = torch.load(generator_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)

    generator.to(args.device)
    logger.info("Training/evaluation parameters %s", args)

    # create dataloader and train
    if args.do_train:
        # dataloader for text_generatior, text_discriminatior, image_generatior, image_discriminatior
        image_dataloader, text_dataloader = \
        make_data_loader(args, "train", is_distributed=args.distributed, is_train=True)
        val_dataloader = None
        if args.evaluate_during_training:
            val_dataloader = make_data_loader(args, "val", is_distributed=args.distributed, is_train=False)

        train(image_dataloader, text_dataloader, val_dataloader, generator, discriminator, args ,local_rank )

        # test best model after training
        if args.test_after_training:
            del val_dataloader, image_dataloader, text_dataloader, discriminator
            gc.collect()
            torch.cuda.empty_cache()
            test_dataloader = make_data_loader(args, "test", is_distributed=args.distributed, is_train=False)
            logger.info("Testing best checkpoint")
            best_checkpoint = op.join(args.output_dir, 'best/model.pt')
            logger.info(f"loading generator from {best_checkpoint}")
            state_dict = torch.load(best_checkpoint, map_location=torch.device('cpu'))
            generator.load_state_dict(state_dict)
            generator.to(args.device)
            result = evaluate(args, "testtime", test_dataloader, generator, generator.tokenizer,
                                    args.output_dir)
            logger.info("Evaluation results : {}".format(str(result)))

    # inference and evaluation
    elif args.do_infer or args.do_eval:
        logger.info("Evaluate on dataset: " + args.eval_mode)
        test_dataloader = make_data_loader(args, args.eval_mode, is_distributed=args.distributed, is_train=False)

        if not args.do_eval:
            predict_file = get_predict_file(args.output_dir, args.eval_mode, "testtime", args)
            test(args, test_dataloader, generator, generator.tokenizer, predict_file)
            logger.info("Prediction results saved to: {}".format(predict_file))
        else:
            result = evaluate(args, "testtime", test_dataloader, generator, generator.tokenizer,
                              args.output_dir)
            logger.info("Evaluation results : {}".format(str(result)))

if __name__ == "__main__":
    main()
# Out:
# Overwriting /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py

# %%
import os

gpus = "0,1"
os.environ["CUDA_VISIBLE_DEVICES"] = gpus
# !export CUDA_VISIBLE_DEVICES=0,1
# !export WORLD_SIZE=2

# %%
import torch
torch.cuda.device_count()
# Out:
# 2

# %%
# !python -m torch.distributed.launch \
# --master_port 17527 \
# --nproc_per_node 2 /kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py \
# --output_dir /kaggle/working/output \
# --generator_init /kaggle/working/data/clip-embedding-cgt-gans/model.pt \
# --data_train /kaggle/working/data/clip-embedding-cgt-gans\coco_images_coco_captions_ViT-L_14_100.pkl \
# --data_val /kaggle/working/data/clip-embedding-cgt-gans\coco_ViT-L_14_val.pkl \
# --data_test /kaggle/working/data/clip-embedding-cgt-gans\coco_ViT-L_14_test.pkl \
# --text_corpus /kaggle/working/data/clip-embedding-cgt-gans\coco_train_sentences.pkl \
# --gt_val /kaggle/working/data/coco/annotations/val_caption_coco_format.json \
# --gt_test /kaggle/working/data/coco/annotations/test_caption_coco_format.json \
# --do_train \
# --epochs 1

# %%
# !export TORCH_ELASTIC_MP_TRACEBACK=1

# %%
# !torchrun --nproc_per_node=2 --master_port 17527 \
/kaggle/working/CgtGAN-main/CgtGAN-main/cgtgan.py \
--output_dir /kaggle/working/output \
--generator_init /kaggle/input/clip-embedding-cgt-gans/model_epoch4.pt \
--data_train /kaggle/working/data/clip-embedding-cgt-gans/coco_images_coco_captions_ViT-L_14_100.pkl \
--data_val /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_val.pkl \
--data_test /kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_test.pkl \
--text_corpus /kaggle/working/data/clip-embedding-cgt-gans/coco_train_sentences.pkl \
--gt_val /kaggle/working/data/coco/annotations/val_caption_coco_format.json \
--gt_test /kaggle/working/data/coco/annotations/test_caption_coco_format.json \
--do_train \
--batch_size 16 \
--epochs 4
# Out:
# [2024-04-24 19:54:38,237] torch.distributed.run: [WARNING]
# [2024-04-24 19:54:38,237] torch.distributed.run: [WARNING] *****************************************
# [2024-04-24 19:54:38,237] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# [2024-04-24 19:54:38,237] torch.distributed.run: [WARNING] *****************************************
# 2024-04-24 19:54:46.117991: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 19:54:46.117991: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 19:54:46.118074: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 19:54:46.118124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 19:54:46.292856: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-24 19:54:46.292851: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Init distributed training on local rank 1
# Init distributed training on local rank 0
# 2024-04-24 19:54:59,756 Trainer WARNING: Device: cuda, n_gpu: 2
# Downloading config.json: 100%|█████████████████| 665/665 [00:00<00:00, 4.14MB/s]
# Downloading model.safetensors: 100%|██████████| 548M/548M [00:01<00:00, 289MB/s]
# Downloading generation_config.json: 100%|███████| 124/124 [00:00<00:00, 489kB/s]
# Downloading vocab.json: 100%|██████████████| 1.04M/1.04M [00:00<00:00, 16.1MB/s]
# Downloading merges.txt: 100%|████████████████| 456k/456k [00:00<00:00, 2.37MB/s]
# Downloading tokenizer_config.json: 100%|██████| 26.0/26.0 [00:00<00:00, 188kB/s]
# Using MLP as Mapper
# Using MLP as Mapper
# 2024-04-24 19:55:06,100 Trainer INFO: loading generator from /kaggle/input/clip-embedding-cgt-gans/model_epoch4.pt
# Downloading config.json: 100%|█████████████████| 481/481 [00:00<00:00, 1.74MB/s]
# Downloading model.safetensors: 100%|██████████| 499M/499M [00:01<00:00, 288MB/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading vocab.json: 100%|████████████████| 899k/899k [00:00<00:00, 12.9MB/s]
# Downloading merges.txt: 100%|████████████████| 456k/456k [00:00<00:00, 36.5MB/s]
# Downloading tokenizer_config.json: 100%|██████| 25.0/25.0 [00:00<00:00, 137kB/s]
# 2024-04-24 19:55:11,605 Trainer INFO: Training/evaluation parameters Namespace(data_train='/kaggle/working/data/clip-embedding-cgt-gans/coco_images_coco_captions_ViT-L_14_100.pkl', text_corpus='/kaggle/working/data/clip-embedding-cgt-gans/coco_train_sentences.pkl', data_val='/kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_val.pkl', data_test='/kaggle/working/data/clip-embedding-cgt-gans/coco_ViT-L_14_test.pkl', gt_val='/kaggle/working/data/coco/annotations/val_caption_coco_format.json', gt_test='/kaggle/working/data/coco/annotations/test_caption_coco_format.json', output_dir='/kaggle/working/output', do_train=True, do_infer=False, do_eval=False, batch_size=16, num_workers=4, generator_init='/kaggle/input/clip-embedding-cgt-gans/model_epoch4.pt', seed=0, clip_model_type='ViT-L/14', mapping_type='mlp', prefix_length=10, prefix_length_clip=10, num_layers=4, normalize_prefix=False, discriminator_type='roberta-base', gradient_accumulation_steps=1, learning_rate=1e-05, weight_decay=0.05, adam_epsilon=1e-08, max_grad_norm=1.0, warmup_steps=150, scheduler='constant', epochs=4, logging_steps=25, evaluate_during_training=True, test_after_training=True, sc_baseline_type='greedy', train_sample_n=5, clip_weight=0.0, cos_weight=0.5, reward_weight=0.5, gan_training_steps=150, gan_warm_steps=2350, eval_model_dir='', max_gen_length=20, num_return_sequences=1, num_keep_best=1, temperature=1, top_k=0, top_p=1, repetition_penalty=1, length_penalty=1, eos_token='.', eval_mode='test', num_gpus=2, distributed=True, device=device(type='cuda'))
# Pair data size is 113287
# Image embedding dim is 768
# Caption embedding dim is 768
# Text Corpus size for Discrimination is 566747
# Pair data size is 113287
# Image embedding dim is 768
# Caption embedding dim is 768
# Text Corpus size for Discrimination is 566747
# 2024-04-24 19:58:30,390 Trainer INFO: Train with 16 images per GPU.
# 2024-04-24 19:58:30,390 Trainer INFO: Total batch size 32
# 2024-04-24 19:58:30,390 Trainer INFO: Total training steps 14160
# 2024-04-24 19:58:30,391 Trainer INFO: load without concate
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# 2024-04-24 19:58:37,931 Trainer INFO: ***** Running training *****
# 2024-04-24 19:58:37,931 Trainer INFO:   Epoch number = 4
# 2024-04-24 19:58:37,932 Trainer INFO:   Batch size per GPU = 16
# 2024-04-24 19:58:37,932 Trainer INFO:   Total train batch size (w. parallel, & accumulation) = 32
# 2024-04-24 19:58:37,933 Trainer INFO:   Gradient Accumulation steps = 1
# 2024-04-24 19:58:37,933 Trainer INFO:   Total optimization steps = 14160
# 100%|████████████████████████████████████████| 890M/890M [00:06<00:00, 135MiB/s]
# 100%|███████████████████████████████████████| 890M/890M [00:18<00:00, 51.1MiB/s]
# 2024-04-24 19:58:59,113 Trainer INFO: SCST training...
# [W reducer.cpp:1346] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [W reducer.cpp:1346] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# 2024-04-24 20:00:10,802 Trainer INFO: Epoch: 1, global_step: 25
# G loss: 0.0173, D loss: 0.6706
# 2024-04-24 20:00:10,803 Trainer INFO: Main Network Training:
# cosine score: 87.4546, l1 score: 81.7155, clip score: 25.9702, critic score: -0.2029
# reward loss: -0.9127, fD loss: 0.0173
#
# 2024-04-24 20:01:10,944 Trainer INFO: Epoch: 1, global_step: 50
# G loss: 0.1528, D loss: 0.6406
# 2024-04-24 20:01:10,945 Trainer INFO: Main Network Training:
# cosine score: 83.9672, l1 score: 80.0556, clip score: 25.8039, critic score: -0.9980
# reward loss: -0.8336, fD loss: 0.1528
#
# 2024-04-24 20:02:11,321 Trainer INFO: Epoch: 1, global_step: 75
# G loss: 0.0531, D loss: 0.5553
# 2024-04-24 20:02:11,321 Trainer INFO: Main Network Training:
# cosine score: 84.3280, l1 score: 80.0517, clip score: 26.4903, critic score: -0.6927
# reward loss: -1.2798, fD loss: 0.0531
#
# 2024-04-24 20:03:12,483 Trainer INFO: Epoch: 1, global_step: 100
# G loss: 0.1357, D loss: 0.6402
# 2024-04-24 20:03:12,484 Trainer INFO: Main Network Training:
# cosine score: 85.9992, l1 score: 81.7951, clip score: 26.6995, critic score: -0.7080
# reward loss: -1.1162, fD loss: 0.1357
#
# 2024-04-24 20:04:13,986 Trainer INFO: Epoch: 1, global_step: 125
# G loss: -0.1260, D loss: 0.5673
# 2024-04-24 20:04:13,986 Trainer INFO: Main Network Training:
# cosine score: 85.0429, l1 score: 80.9354, clip score: 26.0909, critic score: -0.5560
# reward loss: -0.3634, fD loss: -0.1260
#
# 2024-04-24 20:05:12,320 Trainer INFO: Epoch: 1, global_step: 150
# G loss: 0.1215, D loss: 0.6396
# 2024-04-24 20:05:12,320 Trainer INFO: Main Network Training:
# cosine score: 83.3720, l1 score: 79.5604, clip score: 25.6989, critic score: -0.3358
# reward loss: -1.3735, fD loss: 0.1215
#
# 2024-04-24 20:06:11,796 Trainer INFO: Epoch: 1, global_step: 175
# G loss: -0.0200, D loss: 0.6072
# 2024-04-24 20:06:11,796 Trainer INFO: Main Network Training:
# cosine score: 80.4629, l1 score: 78.3214, clip score: 25.8991, critic score: -0.1931
# reward loss: -2.6531, fD loss: -0.0059
#
# 2024-04-24 20:07:17,338 Trainer INFO: Epoch: 1, global_step: 200
# G loss: -0.1644, D loss: 0.5493
# 2024-04-24 20:07:17,338 Trainer INFO: Main Network Training:
# cosine score: 81.0463, l1 score: 79.3307, clip score: 26.1813, critic score: -0.3431
# reward loss: -3.1744, fD loss: -0.1320
#
# 2024-04-24 20:08:20,929 Trainer INFO: Epoch: 1, global_step: 225
# G loss: 0.0039, D loss: 0.6473
# 2024-04-24 20:08:20,930 Trainer INFO: Main Network Training:
# cosine score: 82.9163, l1 score: 79.1504, clip score: 26.0564, critic score: -0.1791
# reward loss: -2.0282, fD loss: 0.0368
#
# 2024-04-24 20:09:19,175 Trainer INFO: Epoch: 1, global_step: 250
# G loss: 0.0645, D loss: 0.6025
# 2024-04-24 20:09:19,176 Trainer INFO: Main Network Training:
# cosine score: 83.6320, l1 score: 79.5107, clip score: 24.5755, critic score: -1.3571
# reward loss: -0.6820, fD loss: 0.0808
#
# 2024-04-24 20:10:20,924 Trainer INFO: Epoch: 1, global_step: 275
# G loss: -0.0206, D loss: 0.5451
# 2024-04-24 20:10:20,925 Trainer INFO: Main Network Training:
# cosine score: 84.7615, l1 score: 80.2484, clip score: 25.9327, critic score: -0.8664
# reward loss: -2.1453, fD loss: 0.0375
#
# 2024-04-24 20:11:23,685 Trainer INFO: Epoch: 1, global_step: 300
# G loss: 0.0227, D loss: 0.5887
# 2024-04-24 20:11:23,686 Trainer INFO: Main Network Training:
# cosine score: 83.9196, l1 score: 80.4258, clip score: 26.7179, critic score: -0.7289
# reward loss: -1.2041, fD loss: 0.0632
#
# 2024-04-24 20:12:24,033 Trainer INFO: Epoch: 1, global_step: 325
# G loss: 0.0892, D loss: 0.6168
# 2024-04-24 20:12:24,033 Trainer INFO: Main Network Training:
# cosine score: 79.3183, l1 score: 77.4767, clip score: 25.2293, critic score: -0.3552
# reward loss: -0.0438, fD loss: 0.0944
#
# 2024-04-24 20:13:27,523 Trainer INFO: Epoch: 1, global_step: 350
# G loss: 0.1081, D loss: 0.7100
# 2024-04-24 20:13:27,524 Trainer INFO: Main Network Training:
# cosine score: 82.0312, l1 score: 78.4220, clip score: 24.6079, critic score: -0.3667
# reward loss: -0.2683, fD loss: 0.1248
#
# 2024-04-24 20:14:28,063 Trainer INFO: Epoch: 1, global_step: 375
# G loss: 0.0388, D loss: 0.6285
# 2024-04-24 20:14:28,064 Trainer INFO: Main Network Training:
# cosine score: 84.2538, l1 score: 80.2923, clip score: 25.9590, critic score: -0.2488
# reward loss: -0.8896, fD loss: 0.0855
#
# 2024-04-24 20:15:28,689 Trainer INFO: Epoch: 1, global_step: 400
# G loss: 0.0506, D loss: 0.5567
# 2024-04-24 20:15:28,689 Trainer INFO: Main Network Training:
# cosine score: 83.6512, l1 score: 79.0924, clip score: 24.0379, critic score: -0.6970
# reward loss: 0.5692, fD loss: 0.0215
#
# 2024-04-24 20:16:32,147 Trainer INFO: Epoch: 1, global_step: 425
# G loss: -0.1102, D loss: 0.6303
# 2024-04-24 20:16:32,147 Trainer INFO: Main Network Training:
# cosine score: 80.6085, l1 score: 78.8428, clip score: 26.3962, critic score: -0.2869
# reward loss: -1.0093, fD loss: -0.0544
#
# 2024-04-24 20:17:34,981 Trainer INFO: Epoch: 1, global_step: 450
# G loss: -0.0950, D loss: 0.6076
# 2024-04-24 20:17:34,981 Trainer INFO: Main Network Training:
# cosine score: 84.3810, l1 score: 79.3893, clip score: 24.7508, critic score: -0.4363
# reward loss: -1.5873, fD loss: 0.0068
#
# 2024-04-24 20:18:33,913 Trainer INFO: Epoch: 1, global_step: 475
# G loss: 0.1282, D loss: 0.6609
# 2024-04-24 20:18:33,914 Trainer INFO: Main Network Training:
# cosine score: 81.4216, l1 score: 78.4437, clip score: 25.8235, critic score: -0.5245
# reward loss: -1.6398, fD loss: 0.2595
#
# 2024-04-24 20:19:35,934 Trainer INFO: Epoch: 1, global_step: 500
# G loss: -0.0351, D loss: 0.6139
# 2024-04-24 20:19:35,935 Trainer INFO: Main Network Training:
# cosine score: 80.7157, l1 score: 78.3204, clip score: 25.6233, critic score: -0.4497
# reward loss: -1.0306, fD loss: 0.0450
#
# 2024-04-24 20:20:40,704 Trainer INFO: Epoch: 1, global_step: 525
# G loss: -0.1101, D loss: 0.5228
# 2024-04-24 20:20:40,705 Trainer INFO: Main Network Training:
# cosine score: 85.0564, l1 score: 81.3200, clip score: 26.6236, critic score: -0.9459
# reward loss: -1.0247, fD loss: -0.0308
#
# 2024-04-24 20:21:43,712 Trainer INFO: Epoch: 1, global_step: 550
# G loss: 0.0153, D loss: 0.5510
# 2024-04-24 20:21:43,713 Trainer INFO: Main Network Training:
# cosine score: 84.7417, l1 score: 80.5789, clip score: 27.2318, critic score: -1.0375
# reward loss: -1.3522, fD loss: 0.1426
#
# 2024-04-24 20:22:43,428 Trainer INFO: Epoch: 1, global_step: 575
# G loss: -0.0199, D loss: 0.5902
# 2024-04-24 20:22:43,429 Trainer INFO: Main Network Training:
# cosine score: 82.2360, l1 score: 79.0241, clip score: 26.9312, critic score: -0.6628
# reward loss: -0.8463, fD loss: 0.0622
#
# 2024-04-24 20:23:42,338 Trainer INFO: Epoch: 1, global_step: 600
# G loss: 0.0649, D loss: 0.5652
# 2024-04-24 20:23:42,339 Trainer INFO: Main Network Training:
# cosine score: 84.1292, l1 score: 79.7203, clip score: 25.8355, critic score: -0.7416
# reward loss: -1.5342, fD loss: 0.2343
#
# 2024-04-24 20:24:43,819 Trainer INFO: Epoch: 1, global_step: 625
# G loss: -0.1098, D loss: 0.6487
# 2024-04-24 20:24:43,820 Trainer INFO: Main Network Training:
# cosine score: 83.3124, l1 score: 79.6607, clip score: 25.5654, critic score: -0.6108
# reward loss: -1.6244, fD loss: 0.0605
#
# 2024-04-24 20:25:48,063 Trainer INFO: Epoch: 1, global_step: 650
# G loss: -0.1432, D loss: 0.5032
# 2024-04-24 20:25:48,063 Trainer INFO: Main Network Training:
# cosine score: 83.7046, l1 score: 80.7868, clip score: 26.7605, critic score: -1.2467
# reward loss: 0.0482, fD loss: -0.1659
#
# 2024-04-24 20:26:49,728 Trainer INFO: Epoch: 1, global_step: 675
# G loss: -0.1428, D loss: 0.5767
# 2024-04-24 20:26:49,729 Trainer INFO: Main Network Training:
# cosine score: 84.4396, l1 score: 79.9806, clip score: 26.4085, critic score: -0.8260
# reward loss: -1.1495, fD loss: -0.0162
#
# 2024-04-24 20:27:48,146 Trainer INFO: Epoch: 1, global_step: 700
# G loss: 0.1508, D loss: 0.6399
# 2024-04-24 20:27:48,147 Trainer INFO: Main Network Training:
# cosine score: 84.4334, l1 score: 80.5533, clip score: 25.6509, critic score: -0.8442
# reward loss: -0.6090, fD loss: 0.2515
#
# 2024-04-24 20:28:49,285 Trainer INFO: Epoch: 1, global_step: 725
# G loss: -0.0939, D loss: 0.5793
# 2024-04-24 20:28:49,286 Trainer INFO: Main Network Training:
# cosine score: 82.5515, l1 score: 79.4412, clip score: 26.8610, critic score: -0.9763
# reward loss: -0.9362, fD loss: 0.0235
#
# 2024-04-24 20:29:51,791 Trainer INFO: Epoch: 1, global_step: 750
# G loss: -0.0416, D loss: 0.5835
# 2024-04-24 20:29:51,792 Trainer INFO: Main Network Training:
# cosine score: 85.0265, l1 score: 80.9613, clip score: 26.3786, critic score: -0.4262
# reward loss: -0.8776, fD loss: 0.0808
#
# 2024-04-24 20:30:50,823 Trainer INFO: Epoch: 1, global_step: 775
# G loss: 0.0192, D loss: 0.6335
# 2024-04-24 20:30:50,823 Trainer INFO: Main Network Training:
# cosine score: 84.8702, l1 score: 80.6369, clip score: 26.3228, critic score: -0.5538
# reward loss: -1.3708, fD loss: 0.2324
#
# 2024-04-24 20:31:51,020 Trainer INFO: Epoch: 1, global_step: 800
# G loss: 0.1020, D loss: 0.5869
# 2024-04-24 20:31:51,020 Trainer INFO: Main Network Training:
# cosine score: 84.4285, l1 score: 79.8713, clip score: 27.0919, critic score: -0.6472
# reward loss: -1.0316, fD loss: 0.2840
#
# 2024-04-24 20:32:53,154 Trainer INFO: Epoch: 1, global_step: 825
# G loss: -0.1954, D loss: 0.6290
# 2024-04-24 20:32:53,154 Trainer INFO: Main Network Training:
# cosine score: 82.5188, l1 score: 79.6814, clip score: 26.4901, critic score: -0.4464
# reward loss: -1.0777, fD loss: -0.0474
#
# 2024-04-24 20:33:56,585 Trainer INFO: Epoch: 1, global_step: 850
# G loss: -0.4103, D loss: 0.5037
# 2024-04-24 20:33:56,586 Trainer INFO: Main Network Training:
# cosine score: 85.0817, l1 score: 80.5948, clip score: 25.8770, critic score: -1.0045
# reward loss: -2.3574, fD loss: -0.0696
#
# 2024-04-24 20:34:56,370 Trainer INFO: Epoch: 1, global_step: 875
# G loss: -0.1488, D loss: 0.5415
# 2024-04-24 20:34:56,371 Trainer INFO: Main Network Training:
# cosine score: 87.1654, l1 score: 81.6234, clip score: 26.6835, critic score: -0.8554
# reward loss: -1.7646, fD loss: 0.1459
#
# 2024-04-24 20:35:55,317 Trainer INFO: Epoch: 1, global_step: 900
# G loss: -0.0177, D loss: 0.4969
# 2024-04-24 20:35:55,317 Trainer INFO: Main Network Training:
# cosine score: 85.3395, l1 score: 80.5475, clip score: 26.7184, critic score: -0.9218
# reward loss: -1.7711, fD loss: 0.3152
#
# 2024-04-24 20:36:56,854 Trainer INFO: Epoch: 1, global_step: 925
# G loss: -0.1192, D loss: 0.6105
# 2024-04-24 20:36:56,855 Trainer INFO: Main Network Training:
# cosine score: 83.9194, l1 score: 80.3797, clip score: 26.6631, critic score: -0.6770
# reward loss: -1.3807, fD loss: 0.1299
#
# 2024-04-24 20:37:59,611 Trainer INFO: Epoch: 1, global_step: 950
# G loss: -0.2855, D loss: 0.4668
# 2024-04-24 20:37:59,612 Trainer INFO: Main Network Training:
# cosine score: 84.0941, l1 score: 80.1021, clip score: 26.7155, critic score: -1.0802
# reward loss: -2.0415, fD loss: 0.0747
#
# 2024-04-24 20:39:02,746 Trainer INFO: Epoch: 1, global_step: 975
# G loss: -0.1058, D loss: 0.5313
# 2024-04-24 20:39:02,746 Trainer INFO: Main Network Training:
# cosine score: 87.6831, l1 score: 81.9626, clip score: 27.7902, critic score: -1.0077
# reward loss: -1.4361, fD loss: 0.1774
#
# 2024-04-24 20:40:03,094 Trainer INFO: Epoch: 1, global_step: 1000
# G loss: 0.0589, D loss: 0.5091
# 2024-04-24 20:40:03,095 Trainer INFO: Main Network Training:
# cosine score: 88.0080, l1 score: 82.3621, clip score: 27.5305, critic score: -1.2327
# reward loss: -0.1099, fD loss: 0.0961
#
# 2024-04-24 20:41:03,524 Trainer INFO: Epoch: 1, global_step: 1025
# G loss: -0.0401, D loss: 0.5802
# 2024-04-24 20:41:03,525 Trainer INFO: Main Network Training:
# cosine score: 86.9706, l1 score: 81.9821, clip score: 26.5947, critic score: -1.1285
# reward loss: -0.9641, fD loss: 0.1713
#
# 2024-04-24 20:42:06,466 Trainer INFO: Epoch: 1, global_step: 1050
# G loss: -0.1643, D loss: 0.5635
# 2024-04-24 20:42:06,466 Trainer INFO: Main Network Training:
# cosine score: 84.8099, l1 score: 80.5106, clip score: 26.5747, critic score: -1.0342
# reward loss: -0.7424, fD loss: -0.0274
#
# 2024-04-24 20:43:09,490 Trainer INFO: Epoch: 1, global_step: 1075
# G loss: -0.1667, D loss: 0.5155
# 2024-04-24 20:43:09,490 Trainer INFO: Main Network Training:
# cosine score: 84.5391, l1 score: 80.1311, clip score: 27.0397, critic score: -1.0737
# reward loss: -1.9526, fD loss: 0.2710
#
# 2024-04-24 20:44:12,095 Trainer INFO: Epoch: 1, global_step: 1100
# G loss: -0.2124, D loss: 0.5286
# 2024-04-24 20:44:12,096 Trainer INFO: Main Network Training:
# cosine score: 87.4994, l1 score: 81.5101, clip score: 26.3229, critic score: -1.1455
# reward loss: -1.1604, fD loss: 0.0278
#
# 2024-04-24 20:45:12,948 Trainer INFO: Epoch: 1, global_step: 1125
# G loss: -0.2555, D loss: 0.5291
# 2024-04-24 20:45:12,949 Trainer INFO: Main Network Training:
# cosine score: 86.9836, l1 score: 81.6093, clip score: 25.0546, critic score: -1.4498
# reward loss: -2.4405, fD loss: 0.3164
#
# 2024-04-24 20:46:15,197 Trainer INFO: Epoch: 1, global_step: 1150
# G loss: -0.1931, D loss: 0.5384
# 2024-04-24 20:46:15,197 Trainer INFO: Main Network Training:
# cosine score: 81.6721, l1 score: 78.0309, clip score: 24.3772, critic score: -1.0806
# reward loss: -1.2275, fD loss: 0.0865
#
# 2024-04-24 20:47:16,655 Trainer INFO: Epoch: 1, global_step: 1175
# G loss: -0.2563, D loss: 0.4803
# 2024-04-24 20:47:16,656 Trainer INFO: Main Network Training:
# cosine score: 85.6786, l1 score: 80.5762, clip score: 25.9501, critic score: -1.2255
# reward loss: -1.0779, fD loss: -0.0272
#
# 2024-04-24 20:48:16,715 Trainer INFO: Epoch: 1, global_step: 1200
# G loss: -0.1001, D loss: 0.5481
# 2024-04-24 20:48:16,716 Trainer INFO: Main Network Training:
# cosine score: 85.9835, l1 score: 81.2996, clip score: 26.8738, critic score: -0.9318
# reward loss: -0.2940, fD loss: -0.0443
#
# 2024-04-24 20:49:16,560 Trainer INFO: Epoch: 1, global_step: 1225
# G loss: -0.0371, D loss: 0.5206
# 2024-04-24 20:49:16,560 Trainer INFO: Main Network Training:
# cosine score: 83.1789, l1 score: 79.2933, clip score: 25.0372, critic score: -1.2591
# reward loss: -0.6130, fD loss: 0.1337
#
# 2024-04-24 20:50:17,206 Trainer INFO: Epoch: 1, global_step: 1250
# G loss: -0.0943, D loss: 0.5410
# 2024-04-24 20:50:17,207 Trainer INFO: Main Network Training:
# cosine score: 85.8285, l1 score: 81.4135, clip score: 27.9102, critic score: -1.2216
# reward loss: -0.9555, fD loss: 0.1688
#
# 2024-04-24 20:51:18,924 Trainer INFO: Epoch: 1, global_step: 1275
# G loss: -0.0310, D loss: 0.4264
# 2024-04-24 20:51:18,925 Trainer INFO: Main Network Training:
# cosine score: 86.0646, l1 score: 81.4439, clip score: 26.2242, critic score: -1.4476
# reward loss: -0.0804, fD loss: -0.0154
#
# 2024-04-24 20:52:20,308 Trainer INFO: Epoch: 1, global_step: 1300
# G loss: 0.1221, D loss: 0.6284
# 2024-04-24 20:52:20,309 Trainer INFO: Main Network Training:
# cosine score: 78.9349, l1 score: 77.4087, clip score: 26.0226, critic score: -0.9800
# reward loss: -0.4069, fD loss: 0.2934
#
# 2024-04-24 20:53:19,632 Trainer INFO: Epoch: 1, global_step: 1325
# G loss: -0.4503, D loss: 0.4248
# 2024-04-24 20:53:19,633 Trainer INFO: Main Network Training:
# cosine score: 82.8630, l1 score: 79.0480, clip score: 25.4411, critic score: -1.4848
# reward loss: -1.7411, fD loss: -0.0200
#
# 2024-04-24 20:54:17,476 Trainer INFO: Epoch: 1, global_step: 1350
# G loss: -0.0994, D loss: 0.4921
# 2024-04-24 20:54:17,477 Trainer INFO: Main Network Training:
# cosine score: 83.6099, l1 score: 80.1914, clip score: 25.7282, critic score: -1.3820
# reward loss: -1.0027, fD loss: 0.2103
#
# 2024-04-24 20:55:17,905 Trainer INFO: Epoch: 1, global_step: 1375
# G loss: -0.2943, D loss: 0.4211
# 2024-04-24 20:55:17,905 Trainer INFO: Main Network Training:
# cosine score: 86.1586, l1 score: 81.8083, clip score: 27.0048, critic score: -1.5304
# reward loss: -1.3444, fD loss: 0.0759
#
# 2024-04-24 20:56:20,609 Trainer INFO: Epoch: 1, global_step: 1400
# G loss: -0.1618, D loss: 0.4994
# 2024-04-24 20:56:20,610 Trainer INFO: Main Network Training:
# cosine score: 86.8225, l1 score: 81.7229, clip score: 26.7479, critic score: -1.1781
# reward loss: -1.0136, fD loss: 0.1468
#
# 2024-04-24 20:57:22,162 Trainer INFO: Epoch: 1, global_step: 1425
# G loss: -0.5004, D loss: 0.5559
# 2024-04-24 20:57:22,163 Trainer INFO: Main Network Training:
# cosine score: 81.0335, l1 score: 78.6601, clip score: 25.8060, critic score: -1.1217
# reward loss: -2.2268, fD loss: 0.1423
#
# 2024-04-24 20:58:22,464 Trainer INFO: Epoch: 1, global_step: 1450
# G loss: -0.1814, D loss: 0.4921
# 2024-04-24 20:58:22,465 Trainer INFO: Main Network Training:
# cosine score: 83.7160, l1 score: 79.5449, clip score: 26.8687, critic score: -1.2082
# reward loss: -1.3569, fD loss: 0.2681
#
# 2024-04-24 20:59:22,088 Trainer INFO: Epoch: 1, global_step: 1475
# G loss: -0.1238, D loss: 0.4656
# 2024-04-24 20:59:22,089 Trainer INFO: Main Network Training:
# cosine score: 87.0899, l1 score: 81.5322, clip score: 26.8880, critic score: -1.6178
# reward loss: -1.1702, fD loss: 0.2870
#
# 2024-04-24 21:00:23,145 Trainer INFO: Epoch: 1, global_step: 1500
# G loss: -0.0586, D loss: 0.5171
# 2024-04-24 21:00:23,146 Trainer INFO: Main Network Training:
# cosine score: 81.2527, l1 score: 79.0015, clip score: 26.6253, critic score: -1.3443
# reward loss: -1.0103, fD loss: 0.3249
#
# 2024-04-24 21:01:25,055 Trainer INFO: Epoch: 1, global_step: 1525
# G loss: -0.1038, D loss: 0.4564
# 2024-04-24 21:01:25,056 Trainer INFO: Main Network Training:
# cosine score: 88.7936, l1 score: 82.6994, clip score: 26.1422, critic score: -1.9351
# reward loss: -0.5108, fD loss: 0.0645
#
# 2024-04-24 21:02:25,524 Trainer INFO: Epoch: 1, global_step: 1550
# G loss: -0.6030, D loss: 0.5672
# 2024-04-24 21:02:25,524 Trainer INFO: Main Network Training:
# cosine score: 82.6927, l1 score: 79.6016, clip score: 26.5223, critic score: -1.1484
# reward loss: -2.8127, fD loss: 0.3344
#
# 2024-04-24 21:03:26,225 Trainer INFO: Epoch: 1, global_step: 1575
# G loss: 0.2718, D loss: 0.4972
# 2024-04-24 21:03:26,226 Trainer INFO: Main Network Training:
# cosine score: 84.7474, l1 score: 80.4260, clip score: 25.5347, critic score: -1.5215
# reward loss: 0.1238, fD loss: 0.3363
#
# 2024-04-24 21:04:27,513 Trainer INFO: Epoch: 1, global_step: 1600
# G loss: -0.2265, D loss: 0.4898
# 2024-04-24 21:04:27,514 Trainer INFO: Main Network Training:
# cosine score: 89.5406, l1 score: 82.7724, clip score: 27.1178, critic score: -1.3966
# reward loss: -0.4463, fD loss: -0.1285
#
# 2024-04-24 21:05:29,283 Trainer INFO: Epoch: 1, global_step: 1625
# G loss: -0.0664, D loss: 0.5019
# 2024-04-24 21:05:29,284 Trainer INFO: Main Network Training:
# cosine score: 85.5549, l1 score: 80.9352, clip score: 26.4102, critic score: -1.5316
# reward loss: -0.6840, fD loss: 0.2160
#
# 2024-04-24 21:06:30,406 Trainer INFO: Epoch: 1, global_step: 1650
# G loss: -0.2641, D loss: 0.4256
# 2024-04-24 21:06:30,406 Trainer INFO: Main Network Training:
# cosine score: 86.7498, l1 score: 81.6017, clip score: 25.3308, critic score: -1.5437
# reward loss: -0.8107, fD loss: -0.0078
#
# 2024-04-24 21:07:31,035 Trainer INFO: Epoch: 1, global_step: 1675
# G loss: -0.2720, D loss: 0.5132
# 2024-04-24 21:07:31,036 Trainer INFO: Main Network Training:
# cosine score: 87.8491, l1 score: 82.4474, clip score: 26.8778, critic score: -1.3124
# reward loss: -0.8148, fD loss: -0.0113
#
# 2024-04-24 21:08:31,946 Trainer INFO: Epoch: 1, global_step: 1700
# G loss: 0.0538, D loss: 0.4825
# 2024-04-24 21:08:31,946 Trainer INFO: Main Network Training:
# cosine score: 87.6300, l1 score: 82.2071, clip score: 26.7243, critic score: -1.4070
# reward loss: -0.3998, fD loss: 0.2771
#
# 2024-04-24 21:09:33,558 Trainer INFO: Epoch: 1, global_step: 1725
# G loss: -0.0096, D loss: 0.4754
# 2024-04-24 21:09:33,558 Trainer INFO: Main Network Training:
# cosine score: 89.2251, l1 score: 83.1314, clip score: 25.9358, critic score: -1.8615
# reward loss: -0.2214, fD loss: 0.0971
#
# 2024-04-24 21:10:34,365 Trainer INFO: Epoch: 1, global_step: 1750
# G loss: -0.1222, D loss: 0.4560
# 2024-04-24 21:10:34,366 Trainer INFO: Main Network Training:
# cosine score: 88.1349, l1 score: 81.6950, clip score: 25.9518, critic score: -1.6877
# reward loss: -0.6539, fD loss: 0.1523
#
# 2024-04-24 21:11:34,873 Trainer INFO: Epoch: 1, global_step: 1775
# G loss: -0.0434, D loss: 0.4421
# 2024-04-24 21:11:34,874 Trainer INFO: Main Network Training:
# cosine score: 86.6289, l1 score: 81.8317, clip score: 26.0797, critic score: -1.6179
# reward loss: -0.0600, fD loss: -0.0346
#
# 2024-04-24 21:12:35,399 Trainer INFO: Epoch: 1, global_step: 1800
# G loss: -0.2618, D loss: 0.4586
# 2024-04-24 21:12:35,400 Trainer INFO: Main Network Training:
# cosine score: 85.4157, l1 score: 80.2310, clip score: 25.4872, critic score: -1.7478
# reward loss: -1.3029, fD loss: 0.3014
#
# 2024-04-24 21:13:36,222 Trainer INFO: Epoch: 1, global_step: 1825
# G loss: -0.2450, D loss: 0.4058
# 2024-04-24 21:13:36,223 Trainer INFO: Main Network Training:
# cosine score: 86.3760, l1 score: 81.3586, clip score: 25.2411, critic score: -1.4795
# reward loss: -0.7516, fD loss: 0.0355
#
# 2024-04-24 21:14:37,040 Trainer INFO: Epoch: 1, global_step: 1850
# G loss: -0.2455, D loss: 0.4438
# 2024-04-24 21:14:37,040 Trainer INFO: Main Network Training:
# cosine score: 84.2630, l1 score: 80.2649, clip score: 25.2667, critic score: -1.8551
# reward loss: -0.6587, fD loss: -0.0113
#
# 2024-04-24 21:15:37,731 Trainer INFO: Epoch: 1, global_step: 1875
# G loss: -0.0997, D loss: 0.4292
# 2024-04-24 21:15:37,731 Trainer INFO: Main Network Training:
# cosine score: 87.4579, l1 score: 81.9054, clip score: 26.6815, critic score: -1.9701
# reward loss: -0.3750, fD loss: 0.0599
#
# 2024-04-24 21:16:37,643 Trainer INFO: Epoch: 1, global_step: 1900
# G loss: -0.3283, D loss: 0.3652
# 2024-04-24 21:16:37,644 Trainer INFO: Main Network Training:
# cosine score: 88.7233, l1 score: 82.4398, clip score: 25.6553, critic score: -2.1677
# reward loss: -0.9862, fD loss: 0.0620
#
# 2024-04-24 21:17:39,048 Trainer INFO: Epoch: 1, global_step: 1925
# G loss: -0.4506, D loss: 0.4820
# 2024-04-24 21:17:39,049 Trainer INFO: Main Network Training:
# cosine score: 86.3297, l1 score: 81.5418, clip score: 27.0326, critic score: -1.3719
# reward loss: -1.3643, fD loss: 0.1038
#
# 2024-04-24 21:18:40,954 Trainer INFO: Epoch: 1, global_step: 1950
# G loss: -0.3277, D loss: 0.4524
# 2024-04-24 21:18:40,955 Trainer INFO: Main Network Training:
# cosine score: 82.6034, l1 score: 78.9689, clip score: 25.6719, critic score: -1.3378
# reward loss: -0.1701, fD loss: -0.4256
#
# 2024-04-24 21:19:42,819 Trainer INFO: Epoch: 1, global_step: 1975
# G loss: -0.1952, D loss: 0.4209
# 2024-04-24 21:19:42,820 Trainer INFO: Main Network Training:
# cosine score: 87.4840, l1 score: 82.0137, clip score: 25.0662, critic score: -1.8747
# reward loss: -0.7883, fD loss: 0.1813
#
# 2024-04-24 21:20:43,735 Trainer INFO: Epoch: 1, global_step: 2000
# G loss: -0.4449, D loss: 0.4527
# 2024-04-24 21:20:43,736 Trainer INFO: Main Network Training:
# cosine score: 81.5136, l1 score: 79.1260, clip score: 24.9327, critic score: -1.9270
# reward loss: -1.3233, fD loss: 0.1253
#
# 2024-04-24 21:21:44,526 Trainer INFO: Epoch: 1, global_step: 2025
# G loss: -0.1799, D loss: 0.4279
# 2024-04-24 21:21:44,527 Trainer INFO: Main Network Training:
# cosine score: 84.9252, l1 score: 81.0363, clip score: 26.5485, critic score: -1.6900
# reward loss: -0.6775, fD loss: 0.1503
#
# 2024-04-24 21:22:44,797 Trainer INFO: Epoch: 1, global_step: 2050
# G loss: -0.5085, D loss: 0.4084
# 2024-04-24 21:22:44,798 Trainer INFO: Main Network Training:
# cosine score: 84.7069, l1 score: 80.6804, clip score: 27.4074, critic score: -1.8511
# reward loss: -1.4779, fD loss: 0.1494
#
# 2024-04-24 21:23:45,713 Trainer INFO: Epoch: 1, global_step: 2075
# G loss: -0.4378, D loss: 0.5084
# 2024-04-24 21:23:45,714 Trainer INFO: Main Network Training:
# cosine score: 84.3577, l1 score: 80.2836, clip score: 26.1279, critic score: -1.2946
# reward loss: -1.1794, fD loss: 0.0766
#
# 2024-04-24 21:24:47,688 Trainer INFO: Epoch: 1, global_step: 2100
# G loss: -0.1374, D loss: 0.3317
# 2024-04-24 21:24:47,689 Trainer INFO: Main Network Training:
# cosine score: 88.8308, l1 score: 82.5944, clip score: 27.2342, critic score: -1.8472
# reward loss: -0.4009, fD loss: 0.0494
#
# 2024-04-24 21:25:49,359 Trainer INFO: Epoch: 1, global_step: 2125
# G loss: -0.1578, D loss: 0.3854
# 2024-04-24 21:25:49,360 Trainer INFO: Main Network Training:
# cosine score: 86.3377, l1 score: 80.9253, clip score: 25.3641, critic score: -1.6202
# reward loss: -0.5258, fD loss: 0.1089
#
# 2024-04-24 21:26:49,406 Trainer INFO: Epoch: 1, global_step: 2150
# G loss: -0.1052, D loss: 0.3859
# 2024-04-24 21:26:49,406 Trainer INFO: Main Network Training:
# cosine score: 87.8766, l1 score: 81.7720, clip score: 25.2425, critic score: -1.8700
# reward loss: -0.2281, fD loss: -0.0141
#
# 2024-04-24 21:27:49,849 Trainer INFO: Epoch: 1, global_step: 2175
# G loss: -0.1161, D loss: 0.3713
# 2024-04-24 21:27:49,849 Trainer INFO: Main Network Training:
# cosine score: 90.2931, l1 score: 84.2720, clip score: 27.4757, critic score: -2.4162
# reward loss: -0.3573, fD loss: 0.0666
#
# 2024-04-24 21:28:50,224 Trainer INFO: Epoch: 1, global_step: 2200
# G loss: -0.4181, D loss: 0.4108
# 2024-04-24 21:28:50,225 Trainer INFO: Main Network Training:
# cosine score: 84.4436, l1 score: 80.9704, clip score: 27.5184, critic score: -1.9227
# reward loss: -0.9338, fD loss: -0.0191
#
# 2024-04-24 21:29:49,594 Trainer INFO: Epoch: 1, global_step: 2225
# G loss: -0.2058, D loss: 0.5026
# 2024-04-24 21:29:49,595 Trainer INFO: Main Network Training:
# cosine score: 86.5855, l1 score: 81.0879, clip score: 25.4659, critic score: -1.9104
# reward loss: -0.7132, fD loss: 0.1953
#
# 2024-04-24 21:30:50,747 Trainer INFO: Epoch: 1, global_step: 2250
# G loss: -0.3681, D loss: 0.3871
# 2024-04-24 21:30:50,748 Trainer INFO: Main Network Training:
# cosine score: 88.1786, l1 score: 82.7143, clip score: 27.4052, critic score: -2.5750
# reward loss: -0.8878, fD loss: 0.0515
#
# 2024-04-24 21:31:51,929 Trainer INFO: Epoch: 1, global_step: 2275
# G loss: -0.3755, D loss: 0.3922
# 2024-04-24 21:31:51,929 Trainer INFO: Main Network Training:
# cosine score: 83.8851, l1 score: 79.7989, clip score: 25.9958, critic score: -2.2948
# reward loss: -1.2169, fD loss: 0.3189
#
# 2024-04-24 21:32:52,377 Trainer INFO: Epoch: 1, global_step: 2300
# G loss: -0.1078, D loss: 0.4463
# 2024-04-24 21:32:52,377 Trainer INFO: Main Network Training:
# cosine score: 86.0544, l1 score: 81.7336, clip score: 27.2263, critic score: -2.0470
# reward loss: -0.4778, fD loss: 0.2042
#
# 2024-04-24 21:33:53,778 Trainer INFO: Epoch: 1, global_step: 2325
# G loss: -0.3250, D loss: 0.4585
# 2024-04-24 21:33:53,779 Trainer INFO: Main Network Training:
# cosine score: 85.9650, l1 score: 81.2343, clip score: 26.9936, critic score: -2.2505
# reward loss: -0.7909, fD loss: 0.0764
#
# 2024-04-24 21:34:54,864 Trainer INFO: Epoch: 1, global_step: 2350
# G loss: -0.0111, D loss: 0.4048
# 2024-04-24 21:34:54,865 Trainer INFO: Main Network Training:
# cosine score: 83.6422, l1 score: 79.7984, clip score: 25.7803, critic score: -1.5667
# reward loss: -0.1910, fD loss: 0.1472
#
# 2024-04-24 21:35:55,591 Trainer INFO: Epoch: 1, global_step: 2375
# G loss: -0.3667, D loss: 0.3844
# 2024-04-24 21:35:55,592 Trainer INFO: Main Network Training:
# cosine score: 86.7071, l1 score: 81.2542, clip score: 26.7870, critic score: -1.8410
# reward loss: -0.6941, fD loss: -0.0723
#
# 2024-04-24 21:36:54,798 Trainer INFO: Epoch: 1, global_step: 2400
# G loss: -0.3340, D loss: 0.3303
# 2024-04-24 21:36:54,799 Trainer INFO: Main Network Training:
# cosine score: 85.7683, l1 score: 80.6633, clip score: 26.1506, critic score: -2.2178
# reward loss: -0.4425, fD loss: -0.2342
#
# 2024-04-24 21:37:54,046 Trainer INFO: Epoch: 1, global_step: 2425
# G loss: 0.0165, D loss: 0.3897
# 2024-04-24 21:37:54,046 Trainer INFO: Main Network Training:
# cosine score: 86.3606, l1 score: 81.6045, clip score: 25.3445, critic score: -2.8330
# reward loss: -0.2262, fD loss: 0.2441
#
# 2024-04-24 21:38:55,478 Trainer INFO: Epoch: 1, global_step: 2450
# G loss: -0.3441, D loss: 0.3650
# 2024-04-24 21:38:55,478 Trainer INFO: Main Network Training:
# cosine score: 87.4523, l1 score: 81.8818, clip score: 26.4783, critic score: -2.2578
# reward loss: -0.5065, fD loss: -0.1884
#
# 2024-04-24 21:39:56,170 Trainer INFO: Epoch: 1, global_step: 2475
# G loss: -0.3136, D loss: 0.4019
# 2024-04-24 21:39:56,170 Trainer INFO: Main Network Training:
# cosine score: 86.0982, l1 score: 81.1773, clip score: 27.4353, critic score: -2.3719
# reward loss: -0.8849, fD loss: 0.2456
#
# 2024-04-24 21:40:56,821 Trainer INFO: Epoch: 1, global_step: 2500
# G loss: -0.1695, D loss: 0.3780
# 2024-04-24 21:40:56,821 Trainer INFO: Main Network Training:
# cosine score: 86.7272, l1 score: 81.6508, clip score: 26.4354, critic score: -2.5403
# reward loss: -0.4835, fD loss: 0.1446
#
# 2024-04-24 21:41:57,972 Trainer INFO: Epoch: 1, global_step: 2525
# G loss: -0.6228, D loss: 0.3140
# 2024-04-24 21:41:57,973 Trainer INFO: Main Network Training:
# cosine score: 86.5734, l1 score: 82.0693, clip score: 27.0686, critic score: -2.2988
# reward loss: -1.2484, fD loss: 0.0027
#
# 2024-04-24 21:42:58,742 Trainer INFO: Epoch: 1, global_step: 2550
# G loss: -0.5834, D loss: 0.3852
# 2024-04-24 21:42:58,742 Trainer INFO: Main Network Training:
# cosine score: 85.9442, l1 score: 82.1058, clip score: 27.9420, critic score: -1.6665
# reward loss: -1.1992, fD loss: 0.0324
#
# 2024-04-24 21:44:00,454 Trainer INFO: Epoch: 1, global_step: 2575
# G loss: -0.2475, D loss: 0.3730
# 2024-04-24 21:44:00,454 Trainer INFO: Main Network Training:
# cosine score: 86.2677, l1 score: 81.2920, clip score: 27.4682, critic score: -2.0097
# reward loss: -0.6612, fD loss: 0.1662
#
# 2024-04-24 21:45:02,168 Trainer INFO: Epoch: 1, global_step: 2600
# G loss: -0.1084, D loss: 0.3974
# 2024-04-24 21:45:02,169 Trainer INFO: Main Network Training:
# cosine score: 85.8291, l1 score: 81.3782, clip score: 25.8109, critic score: -2.0325
# reward loss: -0.4069, fD loss: 0.1901
#
# 2024-04-24 21:46:04,023 Trainer INFO: Epoch: 1, global_step: 2625
# G loss: -0.9137, D loss: 0.3728
# 2024-04-24 21:46:04,024 Trainer INFO: Main Network Training:
# cosine score: 88.7069, l1 score: 82.7328, clip score: 26.4003, critic score: -2.1086
# reward loss: -2.0365, fD loss: 0.2092
#
# 2024-04-24 21:47:05,390 Trainer INFO: Epoch: 1, global_step: 2650
# G loss: -0.3217, D loss: 0.3918
# 2024-04-24 21:47:05,391 Trainer INFO: Main Network Training:
# cosine score: 87.4041, l1 score: 82.2860, clip score: 27.4988, critic score: -2.2898
# reward loss: -0.6775, fD loss: 0.0340
#
# 2024-04-24 21:48:06,023 Trainer INFO: Epoch: 1, global_step: 2675
# G loss: -0.4092, D loss: 0.4261
# 2024-04-24 21:48:06,024 Trainer INFO: Main Network Training:
# cosine score: 87.8506, l1 score: 82.4816, clip score: 27.2489, critic score: -2.1456
# reward loss: -0.6912, fD loss: -0.1272
#
# 2024-04-24 21:49:06,301 Trainer INFO: Epoch: 1, global_step: 2700
# G loss: -0.1311, D loss: 0.3023
# 2024-04-24 21:49:06,302 Trainer INFO: Main Network Training:
# cosine score: 85.9746, l1 score: 80.5732, clip score: 25.4261, critic score: -2.5902
# reward loss: -0.4703, fD loss: 0.2081
#
# 2024-04-24 21:50:06,809 Trainer INFO: Epoch: 1, global_step: 2725
# G loss: -0.2213, D loss: 0.3624
# 2024-04-24 21:50:06,810 Trainer INFO: Main Network Training:
# cosine score: 85.8242, l1 score: 80.6093, clip score: 25.9057, critic score: -2.6034
# reward loss: -0.6506, fD loss: 0.2081
#
# 2024-04-24 21:51:08,111 Trainer INFO: Epoch: 1, global_step: 2750
# G loss: -0.4320, D loss: 0.3430
# 2024-04-24 21:51:08,111 Trainer INFO: Main Network Training:
# cosine score: 86.1104, l1 score: 81.6397, clip score: 27.4394, critic score: -2.5057
# reward loss: -0.9479, fD loss: 0.0839
#
# 2024-04-24 21:52:09,438 Trainer INFO: Epoch: 1, global_step: 2775
# G loss: 0.0533, D loss: 0.3411
# 2024-04-24 21:52:09,438 Trainer INFO: Main Network Training:
# cosine score: 89.6872, l1 score: 83.6807, clip score: 27.1076, critic score: -2.4983
# reward loss: -0.0151, fD loss: 0.1217
#
# 2024-04-24 21:53:10,043 Trainer INFO: Epoch: 1, global_step: 2800
# G loss: -0.3072, D loss: 0.3135
# 2024-04-24 21:53:10,044 Trainer INFO: Main Network Training:
# cosine score: 87.8031, l1 score: 82.3433, clip score: 25.5882, critic score: -2.1402
# reward loss: -0.8156, fD loss: 0.2013
#
# 2024-04-24 21:54:10,854 Trainer INFO: Epoch: 1, global_step: 2825
# G loss: -0.0941, D loss: 0.3899
# 2024-04-24 21:54:10,855 Trainer INFO: Main Network Training:
# cosine score: 88.5203, l1 score: 82.6716, clip score: 27.2057, critic score: -2.4850
# reward loss: -0.3596, fD loss: 0.1714
#
# 2024-04-24 21:55:11,747 Trainer INFO: Epoch: 1, global_step: 2850
# G loss: -0.3308, D loss: 0.3623
# 2024-04-24 21:55:11,748 Trainer INFO: Main Network Training:
# cosine score: 89.2543, l1 score: 83.5063, clip score: 25.8196, critic score: -2.4906
# reward loss: -0.9565, fD loss: 0.2948
#
# 2024-04-24 21:56:13,254 Trainer INFO: Epoch: 1, global_step: 2875
# G loss: -0.2811, D loss: 0.3362
# 2024-04-24 21:56:13,255 Trainer INFO: Main Network Training:
# cosine score: 85.0735, l1 score: 80.1598, clip score: 25.2135, critic score: -2.3325
# reward loss: -0.7862, fD loss: 0.2240
#
# 2024-04-24 21:57:15,293 Trainer INFO: Epoch: 1, global_step: 2900
# G loss: -0.3484, D loss: 0.3232
# 2024-04-24 21:57:15,294 Trainer INFO: Main Network Training:
# cosine score: 85.1638, l1 score: 80.5817, clip score: 25.8802, critic score: -2.7008
# reward loss: -0.7760, fD loss: 0.0791
#
# 2024-04-24 21:58:17,480 Trainer INFO: Epoch: 1, global_step: 2925
# G loss: -0.3052, D loss: 0.3238
# 2024-04-24 21:58:17,481 Trainer INFO: Main Network Training:
# cosine score: 89.2169, l1 score: 83.6866, clip score: 27.8633, critic score: -2.7901
# reward loss: -0.6259, fD loss: 0.0154
#
# 2024-04-24 21:59:18,360 Trainer INFO: Epoch: 1, global_step: 2950
# G loss: -0.7682, D loss: 0.3943
# 2024-04-24 21:59:18,361 Trainer INFO: Main Network Training:
# cosine score: 85.9277, l1 score: 81.1216, clip score: 26.9829, critic score: -2.4895
# reward loss: -1.4960, fD loss: -0.0405
#
# 2024-04-24 22:00:18,796 Trainer INFO: Epoch: 1, global_step: 2975
# G loss: -0.0497, D loss: 0.3585
# 2024-04-24 22:00:18,796 Trainer INFO: Main Network Training:
# cosine score: 84.1986, l1 score: 79.6926, clip score: 25.9961, critic score: -2.3548
# reward loss: -0.1711, fD loss: 0.0717
#
# 2024-04-24 22:01:19,525 Trainer INFO: Epoch: 1, global_step: 3000
# G loss: -0.2307, D loss: 0.3436
# 2024-04-24 22:01:19,525 Trainer INFO: Main Network Training:
# cosine score: 83.6853, l1 score: 79.8122, clip score: 24.9517, critic score: -2.8306
# reward loss: -0.4420, fD loss: -0.0193
#
# 2024-04-24 22:02:19,702 Trainer INFO: Epoch: 1, global_step: 3025
# G loss: -0.7609, D loss: 0.3399
# 2024-04-24 22:02:19,702 Trainer INFO: Main Network Training:
# cosine score: 87.4737, l1 score: 82.0098, clip score: 26.9291, critic score: -2.6305
# reward loss: -1.9230, fD loss: 0.4012
#
# 2024-04-24 22:03:19,992 Trainer INFO: Epoch: 1, global_step: 3050
# G loss: -0.1801, D loss: 0.2987
# 2024-04-24 22:03:19,993 Trainer INFO: Main Network Training:
# cosine score: 85.2672, l1 score: 81.0349, clip score: 26.7534, critic score: -2.6345
# reward loss: -0.2889, fD loss: -0.0713
#
# 2024-04-24 22:04:21,238 Trainer INFO: Epoch: 1, global_step: 3075
# G loss: -0.3151, D loss: 0.4919
# 2024-04-24 22:04:21,239 Trainer INFO: Main Network Training:
# cosine score: 85.2706, l1 score: 81.4552, clip score: 25.8102, critic score: -2.7819
# reward loss: -0.3975, fD loss: -0.2327
#
# 2024-04-24 22:05:23,473 Trainer INFO: Epoch: 1, global_step: 3100
# G loss: -0.1019, D loss: 0.2539
# 2024-04-24 22:05:23,474 Trainer INFO: Main Network Training:
# cosine score: 86.7934, l1 score: 81.1412, clip score: 25.8816, critic score: -2.8607
# reward loss: -0.1610, fD loss: -0.0427
#
# 2024-04-24 22:06:24,687 Trainer INFO: Epoch: 1, global_step: 3125
# G loss: -0.3780, D loss: 0.5389
# 2024-04-24 22:06:24,688 Trainer INFO: Main Network Training:
# cosine score: 84.2718, l1 score: 80.5286, clip score: 25.9395, critic score: -2.3778
# reward loss: -1.0357, fD loss: 0.2796
#
# 2024-04-24 22:07:24,720 Trainer INFO: Epoch: 1, global_step: 3150
# G loss: 0.2189, D loss: 0.3000
# 2024-04-24 22:07:24,720 Trainer INFO: Main Network Training:
# cosine score: 88.4301, l1 score: 82.8000, clip score: 26.7310, critic score: -3.0398
# reward loss: 0.3170, fD loss: 0.1207
#
# 2024-04-24 22:08:25,021 Trainer INFO: Epoch: 1, global_step: 3175
# G loss: 0.0346, D loss: 0.4211
# 2024-04-24 22:08:25,022 Trainer INFO: Main Network Training:
# cosine score: 87.3885, l1 score: 82.3882, clip score: 26.7608, critic score: -2.4951
# reward loss: 0.0390, fD loss: 0.0303
#
# 2024-04-24 22:09:26,105 Trainer INFO: Epoch: 1, global_step: 3200
# G loss: -0.1738, D loss: 0.2697
# 2024-04-24 22:09:26,106 Trainer INFO: Main Network Training:
# cosine score: 87.0848, l1 score: 81.4667, clip score: 25.6734, critic score: -2.7387
# reward loss: -0.1697, fD loss: -0.1779
#
# 2024-04-24 22:10:27,470 Trainer INFO: Epoch: 1, global_step: 3225
# G loss: -0.5050, D loss: 0.4089
# 2024-04-24 22:10:27,471 Trainer INFO: Main Network Training:
# cosine score: 85.5891, l1 score: 80.9180, clip score: 26.1240, critic score: -2.2407
# reward loss: -0.8843, fD loss: -0.1257
#
# 2024-04-24 22:11:29,232 Trainer INFO: Epoch: 1, global_step: 3250
# G loss: -0.0695, D loss: 0.3957
# 2024-04-24 22:11:29,232 Trainer INFO: Main Network Training:
# cosine score: 88.5370, l1 score: 82.9797, clip score: 27.3718, critic score: -2.5420
# reward loss: -0.4640, fD loss: 0.3250
#
# 2024-04-24 22:12:29,214 Trainer INFO: Epoch: 1, global_step: 3275
# G loss: -0.0135, D loss: 0.4216
# 2024-04-24 22:12:29,214 Trainer INFO: Main Network Training:
# cosine score: 86.2079, l1 score: 80.9992, clip score: 26.0996, critic score: -2.3424
# reward loss: -0.1485, fD loss: 0.1216
#
# 2024-04-24 22:13:28,606 Trainer INFO: Epoch: 1, global_step: 3300
# G loss: -0.0589, D loss: 0.3280
# 2024-04-24 22:13:28,607 Trainer INFO: Main Network Training:
# cosine score: 87.0466, l1 score: 82.2866, clip score: 26.4596, critic score: -2.5623
# reward loss: -0.2950, fD loss: 0.1771
#
# 2024-04-24 22:14:27,868 Trainer INFO: Epoch: 1, global_step: 3325
# G loss: -0.6796, D loss: 0.4284
# 2024-04-24 22:14:27,869 Trainer INFO: Main Network Training:
# cosine score: 84.1554, l1 score: 80.3032, clip score: 25.1972, critic score: -1.8749
# reward loss: -1.6584, fD loss: 0.2992
#
# 2024-04-24 22:15:28,087 Trainer INFO: Epoch: 1, global_step: 3350
# G loss: -0.1670, D loss: 0.3149
# 2024-04-24 22:15:28,087 Trainer INFO: Main Network Training:
# cosine score: 85.1646, l1 score: 81.1608, clip score: 26.8541, critic score: -2.6136
# reward loss: -0.1548, fD loss: -0.1792
#
# 2024-04-24 22:16:28,491 Trainer INFO: Epoch: 1, global_step: 3375
# G loss: -0.0572, D loss: 0.3036
# 2024-04-24 22:16:28,491 Trainer INFO: Main Network Training:
# cosine score: 87.7826, l1 score: 82.3121, clip score: 26.3068, critic score: -2.7940
# reward loss: -0.2629, fD loss: 0.1484
#
# 2024-04-24 22:17:30,154 Trainer INFO: Epoch: 1, global_step: 3400
# G loss: 0.0603, D loss: 0.3003
# 2024-04-24 22:17:30,155 Trainer INFO: Main Network Training:
# ...
# 2024-04-25 05:20:21,722 Trainer INFO: Main Network Training:
# cosine score: 84.3790, l1 score: 80.4257, clip score: 25.6794, critic score: -2.9171
# reward loss: -1.4536, fD loss: 0.3026
#
# 2024-04-25 05:21:23,199 Trainer INFO: Epoch: 4, global_step: 13400
# G loss: -0.2122, D loss: 0.2870
# 2024-04-25 05:21:23,200 Trainer INFO: Main Network Training:
# cosine score: 86.3905, l1 score: 81.3148, clip score: 25.1861, critic score: -2.0211
# reward loss: -0.7201, fD loss: 0.2958
#
# 2024-04-25 05:22:26,522 Trainer INFO: Epoch: 4, global_step: 13425
# G loss: 0.0272, D loss: 0.3261
# 2024-04-25 05:22:26,523 Trainer INFO: Main Network Training:
# cosine score: 87.2188, l1 score: 81.7655, clip score: 26.4083, critic score: -2.5824
# reward loss: -0.2345, fD loss: 0.2889
#
# 2024-04-25 05:23:28,099 Trainer INFO: Epoch: 4, global_step: 13450
# G loss: -0.1793, D loss: 0.3046
# 2024-04-25 05:23:28,099 Trainer INFO: Main Network Training:
# cosine score: 85.5923, l1 score: 80.2660, clip score: 25.9474, critic score: -2.7863
# reward loss: -0.3876, fD loss: 0.0291
#
# 2024-04-25 05:24:29,692 Trainer INFO: Epoch: 4, global_step: 13475
# G loss: -0.2515, D loss: 0.2956
# 2024-04-25 05:24:29,693 Trainer INFO: Main Network Training:
# cosine score: 87.3538, l1 score: 82.6447, clip score: 26.9581, critic score: -2.4196
# reward loss: -0.2673, fD loss: -0.2356
#
# 2024-04-25 05:25:30,662 Trainer INFO: Epoch: 4, global_step: 13500
# G loss: -0.1347, D loss: 0.2574
# 2024-04-25 05:25:30,663 Trainer INFO: Main Network Training:
# cosine score: 86.2759, l1 score: 80.7791, clip score: 26.4746, critic score: -2.9607
# reward loss: -0.3868, fD loss: 0.1174
#
# 2024-04-25 05:26:29,915 Trainer INFO: Epoch: 4, global_step: 13525
# G loss: -0.3475, D loss: 0.2491
# 2024-04-25 05:26:29,916 Trainer INFO: Main Network Training:
# cosine score: 87.4156, l1 score: 82.2250, clip score: 26.6779, critic score: -2.9344
# reward loss: -0.7807, fD loss: 0.0857
#
# 2024-04-25 05:27:30,318 Trainer INFO: Epoch: 4, global_step: 13550
# G loss: -0.1307, D loss: 0.3024
# 2024-04-25 05:27:30,319 Trainer INFO: Main Network Training:
# cosine score: 88.5004, l1 score: 82.8487, clip score: 26.8155, critic score: -3.0450
# reward loss: -0.9818, fD loss: 0.7204
#
# 2024-04-25 05:28:31,528 Trainer INFO: Epoch: 4, global_step: 13575
# G loss: -0.3370, D loss: 0.3584
# 2024-04-25 05:28:31,529 Trainer INFO: Main Network Training:
# cosine score: 85.2700, l1 score: 80.8942, clip score: 27.3254, critic score: -2.1518
# reward loss: -0.7247, fD loss: 0.0508
#
# 2024-04-25 05:29:32,188 Trainer INFO: Epoch: 4, global_step: 13600
# G loss: -0.2294, D loss: 0.2518
# 2024-04-25 05:29:32,188 Trainer INFO: Main Network Training:
# cosine score: 89.0768, l1 score: 83.0628, clip score: 27.0897, critic score: -2.1753
# reward loss: -0.6130, fD loss: 0.1541
#
# 2024-04-25 05:30:32,513 Trainer INFO: Epoch: 4, global_step: 13625
# G loss: 0.1267, D loss: 0.3859
# 2024-04-25 05:30:32,514 Trainer INFO: Main Network Training:
# cosine score: 82.8277, l1 score: 79.7438, clip score: 26.8093, critic score: -2.2957
# reward loss: -0.5013, fD loss: 0.7547
#
# 2024-04-25 05:31:33,035 Trainer INFO: Epoch: 4, global_step: 13650
# G loss: -0.0702, D loss: 0.2486
# 2024-04-25 05:31:33,036 Trainer INFO: Main Network Training:
# cosine score: 88.7305, l1 score: 83.0449, clip score: 26.5188, critic score: -2.7112
# reward loss: -0.2795, fD loss: 0.1390
#
# 2024-04-25 05:32:33,109 Trainer INFO: Epoch: 4, global_step: 13675
# G loss: -0.0692, D loss: 0.2758
# 2024-04-25 05:32:33,110 Trainer INFO: Main Network Training:
# cosine score: 83.0682, l1 score: 79.6400, clip score: 25.8631, critic score: -2.9962
# reward loss: -0.1476, fD loss: 0.0091
#
# 2024-04-25 05:33:31,987 Trainer INFO: Epoch: 4, global_step: 13700
# G loss: -0.1293, D loss: 0.3057
# 2024-04-25 05:33:31,987 Trainer INFO: Main Network Training:
# cosine score: 85.9378, l1 score: 80.7723, clip score: 25.6838, critic score: -3.1823
# reward loss: -0.2978, fD loss: 0.0392
#
# 2024-04-25 05:34:30,989 Trainer INFO: Epoch: 4, global_step: 13725
# G loss: -0.2003, D loss: 0.2164
# 2024-04-25 05:34:30,989 Trainer INFO: Main Network Training:
# cosine score: 90.8784, l1 score: 84.4075, clip score: 26.3310, critic score: -3.2449
# reward loss: -0.4147, fD loss: 0.0141
#
# 2024-04-25 05:35:32,405 Trainer INFO: Epoch: 4, global_step: 13750
# G loss: -0.3992, D loss: 0.3706
# 2024-04-25 05:35:32,406 Trainer INFO: Main Network Training:
# cosine score: 85.9405, l1 score: 80.6792, clip score: 25.8690, critic score: -2.5964
# reward loss: -0.5478, fD loss: -0.2506
#
# 2024-04-25 05:36:32,549 Trainer INFO: Epoch: 4, global_step: 13775
# G loss: -0.5035, D loss: 0.2832
# 2024-04-25 05:36:32,550 Trainer INFO: Main Network Training:
# cosine score: 87.2966, l1 score: 82.4109, clip score: 26.8289, critic score: -3.0426
# reward loss: -1.2052, fD loss: 0.1982
#
# 2024-04-25 05:37:32,637 Trainer INFO: Epoch: 4, global_step: 13800
# G loss: -0.0626, D loss: 0.3072
# 2024-04-25 05:37:32,638 Trainer INFO: Main Network Training:
# cosine score: 91.0256, l1 score: 84.2290, clip score: 26.7784, critic score: -3.2105
# reward loss: -0.1754, fD loss: 0.0503
#
# 2024-04-25 05:38:32,909 Trainer INFO: Epoch: 4, global_step: 13825
# G loss: -0.1209, D loss: 0.2100
# 2024-04-25 05:38:32,909 Trainer INFO: Main Network Training:
# cosine score: 83.1714, l1 score: 79.8961, clip score: 25.6590, critic score: -2.8317
# reward loss: -0.5158, fD loss: 0.2741
#
# 2024-04-25 05:39:32,804 Trainer INFO: Epoch: 4, global_step: 13850
# G loss: -0.3630, D loss: 0.3434
# 2024-04-25 05:39:32,804 Trainer INFO: Main Network Training:
# cosine score: 86.7196, l1 score: 81.5426, clip score: 25.8622, critic score: -2.8669
# reward loss: -0.9341, fD loss: 0.2081
#
# 2024-04-25 05:40:32,816 Trainer INFO: Epoch: 4, global_step: 13875
# G loss: -0.2933, D loss: 0.2865
# 2024-04-25 05:40:32,816 Trainer INFO: Main Network Training:
# cosine score: 85.5167, l1 score: 81.3372, clip score: 25.9306, critic score: -3.0901
# reward loss: -0.6204, fD loss: 0.0338
#
# 2024-04-25 05:41:32,408 Trainer INFO: Epoch: 4, global_step: 13900
# G loss: -0.2795, D loss: 0.2753
# 2024-04-25 05:41:32,409 Trainer INFO: Main Network Training:
# cosine score: 82.6767, l1 score: 79.3708, clip score: 25.4342, critic score: -2.8719
# reward loss: -0.6460, fD loss: 0.0869
#
# 2024-04-25 05:42:31,522 Trainer INFO: Epoch: 4, global_step: 13925
# G loss: -0.0986, D loss: 0.2464
# 2024-04-25 05:42:31,522 Trainer INFO: Main Network Training:
# cosine score: 88.0739, l1 score: 82.4072, clip score: 27.0053, critic score: -3.1583
# reward loss: -0.1901, fD loss: -0.0072
#
# 2024-04-25 05:43:31,756 Trainer INFO: Epoch: 4, global_step: 13950
# G loss: -0.5311, D loss: 0.2455
# 2024-04-25 05:43:31,757 Trainer INFO: Main Network Training:
# cosine score: 88.0307, l1 score: 82.2757, clip score: 25.9992, critic score: -3.1946
# reward loss: -0.9039, fD loss: -0.1583
#
# 2024-04-25 05:44:32,755 Trainer INFO: Epoch: 4, global_step: 13975
# G loss: -0.1848, D loss: 0.2752
# 2024-04-25 05:44:32,756 Trainer INFO: Main Network Training:
# cosine score: 84.3408, l1 score: 80.5406, clip score: 26.0882, critic score: -2.9775
# reward loss: -0.5180, fD loss: 0.1484
#
# 2024-04-25 05:45:33,491 Trainer INFO: Epoch: 4, global_step: 14000
# G loss: -0.2169, D loss: 0.3210
# 2024-04-25 05:45:33,492 Trainer INFO: Main Network Training:
# cosine score: 86.7843, l1 score: 81.9672, clip score: 25.2571, critic score: -2.6300
# reward loss: -0.4365, fD loss: 0.0026
#
# 2024-04-25 05:46:33,999 Trainer INFO: Epoch: 4, global_step: 14025
# G loss: -0.0857, D loss: 0.2628
# 2024-04-25 05:46:34,000 Trainer INFO: Main Network Training:
# cosine score: 90.2163, l1 score: 83.1777, clip score: 26.4448, critic score: -3.2395
# reward loss: -0.1543, fD loss: -0.0170
#
# 2024-04-25 05:47:34,762 Trainer INFO: Epoch: 4, global_step: 14050
# G loss: -0.1923, D loss: 0.2271
# 2024-04-25 05:47:34,762 Trainer INFO: Main Network Training:
# cosine score: 90.6775, l1 score: 83.7548, clip score: 26.5542, critic score: -2.9688
# reward loss: -0.6460, fD loss: 0.2614
#
# 2024-04-25 05:48:36,244 Trainer INFO: Epoch: 4, global_step: 14075
# G loss: -0.2213, D loss: 0.2598
# 2024-04-25 05:48:36,244 Trainer INFO: Main Network Training:
# cosine score: 83.9128, l1 score: 80.3229, clip score: 27.3006, critic score: -2.8366
# reward loss: -0.3027, fD loss: -0.1399
#
# 2024-04-25 05:49:36,988 Trainer INFO: Epoch: 4, global_step: 14100
# G loss: -0.1570, D loss: 0.3224
# 2024-04-25 05:49:36,989 Trainer INFO: Main Network Training:
# cosine score: 86.9917, l1 score: 81.1585, clip score: 25.3909, critic score: -2.1823
# reward loss: -0.5249, fD loss: 0.2110
#
# 2024-04-25 05:50:37,459 Trainer INFO: Epoch: 4, global_step: 14125
# G loss: -0.3309, D loss: 0.2316
# 2024-04-25 05:50:37,460 Trainer INFO: Main Network Training:
# cosine score: 87.8190, l1 score: 81.8936, clip score: 26.0200, critic score: -2.9717
# reward loss: -0.7250, fD loss: 0.0632
#
# 2024-04-25 05:51:38,463 Trainer INFO: Epoch: 4, global_step: 14150
# G loss: -0.1777, D loss: 0.3067
# 2024-04-25 05:51:38,463 Trainer INFO: Main Network Training:
# cosine score: 87.5251, l1 score: 82.0993, clip score: 27.4630, critic score: -2.3751
# reward loss: -0.3824, fD loss: 0.0269
#
# 2024-04-25 05:52:05,244 Trainer INFO: Save checkpoint to /kaggle/working/output/checkpoint
# 2024-04-25 05:52:05,245 Trainer INFO: Epoch 4 training finish. Performing evaluation
# 2024-04-25 05:52:41,837 Trainer INFO: Inference model computing time: 0.2171213459816708 seconds per batch
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 307821 tokens at 507900.09 tokens per second.
# PTBTokenizer tokenized 60108 tokens at 178304.30 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 49825, 'reflen': 48983, 'guess': [49825, 44825, 39825, 34825], 'correct': [35578, 17517, 7306, 2913]}
# ratio: 1.017189637221056
# Bleu_1: 0.714
# Bleu_2: 0.528
# Bleu_3: 0.371
# Bleu_4: 0.256
# computing METEOR score...
# METEOR: 0.258
# computing Rouge score...
# ROUGE_L: 0.516
# computing CIDEr score...
# CIDEr: 0.978
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/opt/conda/lib/python3.10/site-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.8 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.9 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.9 sec].
# Threads( StanfordCoreNLP ) [01:23.943 minutes]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 1.714 min
# SPICE: 0.194
# 2024-04-25 05:54:58,715 Trainer INFO: evaluation result: {'Bleu_1': 0.7140592072252743, 'Bleu_2': 0.5282467424651462, 'Bleu_3': 0.37130646657462785, 'Bleu_4': 0.2558065876971371, 'METEOR': 0.25760591460731064, 'ROUGE_L': 0.5160184598591336, 'CIDEr': 0.9775551622447168, 'SPICE': 0.19365911729534482}
#
# 2024-04-25 05:54:58,716 Trainer INFO: epoch: 4, best cider: 0.9775551622447168
# 2024-04-25 05:55:00,208 Trainer INFO: Save checkpoint to /kaggle/working/output/best
# 2024-04-25 05:55:00,209 Trainer INFO: average cos score: [85.49278672428454, 86.88796228527349, 87.05762549147094, 87.16643438177594]
#  average l1 score: [80.98022020415398, 81.74765054304048, 81.85092853395278, 81.90690094899323]
#  average clip score: [26.254027876880883, 26.320640725065758, 26.368809486108983, 26.38542396092819]
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# Image Embedding Data size for generation is 5000
# Clip embedding dim is 768
# 2024-04-25 05:55:12,442 Trainer INFO: Testing best checkpoint
# 2024-04-25 05:55:12,442 Trainer INFO: loading generator from /kaggle/working/output/best/model.pt
# 2024-04-25 05:55:48,919 Trainer INFO: Inference model computing time: 0.21397646217589167 seconds per batch
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 307086 tokens at 502839.26 tokens per second.
# PTBTokenizer tokenized 60158 tokens at 187596.91 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 49927, 'reflen': 48974, 'guess': [49927, 44927, 39927, 34927], 'correct': [35604, 17632, 7580, 3223]}
# ratio: 1.0194593049372929
# Bleu_1: 0.713
# Bleu_2: 0.529
# Bleu_3: 0.376
# Bleu_4: 0.265
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.516
# computing CIDEr score...
# CIDEr: 0.996
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/opt/conda/lib/python3.10/site-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.8 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.9 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# Threads( StanfordCoreNLP ) [03:51.401 minutes]
# Threads( StanfordCoreNLP ) [03:30.519 minutes]
# Threads( StanfordCoreNLP ) [01:34.675 minutes]
# Parsing test captions
# Threads( StanfordCoreNLP ) [01:16.614 minutes]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 10.64 min
# SPICE: 0.198
# 2024-04-25 06:07:02,143 Trainer INFO: Evaluation results : {'Bleu_1': 0.7131211568890438, 'Bleu_2': 0.529028098423654, 'Bleu_3': 0.37594126772437736, 'Bleu_4': 0.2646151812654239, 'METEOR': 0.25958932633903153, 'ROUGE_L': 0.5159139071660721, 'CIDEr': 0.9964638910828889, 'SPICE': 0.1976395915420425}

# %%
# !nvidia-smi
# Out:
# Thu Apr 25 06:07:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  Tesla T4                       Off | 00000000:00:05.0 Off |                    0 |
# | N/A   73C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
import zipfile
from IPython.display import FileLink
from tqdm import tqdm

def zip_and_display(folder_path, zip_file_name):
    """
    Zip a folder and display the link to the zipped file.

    Parameters:
    - folder_path (str): Path to the folder to be zipped.
    - zip_file_name (str): Name of the zip file to be created.

    Returns:
    - None
    """
    zip_file_path = os.path.join(os.path.dirname(folder_path), zip_file_name)
    
    # Get total number of files for tqdm
    total_files = sum(len(files) for _, _, files in os.walk(folder_path))
    
    # Create a ZipFile object
    with zipfile.ZipFile(zip_file_path, 'w') as zipf:
        # Walk through all files and folders in the given directory
        for root, _, files in tqdm(os.walk(folder_path), total=total_files, desc='Zipping files'):
            for file in files:
                file_path = os.path.join(root, file)
                # Add the file to the zip archive
                zipf.write(file_path, os.path.relpath(file_path, folder_path))
    
    # Display the link to the zipped file
    display(FileLink(zip_file_name))

# %%
zip_and_display('/kaggle/working/output', 'cgt-gan-epoch-1.zip')
# Out:
# Zipping files:  38%|███▊      | 3/8 [00:03<00:05,  1.13s/it]
# /kaggle/working/cgt-gan-epoch-1.zip
